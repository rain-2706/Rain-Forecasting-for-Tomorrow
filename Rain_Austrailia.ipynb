# %% [markdown]
# ## `1) Introduction:` <a class="anchor" id="1"></a>

# %% [markdown]
# `Problem - Statement:` Build an efficient Classification Model that should predict whether it Rains Tomorrow or not, using the dataset **Rain in Australia.**
#
# Data source: [Kaggle](https://www.kaggle.com/jsphyg/weather-dataset-rattle-package)

# %% [markdown]
# ## `2) Import Libraries:` <a class="anchor" id="2"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import pickle
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("display.max_columns",None)

# %% [markdown]
# ## `3) Import Data Set`  <a class="anchor" id="3"></a>

# %%
rain = pd.read_csv('weatherAUS.csv')

# %%
rain.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# 4           W           41.0        ENE         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0          24.0         71.0         22.0       1007.7       1007.1       8.0
# 1          22.0         44.0         25.0       1010.6       1007.8       NaN
# 2          26.0         38.0         30.0       1007.6       1008.7       NaN
# 3           9.0         45.0         16.0       1017.6       1012.8       NaN
# 4          20.0         82.0         33.0       1010.8       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       NaN     16.9     21.8        No           No
# 1       NaN     17.2     24.3        No           No
# 2       2.0     21.0     23.2        No           No
# 3       NaN     18.1     26.5        No           No
# 4       8.0     17.8     29.7        No           No

# %% [markdown]
# ## `4) Data Preprocessing`  <a class="anchor" id="4"></a>

# %%
rain.shape
# Out:
# (145460, 23)

# %%
rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
# categorical data:

categorical_features = [column_name for column_name in rain.columns if rain[column_name].dtype == 'O']
print("Number of Categorical Features: {}".format(len(categorical_features)))
print("Categorical Features: ",categorical_features)
# Out:
# Number of Categorical Features: 7
# Categorical Features:  ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
# Numerical Features:

numerical_features = [column_name for column_name in rain.columns if rain[column_name].dtype != 'O']

#rain.select_dtypes(include=['float64','int64']).columns 

print("Number of Numerical Features: {}".format(len(numerical_features)))
print("Numerical Features: ",numerical_features)
# Out:
# Number of Numerical Features: 16
# Numerical Features:  ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>` Cardinality check for Categorical Features:`</b></span>

# %% [markdown]
# - Some Machine Learning algorithms e.g. Logistic Regression, Support Vector Machine can not handle categorical variables and expect all variables to be numeric.
#
#
# - So, categorical data needs to be encoded to numerical data. Before encoding, we need to make sure that categorical features has minimum cardinality.
#
#
# - `Cardinality:` The number of unique values in feature column is known as cardinality. Example: A column with hundreds of zip codes is an example of a high cardinality feature
#
#
# - A high number of unique values within a feature column is known as high cardinality.
#
#
# - High cardinality may pose some serious problems in the machine learning model.
#
#
# - If a feature column as high cardinality, when we use encoding techniques, then that may cause a significant increase number of dimensions, which is not a good for machine learning problems.
#
#
# - If there is high cardinality in feature column, then:
#
#     1) Employ `Feature Engineering` to extract new features from the feature which possess high cardinality. (or)
#
#     2) Simply drop the feature, if that feature doesn't add value to model.

# %%
# finding cardinality of categorical features:

for each_feature in categorical_features:
    print("Cardinality(no. of unique values) of {} are: {}".format(each_feature,len(rain[each_feature].unique())))
# Out:
# Cardinality(no. of unique values) of Date are: 3436
# Cardinality(no. of unique values) of Location are: 49
# Cardinality(no. of unique values) of WindGustDir are: 17
# Cardinality(no. of unique values) of WindDir9am are: 17
# Cardinality(no. of unique values) of WindDir3pm are: 17
# Cardinality(no. of unique values) of RainToday are: 3
# Cardinality(no. of unique values) of RainTomorrow are: 3

# %% [markdown]
# `Date` column has high cardinality which poses several problems to ml model in terms of efficency and also dimenionality of data also increases when converted to numerical data.

# %% [markdown]
# `Feature enginerring of Date column to decrease high cardinality.`

# %%
# Type conversion of Date Column to datetime type:

rain['Date'] = pd.to_datetime(rain['Date'])

# %%
rain['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
rain['year'] = rain['Date'].dt.year
rain['month'] = rain['Date'].dt.month
rain['day'] = rain['Date'].dt.day

# %%
rain.drop('Date', axis = 1, inplace = True)

# %%
rain.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          NaN       NaN           W
# 1   Albury      7.4     25.1       0.0          NaN       NaN         WNW
# 2   Albury     12.9     25.7       0.0          NaN       NaN         WSW
# 3   Albury      9.2     28.0       0.0          NaN       NaN          NE
# 4   Albury     17.5     32.3       1.0          NaN       NaN           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          W        WNW          20.0          24.0
# 1           44.0        NNW        WSW           4.0          22.0
# 2           46.0          W        WSW          19.0          26.0
# 3           24.0         SE          E          11.0           9.0
# 4           41.0        ENE         NW           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1       8.0       NaN
# 1         44.0         25.0       1010.6       1007.8       NaN       NaN
# 2         38.0         30.0       1007.6       1008.7       NaN       2.0
# 3         45.0         16.0       1017.6       1012.8       NaN       NaN
# 4         82.0         33.0       1010.8       1006.0       7.0       8.0
#
#    Temp9am  Temp3pm RainToday RainTomorrow  year  month  day
# 0     16.9     21.8        No           No  2008     12    1
# 1     17.2     24.3        No           No  2008     12    2
# 2     21.0     23.2        No           No  2008     12    3
# 3     18.1     26.5        No           No  2008     12    4
# 4     17.8     29.7        No           No  2008     12    5

# %% [markdown]
# <br>

# %% [markdown]
# <span style='font-size:15px;'><b>` Null (or) NaN (or) Missing Values in Data:`</b></span>
#
#
# The real-world data often has a lot of missing(or null) values. The cause of missing values can be data corruption or failure to record data. The handling of missing data is very important during the preprocessing of the dataset as many machine learning algorithms do not support missing values.
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>` Handling Null values in categorical features:`</b></span>

# %%
# categorical data: 

categorical_features = [column_name for column_name in rain.columns if rain[column_name].dtype == 'O']
print("Number of Categorical Features: {}".format(len(categorical_features)))
print("Categorical Features: ",categorical_features)
# Out:
# Number of Categorical Features: 6
# Categorical Features:  ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
# Numerical Features:

numerical_features = [column_name for column_name in rain.columns if rain[column_name].dtype != 'O']
#rain.select_dtypes(include=['float64','int64']).columns 
print("Number of Numerical Features: {}".format(len(numerical_features)))
print("Numerical Features: ",numerical_features)
# Out:
# Number of Numerical Features: 19
# Numerical Features:  ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'year', 'month', 'day']

# %% [markdown]
# `Checking for Null values:`

# %%
rain[categorical_features].isnull().sum()
# Out:
# Location            0
# WindGustDir     10326
# WindDir9am      10566
# WindDir3pm       4228
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
# list of categorical features which has null values:

categorical_features_with_null = [feature for feature in categorical_features if rain[feature].isnull().sum()]

# %% [markdown]
# `Filling the missing(Null) categorical features with most frequent value(mode)`

# %%
# Filling the missing(Null) categorical features with most frequent value(mode)

for each_feature in categorical_features_with_null:
    mode_val = rain[each_feature].mode()[0]
    rain[each_feature].fillna(mode_val,inplace=True)

# %%
rain[categorical_features].isnull().sum()
# Out:
# Location        0
# WindGustDir     0
# WindDir9am      0
# WindDir3pm      0
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>` Handling Null values in numerical features:`</b></span>

# %%
# checking null values in numerical features

rain[numerical_features].isnull().sum()
# Out:
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustSpeed    10263
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# year                 0
# month                0
# day                  0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(rain[numerical_features].isnull(),linecolor='white')
# Out:
# <AxesSubplot:>

# %%
# visualizing the Null values in Numerical Features:

rain[numerical_features].isnull().sum().sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <br>

# %% [markdown]
# `Null values in Numerical Features can be imputed using Mean and Median. Mean is sensitive to outliers and median is immune to outliers. If you want to impute the null values with mean values, then outliers in numerical features need to be addressed properly.`

# %% [markdown]
# <br>

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>` Checking for outliers in Numerical Features`</b></span>

# %%
#checking for outliers using Box Plot:

for feature in numerical_features:
    plt.figure(figsize=(10,10))
    sns.boxplot(rain[feature])
    plt.title(feature)

# %%
# checking for outliers using the statistical formulas:

rain[numerical_features].describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm           year  \
# count  89572.000000  86102.000000  143693.000000  141851.00000  145460.000000
# mean       4.447461      4.509930      16.990631      21.68339    2012.769751
# std        2.887159      2.720357       6.488753       6.93665       2.537684
# min        0.000000      0.000000      -7.200000      -5.40000    2007.000000
# 25%        1.000000      2.000000      12.300000      16.60000    2011.000000
# 50%        5.000000      5.000000      16.700000      21.10000    2013.000000
# 75%        7.000000      7.000000      21.600000      26.40000    2015.000000
# max        9.000000      9.000000      40.200000      46.70000    2017.000000
#
#                month            day
# count  145460.000000  145460.000000
# mean        6.399615      15.712258
# std         3.427262       8.794789
# min         1.000000       1.000000
# 25%         3.000000       8.000000
# 50%         6.000000      16.000000
# 75%         9.000000      23.000000
# max        12.000000      31.000000

# %% [markdown]
# <br>

# %% [markdown]
# `Outlier Treatment to remove outliers from Numerical Features:`

# %%
# features which has outliers:

features_with_outliers = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'WindGustSpeed','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']

# %%
# Replacing outliers using IQR:

for feature in features_with_outliers:
    q1 = rain[feature].quantile(0.25)
    q3 = rain[feature].quantile(0.75)
    IQR = q3-q1
    lower_limit = q1 - (IQR*1.5)
    upper_limit = q3 + (IQR*1.5)
    rain.loc[rain[feature]<lower_limit,feature] = lower_limit
    rain.loc[rain[feature]>upper_limit,feature] = upper_limit

# %%
for feature in numerical_features:
    plt.figure(figsize=(10,10))
    sns.boxplot(rain[feature])
    plt.title(feature)

# %% [markdown]
# <br>

# %% [markdown]
# `Imputing null values in numerical features using mean:`

# %%
# list of numerical Features with Null values:

numerical_features_with_null = [feature for feature in numerical_features if rain[feature].isnull().sum()]
numerical_features_with_null
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
# Filling null values uisng mean: 

for feature in numerical_features_with_null:
    mean_value = rain[feature].mean()
    rain[feature].fillna(mean_value,inplace=True)

# %%
rain.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# year             0
# month            0
# day              0
# dtype: int64

# %%
rain.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6     5.318667  7.611178           W
# 1   Albury      7.4     25.1       0.0     5.318667  7.611178         WNW
# 2   Albury     12.9     25.7       0.0     5.318667  7.611178         WSW
# 3   Albury      9.2     28.0       0.0     5.318667  7.611178          NE
# 4   Albury     17.5     32.3       1.0     5.318667  7.611178           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          W        WNW          20.0          24.0
# 1           44.0        NNW        WSW           4.0          22.0
# 2           46.0          W        WSW          19.0          26.0
# 3           24.0         SE          E          11.0           9.0
# 4           41.0        ENE         NW           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000   4.50993
# 1         44.0         25.0       1010.6       1007.8  4.447461   4.50993
# 2         38.0         30.0       1007.6       1008.7  4.447461   2.00000
# 3         45.0         16.0       1017.6       1012.8  4.447461   4.50993
# 4         82.0         33.0       1010.8       1006.0  7.000000   8.00000
#
#    Temp9am  Temp3pm RainToday RainTomorrow  year  month  day
# 0     16.9     21.8        No           No  2008     12    1
# 1     17.2     24.3        No           No  2008     12    2
# 2     21.0     23.2        No           No  2008     12    3
# 3     18.1     26.5        No           No  2008     12    4
# 4     17.8     29.7        No           No  2008     12    5

# %% [markdown]
# <br>

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>` Univariate Analysis`</b></span>

# %%
# Exploring RainTomorrow label

rain['RainTomorrow'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Looks like Target variable is imbalanced. It has more 'No' values. If data is imbalanced, then it might decrease performance of model. As this data is released by the meteorological department of Australia, it doesn't make any sense when we try to balance target variable, because the truthfullness of data might descreases. So, let me keep it as it is.

# %%
#Exploring RainToday Variable:

sns.countplot(data=rain, x="RainToday")
plt.grid(linewidth = 0.5)
plt.show()

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>` Multivariate Analysis`</b></span>

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="Location", hue="RainTomorrow", data=rain)

# %%
sns.lineplot(data=rain,x='Sunshine',y='Rainfall',color='goldenrod')
# Out:
# <AxesSubplot:xlabel='Sunshine', ylabel='Rainfall'>

# %%
num_features = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']
rain[num_features].hist(bins=10,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'MinTemp'}>,
#         <AxesSubplot:title={'center':'MaxTemp'}>,
#         <AxesSubplot:title={'center':'Rainfall'}>,
#         <AxesSubplot:title={'center':'Evaporation'}>],
#        [<AxesSubplot:title={'center':'Sunshine'}>,
#         <AxesSubplot:title={'center':'WindGustSpeed'}>,
#         <AxesSubplot:title={'center':'WindSpeed9am'}>,
#         <AxesSubplot:title={'center':'WindSpeed3pm'}>],
#        [<AxesSubplot:title={'center':'Humidity9am'}>,
#         <AxesSubplot:title={'center':'Humidity3pm'}>,
#         <AxesSubplot:title={'center':'Pressure9am'}>,
#         <AxesSubplot:title={'center':'Pressure3pm'}>],
#        [<AxesSubplot:title={'center':'Cloud9am'}>,
#         <AxesSubplot:title={'center':'Cloud3pm'}>,
#         <AxesSubplot:title={'center':'Temp9am'}>,
#         <AxesSubplot:title={'center':'Temp3pm'}>]], dtype=object)

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>` Correlation:`</b></span>

# %% [markdown]
#     - Correlation is a statistic that helps to measure the strength of relationship between features.

# %%
rain.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.733392  0.051203     0.404632  0.051295
# MaxTemp        0.733392  1.000000 -0.255978     0.501465  0.329668
# Rainfall       0.051203 -0.255978  1.000000    -0.188968 -0.261889
# Evaporation    0.404632  0.501465 -0.188968     1.000000  0.339024
# Sunshine       0.051295  0.329668 -0.261889     0.339024  1.000000
# WindGustSpeed  0.180336  0.073229  0.151293     0.170903 -0.019597
# WindSpeed9am   0.177534  0.017140  0.102499     0.157072  0.006782
# WindSpeed3pm   0.177176  0.053117  0.080050     0.113275  0.041356
# Humidity9am   -0.230718 -0.497111  0.387454    -0.421244 -0.349320
# Humidity3pm    0.006033 -0.498544  0.406205    -0.318548 -0.443121
# Pressure9am   -0.428982 -0.314920 -0.179751    -0.248039  0.029821
# Pressure3pm   -0.437161 -0.402168 -0.095155    -0.269624 -0.016637
# Cloud9am       0.062154 -0.225781  0.270881    -0.168963 -0.532497
# Cloud3pm       0.016724 -0.213214  0.234198    -0.167229 -0.553853
# Temp9am        0.897765  0.879365 -0.114011     0.477917  0.208714
# Temp3pm        0.699147  0.968905 -0.260283     0.485623  0.347710
# year           0.043007  0.061734 -0.014480     0.060169  0.006072
# month         -0.202744 -0.163190  0.011964    -0.024221  0.017589
# day            0.002342  0.000655  0.003290    -0.005429 -0.000286
#
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp             0.180336      0.177534      0.177176    -0.230718
# MaxTemp             0.073229      0.017140      0.053117    -0.497111
# Rainfall            0.151293      0.102499      0.080050     0.387454
# Evaporation         0.170903      0.157072      0.113275    -0.421244
# Sunshine           -0.019597      0.006782      0.041356    -0.349320
# WindGustSpeed       1.000000      0.578562      0.659350    -0.214349
# WindSpeed9am        0.578562      1.000000      0.507874    -0.273399
# WindSpeed3pm        0.659350      0.507874      1.000000    -0.146602
# Humidity9am        -0.214349     -0.273399     -0.146602     1.000000
# Humidity3pm        -0.028868     -0.033036      0.015137     0.658850
# Pressure9am        -0.424191     -0.214427     -0.276327     0.133181
# Pressure3pm        -0.381720     -0.164884     -0.237763     0.177319
# Cloud9am            0.050920      0.018119      0.041044     0.354042
# Cloud3pm            0.078253      0.039635      0.018156     0.273774
# Temp9am             0.154054      0.131738      0.165858    -0.468540
# Temp3pm             0.039421      0.007197      0.031299    -0.489627
# year               -0.029014     -0.017855     -0.029658     0.009745
# month               0.058281      0.051481      0.058906    -0.089070
# day                -0.009631     -0.008879     -0.010331     0.015121
#
#                Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# MinTemp           0.006033    -0.428982    -0.437161  0.062154  0.016724
# MaxTemp          -0.498544    -0.314920    -0.402168 -0.225781 -0.213214
# Rainfall          0.406205    -0.179751    -0.095155  0.270881  0.234198
# Evaporation      -0.318548    -0.248039    -0.269624 -0.168963 -0.167229
# Sunshine         -0.443121     0.029821    -0.016637 -0.532497 -0.553853
# WindGustSpeed    -0.028868    -0.424191    -0.381720  0.050920  0.078253
# WindSpeed9am     -0.033036    -0.214427    -0.164884  0.018119  0.039635
# WindSpeed3pm      0.015137    -0.276327    -0.237763  0.041044  0.018156
# Humidity9am       0.658850     0.133181     0.177319  0.354042  0.273774
# Humidity3pm       1.000000    -0.024338     0.050405  0.398762  0.406605
# Pressure9am      -0.024338     1.000000     0.959981 -0.101138 -0.114087
# Pressure3pm       0.050405     0.959981     1.000000 -0.047053 -0.065433
# Cloud9am          0.398762    -0.101138    -0.047053  1.000000  0.559800
# Cloud3pm          0.406605    -0.114087    -0.065433  0.559800  1.000000
# Temp9am          -0.216576    -0.403417    -0.446363 -0.109048 -0.098784
# Temp3pm          -0.555212    -0.272115    -0.366309 -0.232396 -0.247470
# year             -0.009463     0.028290     0.023126  0.051533  0.032182
# month            -0.018568     0.034314     0.025093 -0.007930 -0.003046
# day               0.012813    -0.019915    -0.020277  0.005702 -0.000555
#
#                 Temp9am   Temp3pm      year     month       day
# MinTemp        0.897765  0.699147  0.043007 -0.202744  0.002342
# MaxTemp        0.879365  0.968905  0.061734 -0.163190  0.000655
# Rainfall      -0.114011 -0.260283 -0.014480  0.011964  0.003290
# Evaporation    0.477917  0.485623  0.060169 -0.024221 -0.005429
# Sunshine       0.208714  0.347710  0.006072  0.017589 -0.000286
# WindGustSpeed  0.154054  0.039421 -0.029014  0.058281 -0.009631
# WindSpeed9am   0.131738  0.007197 -0.017855  0.051481 -0.008879
# WindSpeed3pm   0.165858  0.031299 -0.029658  0.058906 -0.010331
# Humidity9am   -0.468540 -0.489627  0.009745 -0.089070  0.015121
# Humidity3pm   -0.216576 -0.555212 -0.009463 -0.018568  0.012813
# Pressure9am   -0.403417 -0.272115  0.028290  0.034314 -0.019915
# Pressure3pm   -0.446363 -0.366309  0.023126  0.025093 -0.020277
# Cloud9am      -0.109048 -0.232396  0.051533 -0.007930  0.005702
# Cloud3pm      -0.098784 -0.247470  0.032182 -0.003046 -0.000555
# Temp9am        1.000000  0.846207  0.045687 -0.135289  0.000183
# Temp3pm        0.846207  1.000000  0.050555 -0.172732 -0.000271
# year           0.045687  0.050555  1.000000 -0.112375 -0.005042
# month         -0.135289 -0.172732 -0.112375  1.000000  0.009223
# day            0.000183 -0.000271 -0.005042  0.009223  1.000000

# %%
plt.figure(figsize=(20,20))
sns.heatmap(rain.corr(),linewidths=0.5,annot=True,fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
rain.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6     5.318667  7.611178           W
# 1   Albury      7.4     25.1       0.0     5.318667  7.611178         WNW
# 2   Albury     12.9     25.7       0.0     5.318667  7.611178         WSW
# 3   Albury      9.2     28.0       0.0     5.318667  7.611178          NE
# 4   Albury     17.5     32.3       1.0     5.318667  7.611178           W
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          W        WNW          20.0          24.0
# 1           44.0        NNW        WSW           4.0          22.0
# 2           46.0          W        WSW          19.0          26.0
# 3           24.0         SE          E          11.0           9.0
# 4           41.0        ENE         NW           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000   4.50993
# 1         44.0         25.0       1010.6       1007.8  4.447461   4.50993
# 2         38.0         30.0       1007.6       1008.7  4.447461   2.00000
# 3         45.0         16.0       1017.6       1012.8  4.447461   4.50993
# 4         82.0         33.0       1010.8       1006.0  7.000000   8.00000
#
#    Temp9am  Temp3pm RainToday RainTomorrow  year  month  day
# 0     16.9     21.8        No           No  2008     12    1
# 1     17.2     24.3        No           No  2008     12    2
# 2     21.0     23.2        No           No  2008     12    3
# 3     18.1     26.5        No           No  2008     12    4
# 4     17.8     29.7        No           No  2008     12    5

# %% [markdown]
# <br>

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>`Encoding of Categorical Features`</b></span>

# %% [markdown]
# Most Machine Learning Algorithms like Logistic Regression, Support Vector Machines, K Nearest Neighbours etc. can't handle categorical data. Hence, these categorical data needs to converted to numerical data for modelling, which is called as `Feature Encoding`.

# %%
categorical_features
# Out:
# ['Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
# Encoding Categorical Features using replace function:

rain['RainToday'].replace({'No':0, 'Yes': 1}, inplace = True)

# pd.get_dummies(rain['RainToday'],drop_first = True)

rain['RainTomorrow'].replace({'No':0, 'Yes': 1}, inplace = True)

# %%
def encode_data(feature_name):
    
    ''' 
    
     function which takes feature name as a parameter and return mapping dictionary to replace(or map) categorical data 
     to numerical data.
     
    '''
    
    mapping_dict = {}
    unique_values = list(rain[feature_name].unique())
    for idx in range(len(unique_values)):
        mapping_dict[unique_values[idx]] = idx
    print(mapping_dict)
    return mapping_dict

# %%
rain['WindGustDir'].replace(encode_data('WindGustDir'),inplace = True)
# Out:
# {'W': 0, 'WNW': 1, 'WSW': 2, 'NE': 3, 'NNW': 4, 'N': 5, 'NNE': 6, 'SW': 7, 'ENE': 8, 'SSE': 9, 'S': 10, 'NW': 11, 'SE': 12, 'ESE': 13, 'E': 14, 'SSW': 15}

# %%
rain['WindDir9am'].replace(encode_data('WindDir9am'),inplace = True)
# Out:
# {'W': 0, 'NNW': 1, 'SE': 2, 'ENE': 3, 'SW': 4, 'SSE': 5, 'S': 6, 'NE': 7, 'N': 8, 'SSW': 9, 'WSW': 10, 'ESE': 11, 'E': 12, 'NW': 13, 'WNW': 14, 'NNE': 15}

# %%
rain['WindDir3pm'].replace(encode_data('WindDir3pm'),inplace = True)
# Out:
# {'WNW': 0, 'WSW': 1, 'E': 2, 'NW': 3, 'W': 4, 'SSE': 5, 'ESE': 6, 'ENE': 7, 'NNW': 8, 'SSW': 9, 'SW': 10, 'SE': 11, 'N': 12, 'S': 13, 'NNE': 14, 'NE': 15}

# %%
rain['Location'].replace(encode_data('Location'), inplace = True)
# Out:
# {'Albury': 0, 'BadgerysCreek': 1, 'Cobar': 2, 'CoffsHarbour': 3, 'Moree': 4, 'Newcastle': 5, 'NorahHead': 6, 'NorfolkIsland': 7, 'Penrith': 8, 'Richmond': 9, 'Sydney': 10, 'SydneyAirport': 11, 'WaggaWagga': 12, 'Williamtown': 13, 'Wollongong': 14, 'Canberra': 15, 'Tuggeranong': 16, 'MountGinini': 17, 'Ballarat': 18, 'Bendigo': 19, 'Sale': 20, 'MelbourneAirport': 21, 'Melbourne': 22, 'Mildura': 23, 'Nhil': 24, 'Portland': 25, 'Watsonia': 26, 'Dartmoor': 27, 'Brisbane': 28, 'Cairns': 29, 'GoldCoast': 30, 'Townsville': 31, 'Adelaide': 32, 'MountGambier': 33, 'Nuriootpa': 34, 'Woomera': 35, 'Albany': 36, 'Witchcliffe': 37, 'PearceRAAF': 38, 'PerthAirport': 39, 'Perth': 40, 'SalmonGums': 41, 'Walpole': 42, 'Hobart': 43, 'Launceston': 44, 'AliceSprings': 45, 'Darwin': 46, 'Katherine': 47, 'Uluru': 48}

# %%
rain.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         0     13.4     22.9       0.6     5.318667  7.611178            0
# 1         0      7.4     25.1       0.0     5.318667  7.611178            1
# 2         0     12.9     25.7       0.0     5.318667  7.611178            2
# 3         0      9.2     28.0       0.0     5.318667  7.611178            3
# 4         0     17.5     32.3       1.0     5.318667  7.611178            0
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0           0           0          20.0          24.0
# 1           44.0           1           1           4.0          22.0
# 2           46.0           0           1          19.0          26.0
# 3           24.0           2           2          11.0           9.0
# 4           41.0           3           3           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000   4.50993
# 1         44.0         25.0       1010.6       1007.8  4.447461   4.50993
# 2         38.0         30.0       1007.6       1008.7  4.447461   2.00000
# 3         45.0         16.0       1017.6       1012.8  4.447461   4.50993
# 4         82.0         33.0       1010.8       1006.0  7.000000   8.00000
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  year  month  day
# 0     16.9     21.8          0             0  2008     12    1
# 1     17.2     24.3          0             0  2008     12    2
# 2     21.0     23.2          0             0  2008     12    3
# 3     18.1     26.5          0             0  2008     12    4
# 4     17.8     29.7          0             0  2008     12    5

# %% [markdown]
# <br>
# <br>
#
# `Spliting data into input features and label`

# %%
X = rain.drop(['RainTomorrow'],axis=1)
y = rain['RainTomorrow']

# %% [markdown]
# <span style='font-size:15px;'>&#10145; <b>`Feature Importance:`</b></span>
#
#     - Machine Learning Model performance depends on features that are used to train a model.
#     - Feature importance describes which features are relevant to build a model.
#     - Feature Importance refers to the techniques that assign a score to input/label features based on how useful they are  at predicting a target variable. Feature importance helps in Feature Selection.

# %%
# finding feature importance using ExtraTreesRegressor:

from sklearn.ensemble import ExtraTreesRegressor
etr_model = ExtraTreesRegressor()
etr_model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
etr_model.feature_importances_
# Out:
# array([0.0348244 , 0.03016307, 0.02903389, 0.0449337 , 0.02346611,
#        0.04337945, 0.0301254 , 0.05724554, 0.03035965, 0.03162871,
#        0.03110846, 0.03236786, 0.0376031 , 0.19844957, 0.03640002,
#        0.04948966, 0.02402266, 0.03572488, 0.02797998, 0.02829194,
#        0.04992722, 0.03071129, 0.03032593, 0.03243752])

# %%
# visualizing feature importance using bar graph:

feature_imp = pd.Series(etr_model.feature_importances_,index=X.columns)
feature_imp.nlargest(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
feature_imp
# Out:
# Location         0.034824
# MinTemp          0.030163
# MaxTemp          0.029034
# Rainfall         0.044934
# Evaporation      0.023466
# Sunshine         0.043379
# WindGustDir      0.030125
# WindGustSpeed    0.057246
# WindDir9am       0.030360
# WindDir3pm       0.031629
# WindSpeed9am     0.031108
# WindSpeed3pm     0.032368
# Humidity9am      0.037603
# Humidity3pm      0.198450
# Pressure9am      0.036400
# Pressure3pm      0.049490
# Cloud9am         0.024023
# Cloud3pm         0.035725
# Temp9am          0.027980
# Temp3pm          0.028292
# RainToday        0.049927
# year             0.030711
# month            0.030326
# day              0.032438
# dtype: float64

# %% [markdown]
# ## `5) Split Data into Training and Testing Set`  <a class="anchor" id=""></a>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)

# %%
print("Length of Training Data: {}".format(len(X_train)))
print("Length of Testing Data: {}".format(len(X_test)))
# Out:
# Length of Training Data: 116368
# Length of Testing Data: 29092

# %% [markdown]
# ## `6) Feature Scaling`  <a class="anchor" id=""></a>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# `Save the Scaler object to Standardize Real Time Data feeded by users for prediction`

# %%
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# %% [markdown]
# ## `7) Model Building`  <a class="anchor" id=""></a>
#     - Model Training
#     - Model Testing
#     - Evaluating Model Performance using Accuracy, Confusion Matrix, Classification Report, RUC-AUC curve
#     - Finding whether model performance can be improved using Cross Validation Score

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# <span style='font-size:15px;'><b>`(i) Logistic Regression`</b></span>

# %% [markdown]
# `Model Training:`

# %%
from sklearn.linear_model import LogisticRegression

# %%
start_time = time.time()
classifier_logreg = LogisticRegression(solver='liblinear', random_state=0)
classifier_logreg.fit(X_train, y_train)
end_time = time.time()

# %%
print("Time Taken to train: {}".format(end_time - start_time))
# Out:
# Time Taken to train: 2.1360485553741455

# %% [markdown]
# `Model Testing:`

# %%
y_pred = classifier_logreg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print("Accuracy Score: {}".format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy Score: 0.8444933315000688

# %% [markdown]
# `Checking for Overfitting and Under Fitting:`

# %%
print("Train Data Score: {}".format(classifier_logreg.score(X_train, y_train)))
print("Test Data Score: {}".format(classifier_logreg.score(X_test, y_test)))
# Out:
# Train Data Score: 0.8437714835693662
# Test Data Score: 0.8444933315000688

# %% [markdown]
# _`Accuracy Score of Training and Testing Data is comparable and almost equal. So, there is no question of Underfitting and Over Fitting. And model is generalizing well for new unseen data.`_

# %%
# confusion Matrix:

print("Confusion Matrix:")
print("\n",confusion_matrix(y_test,y_pred))
# Out:
# Confusion Matrix:
#
#  [[21536  1190]
#  [ 3334  3032]]

# %%
# Classification Report:

print("classification_report:")
print("\n",classification_report(y_test,y_pred))
# Out:
# classification_report:
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.90     22726
#            1       0.72      0.48      0.57      6366
#
#     accuracy                           0.84     29092
#    macro avg       0.79      0.71      0.74     29092
# weighted avg       0.83      0.84      0.83     29092

# %%
# predicting probabilities:

y_pred_logreg_proba = classifier_logreg.predict_proba(X_test)

# %%
# Finding True Positive Rate(tpr), False Positive Rate(fpr), threshold values to plot ROC curve

from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_logreg_proba[:,1])

# %%
# Plotting ROC curve:

plt.figure(figsize=(6,4))
plt.plot(fpr,tpr,'-g',linewidth=1)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve for Logistic Regression Model')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()

# %%
# finding ROC-AUC score:

from sklearn.metrics import roc_auc_score
print('ROC AUC Scores: {}'.format(roc_auc_score(y_test, y_pred)))
# Out:
# ROC AUC Scores: 0.7119586532221237

# %% [markdown]
# <br>

# %% [markdown]
# `Finding whether model performance can be improved using Cross Validation Score:`

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(classifier_logreg, X_train, y_train, cv = 5, scoring='accuracy')
print('Cross-validation scores:{}'.format(scores))
# Out:
# Cross-validation scores:[0.84338747 0.84235628 0.84691072 0.84067374 0.84359558]

# %%
print('Average cross-validation score: {}'.format(scores.mean()))
# Out:
# Average cross-validation score: 0.8433847578355673

# %% [markdown]
# _`The mean accuracy score of cross validation is almost same like original model accuracy score which is 0.8445. So, accuracy of model may not be improved using Cross-validation.`_

# %% [markdown]
# <hr style="height:1px">

# %% [markdown]
# <span style='font-size:15px;'><b>`(ii) Cat Boost`</b></span>

# %%
from catboost import CatBoostClassifier

# %% [markdown]
# `Model Training:`

# %%
start_time = time.time()
cat_classifier = CatBoostClassifier(iterations=2000, eval_metric = "AUC")
cat_classifier.fit(X_train, y_train)
end_time = time.time()
# Out:
# Learning rate set to 0.041591
# 0:	total: 257ms	remaining: 8m 33s
# 1:	total: 481ms	remaining: 8m
# 2:	total: 623ms	remaining: 6m 55s
# 3:	total: 737ms	remaining: 6m 7s
# 4:	total: 875ms	remaining: 5m 48s
# 5:	total: 1.02s	remaining: 5m 38s
# 6:	total: 1.17s	remaining: 5m 32s
# 7:	total: 1.3s	remaining: 5m 23s
# 8:	total: 1.43s	remaining: 5m 16s
# 9:	total: 1.54s	remaining: 5m 7s
# 10:	total: 1.66s	remaining: 5m
# 11:	total: 1.73s	remaining: 4m 47s
# 12:	total: 1.84s	remaining: 4m 41s
# 13:	total: 1.92s	remaining: 4m 32s
# 14:	total: 2.01s	remaining: 4m 25s
# 15:	total: 2.11s	remaining: 4m 21s
# 16:	total: 2.18s	remaining: 4m 14s
# 17:	total: 2.25s	remaining: 4m 8s
# 18:	total: 2.35s	remaining: 4m 4s
# 19:	total: 2.41s	remaining: 3m 58s
# 20:	total: 2.49s	remaining: 3m 54s
# 21:	total: 2.58s	remaining: 3m 52s
# 22:	total: 2.64s	remaining: 3m 46s
# 23:	total: 2.7s	remaining: 3m 42s
# 24:	total: 2.76s	remaining: 3m 38s
# 25:	total: 2.84s	remaining: 3m 35s
# 26:	total: 2.9s	remaining: 3m 32s
# 27:	total: 2.97s	remaining: 3m 29s
# 28:	total: 3.05s	remaining: 3m 27s
# 29:	total: 3.11s	remaining: 3m 24s
# 30:	total: 3.17s	remaining: 3m 21s
# 31:	total: 3.24s	remaining: 3m 19s
# 32:	total: 3.31s	remaining: 3m 17s
# 33:	total: 3.36s	remaining: 3m 14s
# 34:	total: 3.42s	remaining: 3m 12s
# 35:	total: 3.47s	remaining: 3m 9s
# 36:	total: 3.52s	remaining: 3m 6s
# 37:	total: 3.56s	remaining: 3m 4s
# 38:	total: 3.63s	remaining: 3m 2s
# 39:	total: 3.68s	remaining: 3m
# 40:	total: 3.73s	remaining: 2m 58s
# 41:	total: 3.79s	remaining: 2m 56s
# 42:	total: 3.84s	remaining: 2m 54s
# 43:	total: 3.89s	remaining: 2m 52s
# 44:	total: 3.93s	remaining: 2m 50s
# 45:	total: 3.98s	remaining: 2m 49s
# 46:	total: 4.04s	remaining: 2m 47s
# 47:	total: 4.08s	remaining: 2m 46s
# 48:	total: 4.13s	remaining: 2m 44s
# 49:	total: 4.18s	remaining: 2m 43s
# 50:	total: 4.23s	remaining: 2m 41s
# 51:	total: 4.28s	remaining: 2m 40s
# 52:	total: 4.33s	remaining: 2m 39s
# 53:	total: 4.38s	remaining: 2m 37s
# 54:	total: 4.43s	remaining: 2m 36s
# 55:	total: 4.47s	remaining: 2m 35s
# 56:	total: 4.51s	remaining: 2m 33s
# 57:	total: 4.55s	remaining: 2m 32s
# 58:	total: 4.6s	remaining: 2m 31s
# 59:	total: 4.65s	remaining: 2m 30s
# 60:	total: 4.69s	remaining: 2m 29s
# 61:	total: 4.74s	remaining: 2m 28s
# 62:	total: 4.78s	remaining: 2m 27s
# 63:	total: 4.83s	remaining: 2m 26s
# 64:	total: 4.87s	remaining: 2m 24s
# 65:	total: 4.9s	remaining: 2m 23s
# 66:	total: 4.94s	remaining: 2m 22s
# 67:	total: 4.98s	remaining: 2m 21s
# 68:	total: 5.04s	remaining: 2m 21s
# 69:	total: 5.08s	remaining: 2m 20s
# 70:	total: 5.12s	remaining: 2m 19s
# 71:	total: 5.17s	remaining: 2m 18s
# 72:	total: 5.22s	remaining: 2m 17s
# 73:	total: 5.25s	remaining: 2m 16s
# 74:	total: 5.29s	remaining: 2m 15s
# 75:	total: 5.33s	remaining: 2m 15s
# 76:	total: 5.38s	remaining: 2m 14s
# 77:	total: 5.44s	remaining: 2m 13s
# 78:	total: 5.48s	remaining: 2m 13s
# 79:	total: 5.52s	remaining: 2m 12s
# 80:	total: 5.56s	remaining: 2m 11s
# 81:	total: 5.61s	remaining: 2m 11s
# 82:	total: 5.65s	remaining: 2m 10s
# 83:	total: 5.7s	remaining: 2m 9s
# 84:	total: 5.75s	remaining: 2m 9s
# 85:	total: 5.79s	remaining: 2m 8s
# 86:	total: 5.83s	remaining: 2m 8s
# 87:	total: 5.87s	remaining: 2m 7s
# 88:	total: 5.92s	remaining: 2m 7s
# 89:	total: 5.96s	remaining: 2m 6s
# 90:	total: 6.01s	remaining: 2m 6s
# 91:	total: 6.05s	remaining: 2m 5s
# 92:	total: 6.09s	remaining: 2m 4s
# 93:	total: 6.13s	remaining: 2m 4s
# 94:	total: 6.17s	remaining: 2m 3s
# 95:	total: 6.21s	remaining: 2m 3s
# 96:	total: 6.25s	remaining: 2m 2s
# 97:	total: 6.31s	remaining: 2m 2s
# 98:	total: 6.35s	remaining: 2m 1s
# 99:	total: 6.39s	remaining: 2m 1s
# 100:	total: 6.43s	remaining: 2m
# 101:	total: 6.47s	remaining: 2m
# 102:	total: 6.52s	remaining: 2m
# 103:	total: 6.57s	remaining: 1m 59s
# 104:	total: 6.61s	remaining: 1m 59s
# 105:	total: 6.64s	remaining: 1m 58s
# 106:	total: 6.68s	remaining: 1m 58s
# 107:	total: 6.73s	remaining: 1m 57s
# 108:	total: 6.78s	remaining: 1m 57s
# 109:	total: 6.82s	remaining: 1m 57s
# 110:	total: 6.86s	remaining: 1m 56s
# 111:	total: 6.91s	remaining: 1m 56s
# 112:	total: 6.96s	remaining: 1m 56s
# 113:	total: 7s	remaining: 1m 55s
# 114:	total: 7.04s	remaining: 1m 55s
# 115:	total: 7.08s	remaining: 1m 54s
# 116:	total: 7.12s	remaining: 1m 54s
# 117:	total: 7.17s	remaining: 1m 54s
# 118:	total: 7.21s	remaining: 1m 53s
# 119:	total: 7.25s	remaining: 1m 53s
# 120:	total: 7.29s	remaining: 1m 53s
# 121:	total: 7.33s	remaining: 1m 52s
# 122:	total: 7.38s	remaining: 1m 52s
# 123:	total: 7.42s	remaining: 1m 52s
# 124:	total: 7.45s	remaining: 1m 51s
# 125:	total: 7.5s	remaining: 1m 51s
# 126:	total: 7.54s	remaining: 1m 51s
# 127:	total: 7.59s	remaining: 1m 51s
# 128:	total: 7.63s	remaining: 1m 50s
# 129:	total: 7.67s	remaining: 1m 50s
# 130:	total: 7.71s	remaining: 1m 49s
# 131:	total: 7.75s	remaining: 1m 49s
# 132:	total: 7.8s	remaining: 1m 49s
# 133:	total: 7.84s	remaining: 1m 49s
# 134:	total: 7.88s	remaining: 1m 48s
# 135:	total: 7.92s	remaining: 1m 48s
# 136:	total: 7.97s	remaining: 1m 48s
# 137:	total: 8.02s	remaining: 1m 48s
# 138:	total: 8.06s	remaining: 1m 47s
# 139:	total: 8.11s	remaining: 1m 47s
# 140:	total: 8.15s	remaining: 1m 47s
# 141:	total: 8.19s	remaining: 1m 47s
# 142:	total: 8.24s	remaining: 1m 47s
# 143:	total: 8.28s	remaining: 1m 46s
# 144:	total: 8.32s	remaining: 1m 46s
# 145:	total: 8.36s	remaining: 1m 46s
# 146:	total: 8.4s	remaining: 1m 45s
# 147:	total: 8.45s	remaining: 1m 45s
# 148:	total: 8.5s	remaining: 1m 45s
# 149:	total: 8.54s	remaining: 1m 45s
# 150:	total: 8.57s	remaining: 1m 44s
# 151:	total: 8.62s	remaining: 1m 44s
# 152:	total: 8.66s	remaining: 1m 44s
# 153:	total: 8.71s	remaining: 1m 44s
# 154:	total: 8.75s	remaining: 1m 44s
# 155:	total: 8.79s	remaining: 1m 43s
# 156:	total: 8.83s	remaining: 1m 43s
# 157:	total: 8.88s	remaining: 1m 43s
# 158:	total: 8.92s	remaining: 1m 43s
# 159:	total: 8.96s	remaining: 1m 43s
# 160:	total: 9s	remaining: 1m 42s
# 161:	total: 9.05s	remaining: 1m 42s
# 162:	total: 9.09s	remaining: 1m 42s
# 163:	total: 9.13s	remaining: 1m 42s
# 164:	total: 9.17s	remaining: 1m 42s
# 165:	total: 9.21s	remaining: 1m 41s
# 166:	total: 9.27s	remaining: 1m 41s
# 167:	total: 9.31s	remaining: 1m 41s
# 168:	total: 9.35s	remaining: 1m 41s
# 169:	total: 9.39s	remaining: 1m 41s
# 170:	total: 9.43s	remaining: 1m 40s
# 171:	total: 9.48s	remaining: 1m 40s
# 172:	total: 9.52s	remaining: 1m 40s
# 173:	total: 9.56s	remaining: 1m 40s
# 174:	total: 9.6s	remaining: 1m 40s
# 175:	total: 9.65s	remaining: 1m 40s
# 176:	total: 9.7s	remaining: 1m 39s
# 177:	total: 9.74s	remaining: 1m 39s
# 178:	total: 9.78s	remaining: 1m 39s
# 179:	total: 9.83s	remaining: 1m 39s
# 180:	total: 9.87s	remaining: 1m 39s
# 181:	total: 9.91s	remaining: 1m 39s
# 182:	total: 9.96s	remaining: 1m 38s
# 183:	total: 10s	remaining: 1m 38s
# 184:	total: 10s	remaining: 1m 38s
# 185:	total: 10.1s	remaining: 1m 38s
# 186:	total: 10.1s	remaining: 1m 38s
# 187:	total: 10.2s	remaining: 1m 38s
# 188:	total: 10.2s	remaining: 1m 37s
# 189:	total: 10.3s	remaining: 1m 37s
# 190:	total: 10.3s	remaining: 1m 37s
# 191:	total: 10.4s	remaining: 1m 37s
# 192:	total: 10.4s	remaining: 1m 37s
# 193:	total: 10.4s	remaining: 1m 37s
# 194:	total: 10.5s	remaining: 1m 36s
# 195:	total: 10.5s	remaining: 1m 36s
# 196:	total: 10.6s	remaining: 1m 36s
# 197:	total: 10.6s	remaining: 1m 36s
# 198:	total: 10.6s	remaining: 1m 36s
# 199:	total: 10.7s	remaining: 1m 36s
# 200:	total: 10.7s	remaining: 1m 36s
# 201:	total: 10.8s	remaining: 1m 35s
# 202:	total: 10.8s	remaining: 1m 35s
# 203:	total: 10.9s	remaining: 1m 35s
# 204:	total: 10.9s	remaining: 1m 35s
# 205:	total: 10.9s	remaining: 1m 35s
# 206:	total: 11s	remaining: 1m 35s
# 207:	total: 11s	remaining: 1m 35s
# 208:	total: 11.1s	remaining: 1m 34s
# 209:	total: 11.1s	remaining: 1m 34s
# 210:	total: 11.2s	remaining: 1m 34s
# 211:	total: 11.2s	remaining: 1m 34s
# 212:	total: 11.2s	remaining: 1m 34s
# 213:	total: 11.3s	remaining: 1m 34s
# 214:	total: 11.3s	remaining: 1m 34s
# 215:	total: 11.4s	remaining: 1m 33s
# 216:	total: 11.4s	remaining: 1m 33s
# 217:	total: 11.5s	remaining: 1m 33s
# 218:	total: 11.5s	remaining: 1m 33s
# 219:	total: 11.6s	remaining: 1m 33s
# 220:	total: 11.6s	remaining: 1m 33s
# 221:	total: 11.6s	remaining: 1m 33s
# 222:	total: 11.7s	remaining: 1m 33s
# 223:	total: 11.7s	remaining: 1m 32s
# 224:	total: 11.8s	remaining: 1m 32s
# 225:	total: 11.8s	remaining: 1m 32s
# 226:	total: 11.9s	remaining: 1m 32s
# 227:	total: 11.9s	remaining: 1m 32s
# 228:	total: 11.9s	remaining: 1m 32s
# 229:	total: 12s	remaining: 1m 32s
# 230:	total: 12s	remaining: 1m 32s
# 231:	total: 12.1s	remaining: 1m 31s
# 232:	total: 12.1s	remaining: 1m 31s
# 233:	total: 12.1s	remaining: 1m 31s
# 234:	total: 12.2s	remaining: 1m 31s
# 235:	total: 12.2s	remaining: 1m 31s
# 236:	total: 12.3s	remaining: 1m 31s
# 237:	total: 12.3s	remaining: 1m 31s
# 238:	total: 12.4s	remaining: 1m 31s
# 239:	total: 12.4s	remaining: 1m 31s
# 240:	total: 12.4s	remaining: 1m 30s
# 241:	total: 12.5s	remaining: 1m 30s
# 242:	total: 12.5s	remaining: 1m 30s
# 243:	total: 12.6s	remaining: 1m 30s
# 244:	total: 12.6s	remaining: 1m 30s
# 245:	total: 12.7s	remaining: 1m 30s
# 246:	total: 12.7s	remaining: 1m 30s
# 247:	total: 12.7s	remaining: 1m 29s
# 248:	total: 12.8s	remaining: 1m 29s
# 249:	total: 12.8s	remaining: 1m 29s
# 250:	total: 12.9s	remaining: 1m 29s
# 251:	total: 12.9s	remaining: 1m 29s
# 252:	total: 12.9s	remaining: 1m 29s
# 253:	total: 13s	remaining: 1m 29s
# 254:	total: 13s	remaining: 1m 29s
# 255:	total: 13.1s	remaining: 1m 29s
# 256:	total: 13.1s	remaining: 1m 28s
# 257:	total: 13.2s	remaining: 1m 28s
# 258:	total: 13.2s	remaining: 1m 28s
# 259:	total: 13.2s	remaining: 1m 28s
# 260:	total: 13.3s	remaining: 1m 28s
# 261:	total: 13.3s	remaining: 1m 28s
# 262:	total: 13.4s	remaining: 1m 28s
# 263:	total: 13.4s	remaining: 1m 28s
# 264:	total: 13.5s	remaining: 1m 28s
# 265:	total: 13.5s	remaining: 1m 28s
# 266:	total: 13.5s	remaining: 1m 27s
# 267:	total: 13.6s	remaining: 1m 27s
# 268:	total: 13.6s	remaining: 1m 27s
# 269:	total: 13.7s	remaining: 1m 27s
# 270:	total: 13.7s	remaining: 1m 27s
# 271:	total: 13.7s	remaining: 1m 27s
# 272:	total: 13.8s	remaining: 1m 27s
# 273:	total: 13.8s	remaining: 1m 27s
# 274:	total: 13.9s	remaining: 1m 27s
# 275:	total: 13.9s	remaining: 1m 26s
# 276:	total: 14s	remaining: 1m 26s
# 277:	total: 14s	remaining: 1m 26s
# 278:	total: 14.1s	remaining: 1m 26s
# 279:	total: 14.1s	remaining: 1m 26s
# 280:	total: 14.1s	remaining: 1m 26s
# 281:	total: 14.2s	remaining: 1m 26s
# 282:	total: 14.2s	remaining: 1m 26s
# 283:	total: 14.3s	remaining: 1m 26s
# 284:	total: 14.3s	remaining: 1m 26s
# 285:	total: 14.4s	remaining: 1m 26s
# 286:	total: 14.4s	remaining: 1m 25s
# 287:	total: 14.4s	remaining: 1m 25s
# 288:	total: 14.5s	remaining: 1m 25s
# 289:	total: 14.5s	remaining: 1m 25s
# 290:	total: 14.6s	remaining: 1m 25s
# 291:	total: 14.6s	remaining: 1m 25s
# 292:	total: 14.6s	remaining: 1m 25s
# 293:	total: 14.7s	remaining: 1m 25s
# 294:	total: 14.7s	remaining: 1m 25s
# 295:	total: 14.8s	remaining: 1m 25s
# 296:	total: 14.8s	remaining: 1m 24s
# 297:	total: 14.9s	remaining: 1m 24s
# 298:	total: 14.9s	remaining: 1m 24s
# 299:	total: 14.9s	remaining: 1m 24s
# 300:	total: 15s	remaining: 1m 24s
# 301:	total: 15s	remaining: 1m 24s
# 302:	total: 15.1s	remaining: 1m 24s
# 303:	total: 15.1s	remaining: 1m 24s
# 304:	total: 15.2s	remaining: 1m 24s
# 305:	total: 15.2s	remaining: 1m 24s
# 306:	total: 15.2s	remaining: 1m 24s
# 307:	total: 15.3s	remaining: 1m 23s
# 308:	total: 15.3s	remaining: 1m 23s
# 309:	total: 15.4s	remaining: 1m 23s
# 310:	total: 15.4s	remaining: 1m 23s
# 311:	total: 15.5s	remaining: 1m 23s
# 312:	total: 15.5s	remaining: 1m 23s
# 313:	total: 15.6s	remaining: 1m 23s
# 314:	total: 15.6s	remaining: 1m 23s
# 315:	total: 15.6s	remaining: 1m 23s
# 316:	total: 15.7s	remaining: 1m 23s
# 317:	total: 15.7s	remaining: 1m 23s
# 318:	total: 15.8s	remaining: 1m 23s
# 319:	total: 15.8s	remaining: 1m 23s
# 320:	total: 15.9s	remaining: 1m 22s
# 321:	total: 15.9s	remaining: 1m 22s
# 322:	total: 15.9s	remaining: 1m 22s
# 323:	total: 16s	remaining: 1m 22s
# 324:	total: 16s	remaining: 1m 22s
# 325:	total: 16.1s	remaining: 1m 22s
# 326:	total: 16.1s	remaining: 1m 22s
# 327:	total: 16.2s	remaining: 1m 22s
# 328:	total: 16.2s	remaining: 1m 22s
# 329:	total: 16.3s	remaining: 1m 22s
# 330:	total: 16.3s	remaining: 1m 22s
# 331:	total: 16.3s	remaining: 1m 22s
# 332:	total: 16.4s	remaining: 1m 21s
# 333:	total: 16.4s	remaining: 1m 21s
# 334:	total: 16.5s	remaining: 1m 21s
# 335:	total: 16.5s	remaining: 1m 21s
# 336:	total: 16.5s	remaining: 1m 21s
# 337:	total: 16.6s	remaining: 1m 21s
# 338:	total: 16.6s	remaining: 1m 21s
# 339:	total: 16.7s	remaining: 1m 21s
# 340:	total: 16.7s	remaining: 1m 21s
# 341:	total: 16.8s	remaining: 1m 21s
# 342:	total: 16.8s	remaining: 1m 21s
# 343:	total: 16.8s	remaining: 1m 21s
# 344:	total: 16.9s	remaining: 1m 21s
# 345:	total: 16.9s	remaining: 1m 20s
# 346:	total: 17s	remaining: 1m 20s
# 347:	total: 17s	remaining: 1m 20s
# 348:	total: 17.1s	remaining: 1m 20s
# 349:	total: 17.1s	remaining: 1m 20s
# 350:	total: 17.1s	remaining: 1m 20s
# 351:	total: 17.2s	remaining: 1m 20s
# 352:	total: 17.2s	remaining: 1m 20s
# 353:	total: 17.3s	remaining: 1m 20s
# 354:	total: 17.3s	remaining: 1m 20s
# 355:	total: 17.3s	remaining: 1m 20s
# 356:	total: 17.4s	remaining: 1m 20s
# 357:	total: 17.4s	remaining: 1m 19s
# 358:	total: 17.5s	remaining: 1m 19s
# 359:	total: 17.5s	remaining: 1m 19s
# 360:	total: 17.6s	remaining: 1m 19s
# 361:	total: 17.6s	remaining: 1m 19s
# 362:	total: 17.7s	remaining: 1m 19s
# 363:	total: 17.7s	remaining: 1m 19s
# 364:	total: 17.8s	remaining: 1m 19s
# 365:	total: 17.8s	remaining: 1m 19s
# 366:	total: 17.8s	remaining: 1m 19s
# 367:	total: 17.9s	remaining: 1m 19s
# 368:	total: 17.9s	remaining: 1m 19s
# 369:	total: 18s	remaining: 1m 19s
# 370:	total: 18s	remaining: 1m 19s
# 371:	total: 18.1s	remaining: 1m 19s
# 372:	total: 18.1s	remaining: 1m 18s
# 373:	total: 18.1s	remaining: 1m 18s
# 374:	total: 18.2s	remaining: 1m 18s
# 375:	total: 18.2s	remaining: 1m 18s
# 376:	total: 18.3s	remaining: 1m 18s
# 377:	total: 18.3s	remaining: 1m 18s
# 378:	total: 18.3s	remaining: 1m 18s
# 379:	total: 18.4s	remaining: 1m 18s
# 380:	total: 18.4s	remaining: 1m 18s
# 381:	total: 18.5s	remaining: 1m 18s
# 382:	total: 18.5s	remaining: 1m 18s
# 383:	total: 18.6s	remaining: 1m 18s
# 384:	total: 18.6s	remaining: 1m 18s
# 385:	total: 18.7s	remaining: 1m 17s
# 386:	total: 18.7s	remaining: 1m 17s
# 387:	total: 18.7s	remaining: 1m 17s
# 388:	total: 18.8s	remaining: 1m 17s
# 389:	total: 18.8s	remaining: 1m 17s
# 390:	total: 18.9s	remaining: 1m 17s
# 391:	total: 18.9s	remaining: 1m 17s
# 392:	total: 19s	remaining: 1m 17s
# 393:	total: 19s	remaining: 1m 17s
# 394:	total: 19.1s	remaining: 1m 17s
# 395:	total: 19.1s	remaining: 1m 17s
# 396:	total: 19.1s	remaining: 1m 17s
# 397:	total: 19.2s	remaining: 1m 17s
# 398:	total: 19.2s	remaining: 1m 17s
# 399:	total: 19.3s	remaining: 1m 17s
# 400:	total: 19.3s	remaining: 1m 17s
# 401:	total: 19.4s	remaining: 1m 16s
# 402:	total: 19.4s	remaining: 1m 16s
# 403:	total: 19.4s	remaining: 1m 16s
# 404:	total: 19.5s	remaining: 1m 16s
# 405:	total: 19.5s	remaining: 1m 16s
# 406:	total: 19.6s	remaining: 1m 16s
# 407:	total: 19.6s	remaining: 1m 16s
# 408:	total: 19.8s	remaining: 1m 16s
# 409:	total: 19.8s	remaining: 1m 16s
# 410:	total: 19.9s	remaining: 1m 16s
# 411:	total: 19.9s	remaining: 1m 16s
# 412:	total: 20s	remaining: 1m 16s
# 413:	total: 20s	remaining: 1m 16s
# 414:	total: 20s	remaining: 1m 16s
# 415:	total: 20.1s	remaining: 1m 16s
# 416:	total: 20.1s	remaining: 1m 16s
# 417:	total: 20.2s	remaining: 1m 16s
# 418:	total: 20.2s	remaining: 1m 16s
# 419:	total: 20.3s	remaining: 1m 16s
# 420:	total: 20.3s	remaining: 1m 16s
# 421:	total: 20.4s	remaining: 1m 16s
# 422:	total: 20.4s	remaining: 1m 16s
# 423:	total: 20.4s	remaining: 1m 15s
# 424:	total: 20.5s	remaining: 1m 15s
# 425:	total: 20.5s	remaining: 1m 15s
# 426:	total: 20.6s	remaining: 1m 15s
# 427:	total: 20.6s	remaining: 1m 15s
# 428:	total: 20.7s	remaining: 1m 15s
# 429:	total: 20.7s	remaining: 1m 15s
# 430:	total: 20.8s	remaining: 1m 15s
# 431:	total: 20.8s	remaining: 1m 15s
# 432:	total: 20.8s	remaining: 1m 15s
# 433:	total: 20.9s	remaining: 1m 15s
# 434:	total: 20.9s	remaining: 1m 15s
# 435:	total: 21s	remaining: 1m 15s
# 436:	total: 21s	remaining: 1m 15s
# 437:	total: 21.1s	remaining: 1m 15s
# 438:	total: 21.1s	remaining: 1m 15s
# 439:	total: 21.2s	remaining: 1m 15s
# 440:	total: 21.2s	remaining: 1m 14s
# 441:	total: 21.2s	remaining: 1m 14s
# 442:	total: 21.3s	remaining: 1m 14s
# 443:	total: 21.3s	remaining: 1m 14s
# 444:	total: 21.4s	remaining: 1m 14s
# 445:	total: 21.4s	remaining: 1m 14s
# 446:	total: 21.5s	remaining: 1m 14s
# 447:	total: 21.5s	remaining: 1m 14s
# 448:	total: 21.5s	remaining: 1m 14s
# 449:	total: 21.6s	remaining: 1m 14s
# 450:	total: 21.6s	remaining: 1m 14s
# 451:	total: 21.7s	remaining: 1m 14s
# 452:	total: 21.7s	remaining: 1m 14s
# 453:	total: 21.8s	remaining: 1m 14s
# 454:	total: 21.8s	remaining: 1m 14s
# 455:	total: 21.9s	remaining: 1m 14s
# 456:	total: 21.9s	remaining: 1m 13s
# 457:	total: 22s	remaining: 1m 13s
# 458:	total: 22s	remaining: 1m 13s
# 459:	total: 22s	remaining: 1m 13s
# 460:	total: 22.1s	remaining: 1m 13s
# 461:	total: 22.1s	remaining: 1m 13s
# 462:	total: 22.2s	remaining: 1m 13s
# 463:	total: 22.2s	remaining: 1m 13s
# 464:	total: 22.3s	remaining: 1m 13s
# 465:	total: 22.3s	remaining: 1m 13s
# 466:	total: 22.3s	remaining: 1m 13s
# 467:	total: 22.4s	remaining: 1m 13s
# 468:	total: 22.4s	remaining: 1m 13s
# 469:	total: 22.5s	remaining: 1m 13s
# 470:	total: 22.5s	remaining: 1m 13s
# 471:	total: 22.6s	remaining: 1m 13s
# 472:	total: 22.7s	remaining: 1m 13s
# 473:	total: 22.8s	remaining: 1m 13s
# 474:	total: 22.9s	remaining: 1m 13s
# 475:	total: 23.1s	remaining: 1m 13s
# 476:	total: 23.2s	remaining: 1m 14s
# 477:	total: 23.4s	remaining: 1m 14s
# 478:	total: 23.5s	remaining: 1m 14s
# 479:	total: 23.6s	remaining: 1m 14s
# 480:	total: 23.7s	remaining: 1m 14s
# 481:	total: 23.8s	remaining: 1m 14s
# 482:	total: 23.9s	remaining: 1m 14s
# 483:	total: 24s	remaining: 1m 15s
# 484:	total: 24.1s	remaining: 1m 15s
# 485:	total: 24.2s	remaining: 1m 15s
# 486:	total: 24.3s	remaining: 1m 15s
# 487:	total: 24.3s	remaining: 1m 15s
# 488:	total: 24.4s	remaining: 1m 15s
# 489:	total: 24.5s	remaining: 1m 15s
# 490:	total: 24.6s	remaining: 1m 15s
# 491:	total: 24.7s	remaining: 1m 15s
# 492:	total: 24.8s	remaining: 1m 15s
# 493:	total: 24.8s	remaining: 1m 15s
# 494:	total: 24.9s	remaining: 1m 15s
# 495:	total: 25s	remaining: 1m 15s
# 496:	total: 25.1s	remaining: 1m 15s
# 497:	total: 25.1s	remaining: 1m 15s
# 498:	total: 25.2s	remaining: 1m 15s
# 499:	total: 25.3s	remaining: 1m 15s
# 500:	total: 25.3s	remaining: 1m 15s
# 501:	total: 25.4s	remaining: 1m 15s
# 502:	total: 25.5s	remaining: 1m 15s
# 503:	total: 25.5s	remaining: 1m 15s
# 504:	total: 25.6s	remaining: 1m 15s
# 505:	total: 25.6s	remaining: 1m 15s
# 506:	total: 25.7s	remaining: 1m 15s
# 507:	total: 25.8s	remaining: 1m 15s
# 508:	total: 25.8s	remaining: 1m 15s
# 509:	total: 25.9s	remaining: 1m 15s
# 510:	total: 25.9s	remaining: 1m 15s
# 511:	total: 26s	remaining: 1m 15s
# 512:	total: 26s	remaining: 1m 15s
# 513:	total: 26.1s	remaining: 1m 15s
# 514:	total: 26.1s	remaining: 1m 15s
# 515:	total: 26.2s	remaining: 1m 15s
# 516:	total: 26.2s	remaining: 1m 15s
# 517:	total: 26.3s	remaining: 1m 15s
# 518:	total: 26.3s	remaining: 1m 15s
# 519:	total: 26.4s	remaining: 1m 15s
# 520:	total: 26.5s	remaining: 1m 15s
# 521:	total: 26.5s	remaining: 1m 15s
# 522:	total: 26.5s	remaining: 1m 14s
# 523:	total: 26.6s	remaining: 1m 15s
# 524:	total: 26.7s	remaining: 1m 14s
# 525:	total: 26.7s	remaining: 1m 14s
# 526:	total: 26.8s	remaining: 1m 14s
# 527:	total: 26.8s	remaining: 1m 14s
# 528:	total: 26.9s	remaining: 1m 14s
# 529:	total: 26.9s	remaining: 1m 14s
# 530:	total: 27s	remaining: 1m 14s
# 531:	total: 27s	remaining: 1m 14s
# 532:	total: 27.1s	remaining: 1m 14s
# 533:	total: 27.1s	remaining: 1m 14s
# 534:	total: 27.1s	remaining: 1m 14s
# 535:	total: 27.2s	remaining: 1m 14s
# 536:	total: 27.2s	remaining: 1m 14s
# 537:	total: 27.3s	remaining: 1m 14s
# 538:	total: 27.3s	remaining: 1m 14s
# 539:	total: 27.4s	remaining: 1m 13s
# 540:	total: 27.4s	remaining: 1m 13s
# 541:	total: 27.4s	remaining: 1m 13s
# 542:	total: 27.5s	remaining: 1m 13s
# 543:	total: 27.5s	remaining: 1m 13s
# 544:	total: 27.6s	remaining: 1m 13s
# 545:	total: 27.6s	remaining: 1m 13s
# 546:	total: 27.7s	remaining: 1m 13s
# 547:	total: 27.7s	remaining: 1m 13s
# 548:	total: 27.8s	remaining: 1m 13s
# 549:	total: 27.8s	remaining: 1m 13s
# 550:	total: 27.8s	remaining: 1m 13s
# 551:	total: 27.9s	remaining: 1m 13s
# 552:	total: 27.9s	remaining: 1m 13s
# 553:	total: 28s	remaining: 1m 13s
# 554:	total: 28s	remaining: 1m 12s
# 555:	total: 28.1s	remaining: 1m 12s
# 556:	total: 28.1s	remaining: 1m 12s
# 557:	total: 28.1s	remaining: 1m 12s
# 558:	total: 28.2s	remaining: 1m 12s
# 559:	total: 28.2s	remaining: 1m 12s
# 560:	total: 28.3s	remaining: 1m 12s
# 561:	total: 28.3s	remaining: 1m 12s
# 562:	total: 28.4s	remaining: 1m 12s
# 563:	total: 28.4s	remaining: 1m 12s
# 564:	total: 28.5s	remaining: 1m 12s
# 565:	total: 28.5s	remaining: 1m 12s
# 566:	total: 28.5s	remaining: 1m 12s
# 567:	total: 28.6s	remaining: 1m 12s
# 568:	total: 28.6s	remaining: 1m 12s
# 569:	total: 28.7s	remaining: 1m 11s
# 570:	total: 28.7s	remaining: 1m 11s
# 571:	total: 28.8s	remaining: 1m 11s
# 572:	total: 28.8s	remaining: 1m 11s
# 573:	total: 28.8s	remaining: 1m 11s
# 574:	total: 28.9s	remaining: 1m 11s
# 575:	total: 28.9s	remaining: 1m 11s
# 576:	total: 29s	remaining: 1m 11s
# 577:	total: 29s	remaining: 1m 11s
# 578:	total: 29.1s	remaining: 1m 11s
# 579:	total: 29.1s	remaining: 1m 11s
# 580:	total: 29.1s	remaining: 1m 11s
# 581:	total: 29.2s	remaining: 1m 11s
# 582:	total: 29.2s	remaining: 1m 11s
# 583:	total: 29.3s	remaining: 1m 10s
# 584:	total: 29.3s	remaining: 1m 10s
# 585:	total: 29.4s	remaining: 1m 10s
# 586:	total: 29.4s	remaining: 1m 10s
# 587:	total: 29.5s	remaining: 1m 10s
# 588:	total: 29.5s	remaining: 1m 10s
# 589:	total: 29.6s	remaining: 1m 10s
# 590:	total: 29.6s	remaining: 1m 10s
# 591:	total: 29.6s	remaining: 1m 10s
# 592:	total: 29.7s	remaining: 1m 10s
# 593:	total: 29.7s	remaining: 1m 10s
# 594:	total: 29.8s	remaining: 1m 10s
# 595:	total: 29.8s	remaining: 1m 10s
# 596:	total: 29.9s	remaining: 1m 10s
# 597:	total: 29.9s	remaining: 1m 10s
# 598:	total: 30s	remaining: 1m 10s
# 599:	total: 30s	remaining: 1m 9s
# 600:	total: 30.1s	remaining: 1m 9s
# 601:	total: 30.1s	remaining: 1m 9s
# 602:	total: 30.1s	remaining: 1m 9s
# 603:	total: 30.2s	remaining: 1m 9s
# 604:	total: 30.2s	remaining: 1m 9s
# 605:	total: 30.3s	remaining: 1m 9s
# 606:	total: 30.3s	remaining: 1m 9s
# 607:	total: 30.4s	remaining: 1m 9s
# 608:	total: 30.4s	remaining: 1m 9s
# 609:	total: 30.5s	remaining: 1m 9s
# 610:	total: 30.5s	remaining: 1m 9s
# 611:	total: 30.5s	remaining: 1m 9s
# 612:	total: 30.6s	remaining: 1m 9s
# 613:	total: 30.6s	remaining: 1m 9s
# 614:	total: 30.7s	remaining: 1m 9s
# 615:	total: 30.7s	remaining: 1m 9s
# 616:	total: 30.8s	remaining: 1m 8s
# 617:	total: 30.8s	remaining: 1m 8s
# 618:	total: 30.9s	remaining: 1m 8s
# 619:	total: 30.9s	remaining: 1m 8s
# 620:	total: 31s	remaining: 1m 8s
# 621:	total: 31s	remaining: 1m 8s
# 622:	total: 31s	remaining: 1m 8s
# 623:	total: 31.1s	remaining: 1m 8s
# 624:	total: 31.1s	remaining: 1m 8s
# 625:	total: 31.2s	remaining: 1m 8s
# 626:	total: 31.2s	remaining: 1m 8s
# 627:	total: 31.3s	remaining: 1m 8s
# 628:	total: 31.3s	remaining: 1m 8s
# 629:	total: 31.4s	remaining: 1m 8s
# 630:	total: 31.4s	remaining: 1m 8s
# 631:	total: 31.4s	remaining: 1m 8s
# 632:	total: 31.5s	remaining: 1m 7s
# 633:	total: 31.5s	remaining: 1m 7s
# 634:	total: 31.6s	remaining: 1m 7s
# 635:	total: 31.6s	remaining: 1m 7s
# 636:	total: 31.7s	remaining: 1m 7s
# 637:	total: 31.7s	remaining: 1m 7s
# 638:	total: 31.7s	remaining: 1m 7s
# 639:	total: 31.8s	remaining: 1m 7s
# 640:	total: 31.8s	remaining: 1m 7s
# 641:	total: 31.9s	remaining: 1m 7s
# 642:	total: 31.9s	remaining: 1m 7s
# 643:	total: 32s	remaining: 1m 7s
# 644:	total: 32s	remaining: 1m 7s
# 645:	total: 32s	remaining: 1m 7s
# 646:	total: 32.1s	remaining: 1m 7s
# 647:	total: 32.1s	remaining: 1m 7s
# 648:	total: 32.2s	remaining: 1m 6s
# 649:	total: 32.2s	remaining: 1m 6s
# 650:	total: 32.3s	remaining: 1m 6s
# 651:	total: 32.3s	remaining: 1m 6s
# 652:	total: 32.3s	remaining: 1m 6s
# 653:	total: 32.4s	remaining: 1m 6s
# 654:	total: 32.4s	remaining: 1m 6s
# 655:	total: 32.5s	remaining: 1m 6s
# 656:	total: 32.5s	remaining: 1m 6s
# 657:	total: 32.5s	remaining: 1m 6s
# 658:	total: 32.6s	remaining: 1m 6s
# 659:	total: 32.6s	remaining: 1m 6s
# 660:	total: 32.7s	remaining: 1m 6s
# 661:	total: 32.7s	remaining: 1m 6s
# 662:	total: 32.8s	remaining: 1m 6s
# 663:	total: 32.8s	remaining: 1m 6s
# 664:	total: 32.8s	remaining: 1m 5s
# 665:	total: 32.9s	remaining: 1m 5s
# 666:	total: 32.9s	remaining: 1m 5s
# 667:	total: 33s	remaining: 1m 5s
# 668:	total: 33s	remaining: 1m 5s
# 669:	total: 33.1s	remaining: 1m 5s
# 670:	total: 33.1s	remaining: 1m 5s
# 671:	total: 33.2s	remaining: 1m 5s
# 672:	total: 33.2s	remaining: 1m 5s
# 673:	total: 33.2s	remaining: 1m 5s
# 674:	total: 33.3s	remaining: 1m 5s
# 675:	total: 33.3s	remaining: 1m 5s
# 676:	total: 33.4s	remaining: 1m 5s
# 677:	total: 33.4s	remaining: 1m 5s
# 678:	total: 33.5s	remaining: 1m 5s
# 679:	total: 33.5s	remaining: 1m 5s
# 680:	total: 33.6s	remaining: 1m 5s
# 681:	total: 33.7s	remaining: 1m 5s
# 682:	total: 33.8s	remaining: 1m 5s
# 683:	total: 33.9s	remaining: 1m 5s
# 684:	total: 34s	remaining: 1m 5s
# 685:	total: 34.1s	remaining: 1m 5s
# 686:	total: 34.2s	remaining: 1m 5s
# 687:	total: 34.3s	remaining: 1m 5s
# 688:	total: 34.4s	remaining: 1m 5s
# 689:	total: 34.5s	remaining: 1m 5s
# 690:	total: 34.6s	remaining: 1m 5s
# 691:	total: 34.7s	remaining: 1m 5s
# 692:	total: 34.8s	remaining: 1m 5s
# 693:	total: 34.9s	remaining: 1m 5s
# 694:	total: 35s	remaining: 1m 5s
# 695:	total: 35s	remaining: 1m 5s
# 696:	total: 35.1s	remaining: 1m 5s
# 697:	total: 35.2s	remaining: 1m 5s
# 698:	total: 35.3s	remaining: 1m 5s
# 699:	total: 35.4s	remaining: 1m 5s
# 700:	total: 35.5s	remaining: 1m 5s
# 701:	total: 35.6s	remaining: 1m 5s
# 702:	total: 35.6s	remaining: 1m 5s
# 703:	total: 35.7s	remaining: 1m 5s
# 704:	total: 35.8s	remaining: 1m 5s
# 705:	total: 35.9s	remaining: 1m 5s
# 706:	total: 35.9s	remaining: 1m 5s
# 707:	total: 36s	remaining: 1m 5s
# 708:	total: 36.1s	remaining: 1m 5s
# 709:	total: 36.1s	remaining: 1m 5s
# 710:	total: 36.2s	remaining: 1m 5s
# 711:	total: 36.3s	remaining: 1m 5s
# 712:	total: 36.3s	remaining: 1m 5s
# 713:	total: 36.4s	remaining: 1m 5s
# 714:	total: 36.5s	remaining: 1m 5s
# 715:	total: 36.5s	remaining: 1m 5s
# 716:	total: 36.6s	remaining: 1m 5s
# 717:	total: 36.7s	remaining: 1m 5s
# 718:	total: 36.7s	remaining: 1m 5s
# 719:	total: 36.8s	remaining: 1m 5s
# 720:	total: 36.8s	remaining: 1m 5s
# 721:	total: 36.9s	remaining: 1m 5s
# 722:	total: 36.9s	remaining: 1m 5s
# 723:	total: 37s	remaining: 1m 5s
# 724:	total: 37.1s	remaining: 1m 5s
# 725:	total: 37.1s	remaining: 1m 5s
# 726:	total: 37.2s	remaining: 1m 5s
# 727:	total: 37.2s	remaining: 1m 5s
# 728:	total: 37.3s	remaining: 1m 5s
# 729:	total: 37.3s	remaining: 1m 4s
# 730:	total: 37.4s	remaining: 1m 4s
# 731:	total: 37.4s	remaining: 1m 4s
# 732:	total: 37.5s	remaining: 1m 4s
# 733:	total: 37.5s	remaining: 1m 4s
# 734:	total: 37.6s	remaining: 1m 4s
# 735:	total: 37.6s	remaining: 1m 4s
# 736:	total: 37.7s	remaining: 1m 4s
# 737:	total: 37.7s	remaining: 1m 4s
# 738:	total: 37.8s	remaining: 1m 4s
# 739:	total: 37.8s	remaining: 1m 4s
# 740:	total: 37.9s	remaining: 1m 4s
# 741:	total: 37.9s	remaining: 1m 4s
# 742:	total: 38s	remaining: 1m 4s
# 743:	total: 38s	remaining: 1m 4s
# 744:	total: 38.1s	remaining: 1m 4s
# 745:	total: 38.1s	remaining: 1m 4s
# 746:	total: 38.2s	remaining: 1m 4s
# 747:	total: 38.2s	remaining: 1m 3s
# 748:	total: 38.3s	remaining: 1m 3s
# 749:	total: 38.3s	remaining: 1m 3s
# 750:	total: 38.4s	remaining: 1m 3s
# 751:	total: 38.4s	remaining: 1m 3s
# 752:	total: 38.5s	remaining: 1m 3s
# 753:	total: 38.5s	remaining: 1m 3s
# 754:	total: 38.5s	remaining: 1m 3s
# 755:	total: 38.6s	remaining: 1m 3s
# 756:	total: 38.6s	remaining: 1m 3s
# 757:	total: 38.7s	remaining: 1m 3s
# 758:	total: 38.7s	remaining: 1m 3s
# 759:	total: 38.8s	remaining: 1m 3s
# 760:	total: 38.8s	remaining: 1m 3s
# 761:	total: 38.9s	remaining: 1m 3s
# 762:	total: 38.9s	remaining: 1m 3s
# 763:	total: 38.9s	remaining: 1m 3s
# 764:	total: 39s	remaining: 1m 2s
# 765:	total: 39s	remaining: 1m 2s
# 766:	total: 39.1s	remaining: 1m 2s
# 767:	total: 39.1s	remaining: 1m 2s
# 768:	total: 39.2s	remaining: 1m 2s
# 769:	total: 39.2s	remaining: 1m 2s
# 770:	total: 39.2s	remaining: 1m 2s
# 771:	total: 39.3s	remaining: 1m 2s
# 772:	total: 39.3s	remaining: 1m 2s
# 773:	total: 39.4s	remaining: 1m 2s
# 774:	total: 39.4s	remaining: 1m 2s
# 775:	total: 39.5s	remaining: 1m 2s
# 776:	total: 39.5s	remaining: 1m 2s
# 777:	total: 39.6s	remaining: 1m 2s
# 778:	total: 39.6s	remaining: 1m 2s
# 779:	total: 39.6s	remaining: 1m 1s
# 780:	total: 39.7s	remaining: 1m 1s
# 781:	total: 39.7s	remaining: 1m 1s
# 782:	total: 39.8s	remaining: 1m 1s
# 783:	total: 39.8s	remaining: 1m 1s
# 784:	total: 39.9s	remaining: 1m 1s
# 785:	total: 39.9s	remaining: 1m 1s
# 786:	total: 39.9s	remaining: 1m 1s
# 787:	total: 40s	remaining: 1m 1s
# 788:	total: 40s	remaining: 1m 1s
# 789:	total: 40.1s	remaining: 1m 1s
# 790:	total: 40.1s	remaining: 1m 1s
# 791:	total: 40.2s	remaining: 1m 1s
# 792:	total: 40.2s	remaining: 1m 1s
# 793:	total: 40.3s	remaining: 1m 1s
# 794:	total: 40.3s	remaining: 1m 1s
# 795:	total: 40.3s	remaining: 1m 1s
# 796:	total: 40.4s	remaining: 1m
# 797:	total: 40.6s	remaining: 1m 1s
# 798:	total: 40.6s	remaining: 1m 1s
# 799:	total: 40.6s	remaining: 1m
# 800:	total: 40.7s	remaining: 1m
# 801:	total: 40.7s	remaining: 1m
# 802:	total: 40.8s	remaining: 1m
# 803:	total: 40.8s	remaining: 1m
# 804:	total: 40.9s	remaining: 1m
# 805:	total: 40.9s	remaining: 1m
# 806:	total: 40.9s	remaining: 1m
# 807:	total: 41s	remaining: 1m
# 808:	total: 41s	remaining: 1m
# 809:	total: 41.1s	remaining: 1m
# 810:	total: 41.1s	remaining: 1m
# 811:	total: 41.1s	remaining: 1m
# 812:	total: 41.2s	remaining: 1m
# 813:	total: 41.2s	remaining: 1m
# 814:	total: 41.3s	remaining: 1m
# 815:	total: 41.3s	remaining: 60s
# 816:	total: 41.4s	remaining: 59.9s
# 817:	total: 41.4s	remaining: 59.8s
# 818:	total: 41.5s	remaining: 59.8s
# 819:	total: 41.5s	remaining: 59.7s
# 820:	total: 41.5s	remaining: 59.7s
# 821:	total: 41.6s	remaining: 59.6s
# 822:	total: 41.6s	remaining: 59.5s
# 823:	total: 41.7s	remaining: 59.5s
# 824:	total: 41.7s	remaining: 59.4s
# 825:	total: 41.8s	remaining: 59.3s
# 826:	total: 41.8s	remaining: 59.3s
# 827:	total: 41.8s	remaining: 59.2s
# 828:	total: 41.9s	remaining: 59.2s
# 829:	total: 41.9s	remaining: 59.1s
# 830:	total: 42s	remaining: 59s
# 831:	total: 42s	remaining: 59s
# 832:	total: 42.1s	remaining: 58.9s
# 833:	total: 42.1s	remaining: 58.9s
# 834:	total: 42.1s	remaining: 58.8s
# 835:	total: 42.2s	remaining: 58.7s
# 836:	total: 42.2s	remaining: 58.7s
# 837:	total: 42.3s	remaining: 58.6s
# 838:	total: 42.3s	remaining: 58.6s
# 839:	total: 42.4s	remaining: 58.5s
# 840:	total: 42.4s	remaining: 58.4s
# 841:	total: 42.4s	remaining: 58.4s
# 842:	total: 42.5s	remaining: 58.3s
# 843:	total: 42.5s	remaining: 58.3s
# 844:	total: 42.6s	remaining: 58.2s
# 845:	total: 42.6s	remaining: 58.1s
# 846:	total: 42.7s	remaining: 58.1s
# 847:	total: 42.7s	remaining: 58s
# 848:	total: 42.8s	remaining: 58s
# 849:	total: 42.8s	remaining: 57.9s
# 850:	total: 42.8s	remaining: 57.9s
# 851:	total: 42.9s	remaining: 57.8s
# 852:	total: 42.9s	remaining: 57.7s
# 853:	total: 43s	remaining: 57.7s
# 854:	total: 43s	remaining: 57.6s
# 855:	total: 43.1s	remaining: 57.6s
# 856:	total: 43.1s	remaining: 57.5s
# 857:	total: 43.1s	remaining: 57.4s
# 858:	total: 43.2s	remaining: 57.4s
# 859:	total: 43.2s	remaining: 57.3s
# 860:	total: 43.3s	remaining: 57.2s
# 861:	total: 43.3s	remaining: 57.2s
# 862:	total: 43.4s	remaining: 57.1s
# 863:	total: 43.4s	remaining: 57.1s
# 864:	total: 43.4s	remaining: 57s
# 865:	total: 43.5s	remaining: 57s
# 866:	total: 43.5s	remaining: 56.9s
# 867:	total: 43.6s	remaining: 56.8s
# 868:	total: 43.6s	remaining: 56.8s
# 869:	total: 43.7s	remaining: 56.7s
# 870:	total: 43.7s	remaining: 56.7s
# 871:	total: 43.8s	remaining: 56.6s
# 872:	total: 43.8s	remaining: 56.5s
# 873:	total: 43.8s	remaining: 56.5s
# 874:	total: 43.9s	remaining: 56.4s
# 875:	total: 43.9s	remaining: 56.3s
# 876:	total: 44s	remaining: 56.3s
# 877:	total: 44s	remaining: 56.2s
# 878:	total: 44s	remaining: 56.2s
# 879:	total: 44.1s	remaining: 56.1s
# 880:	total: 44.1s	remaining: 56.1s
# 881:	total: 44.2s	remaining: 56s
# 882:	total: 44.2s	remaining: 56s
# 883:	total: 44.3s	remaining: 55.9s
# 884:	total: 44.3s	remaining: 55.8s
# 885:	total: 44.4s	remaining: 55.8s
# 886:	total: 44.4s	remaining: 55.7s
# 887:	total: 44.5s	remaining: 55.7s
# 888:	total: 44.5s	remaining: 55.6s
# 889:	total: 44.5s	remaining: 55.6s
# 890:	total: 44.6s	remaining: 55.5s
# 891:	total: 44.6s	remaining: 55.4s
# 892:	total: 44.7s	remaining: 55.4s
# 893:	total: 44.7s	remaining: 55.3s
# 894:	total: 44.7s	remaining: 55.2s
# 895:	total: 44.8s	remaining: 55.2s
# 896:	total: 44.8s	remaining: 55.1s
# 897:	total: 44.9s	remaining: 55.1s
# 898:	total: 44.9s	remaining: 55s
# 899:	total: 45s	remaining: 55s
# 900:	total: 45s	remaining: 54.9s
# 901:	total: 45.1s	remaining: 54.9s
# 902:	total: 45.1s	remaining: 54.8s
# 903:	total: 45.2s	remaining: 54.7s
# 904:	total: 45.2s	remaining: 54.7s
# 905:	total: 45.2s	remaining: 54.6s
# 906:	total: 45.3s	remaining: 54.6s
# 907:	total: 45.3s	remaining: 54.5s
# 908:	total: 45.4s	remaining: 54.4s
# 909:	total: 45.4s	remaining: 54.4s
# 910:	total: 45.5s	remaining: 54.3s
# 911:	total: 45.5s	remaining: 54.3s
# 912:	total: 45.5s	remaining: 54.2s
# 913:	total: 45.6s	remaining: 54.2s
# 914:	total: 45.6s	remaining: 54.1s
# 915:	total: 45.7s	remaining: 54s
# 916:	total: 45.7s	remaining: 54s
# 917:	total: 45.8s	remaining: 53.9s
# 918:	total: 45.8s	remaining: 53.9s
# 919:	total: 45.8s	remaining: 53.8s
# 920:	total: 45.9s	remaining: 53.8s
# 921:	total: 45.9s	remaining: 53.7s
# 922:	total: 46s	remaining: 53.6s
# 923:	total: 46s	remaining: 53.6s
# 924:	total: 46s	remaining: 53.5s
# 925:	total: 46.1s	remaining: 53.5s
# 926:	total: 46.1s	remaining: 53.4s
# 927:	total: 46.2s	remaining: 53.3s
# 928:	total: 46.2s	remaining: 53.3s
# 929:	total: 46.3s	remaining: 53.2s
# 930:	total: 46.3s	remaining: 53.2s
# 931:	total: 46.3s	remaining: 53.1s
# 932:	total: 46.4s	remaining: 53.1s
# 933:	total: 46.4s	remaining: 53s
# 934:	total: 46.5s	remaining: 52.9s
# 935:	total: 46.5s	remaining: 52.9s
# 936:	total: 46.6s	remaining: 52.8s
# 937:	total: 46.6s	remaining: 52.8s
# 938:	total: 46.7s	remaining: 52.7s
# 939:	total: 46.7s	remaining: 52.7s
# 940:	total: 46.7s	remaining: 52.6s
# 941:	total: 46.8s	remaining: 52.6s
# 942:	total: 46.8s	remaining: 52.5s
# 943:	total: 46.9s	remaining: 52.4s
# 944:	total: 46.9s	remaining: 52.4s
# 945:	total: 47s	remaining: 52.3s
# 946:	total: 47s	remaining: 52.3s
# 947:	total: 47.1s	remaining: 52.2s
# 948:	total: 47.1s	remaining: 52.2s
# 949:	total: 47.1s	remaining: 52.1s
# 950:	total: 47.2s	remaining: 52s
# 951:	total: 47.2s	remaining: 52s
# 952:	total: 47.3s	remaining: 51.9s
# 953:	total: 47.3s	remaining: 51.9s
# 954:	total: 47.4s	remaining: 51.8s
# 955:	total: 47.4s	remaining: 51.8s
# 956:	total: 47.4s	remaining: 51.7s
# 957:	total: 47.5s	remaining: 51.6s
# 958:	total: 47.5s	remaining: 51.6s
# 959:	total: 47.6s	remaining: 51.5s
# 960:	total: 47.6s	remaining: 51.5s
# 961:	total: 47.7s	remaining: 51.4s
# 962:	total: 47.7s	remaining: 51.4s
# 963:	total: 47.7s	remaining: 51.3s
# 964:	total: 47.8s	remaining: 51.3s
# 965:	total: 47.8s	remaining: 51.2s
# 966:	total: 47.9s	remaining: 51.1s
# 967:	total: 47.9s	remaining: 51.1s
# 968:	total: 48s	remaining: 51s
# 969:	total: 48s	remaining: 51s
# 970:	total: 48s	remaining: 50.9s
# 971:	total: 48.1s	remaining: 50.8s
# 972:	total: 48.1s	remaining: 50.8s
# 973:	total: 48.2s	remaining: 50.7s
# 974:	total: 48.2s	remaining: 50.7s
# 975:	total: 48.2s	remaining: 50.6s
# 976:	total: 48.3s	remaining: 50.6s
# 977:	total: 48.3s	remaining: 50.5s
# 978:	total: 48.4s	remaining: 50.5s
# 979:	total: 48.4s	remaining: 50.4s
# 980:	total: 48.5s	remaining: 50.3s
# 981:	total: 48.5s	remaining: 50.3s
# 982:	total: 48.5s	remaining: 50.2s
# 983:	total: 48.6s	remaining: 50.2s
# 984:	total: 48.6s	remaining: 50.1s
# 985:	total: 48.7s	remaining: 50s
# 986:	total: 48.7s	remaining: 50s
# 987:	total: 48.7s	remaining: 49.9s
# 988:	total: 48.8s	remaining: 49.9s
# 989:	total: 48.8s	remaining: 49.8s
# 990:	total: 48.9s	remaining: 49.8s
# 991:	total: 48.9s	remaining: 49.7s
# 992:	total: 49s	remaining: 49.7s
# 993:	total: 49s	remaining: 49.6s
# 994:	total: 49.1s	remaining: 49.5s
# 995:	total: 49.1s	remaining: 49.5s
# 996:	total: 49.1s	remaining: 49.4s
# 997:	total: 49.2s	remaining: 49.4s
# 998:	total: 49.2s	remaining: 49.3s
# 999:	total: 49.3s	remaining: 49.3s
# 1000:	total: 49.3s	remaining: 49.2s
# 1001:	total: 49.4s	remaining: 49.2s
# 1002:	total: 49.4s	remaining: 49.1s
# 1003:	total: 49.5s	remaining: 49.1s
# 1004:	total: 49.5s	remaining: 49s
# 1005:	total: 49.5s	remaining: 48.9s
# 1006:	total: 49.6s	remaining: 48.9s
# 1007:	total: 49.6s	remaining: 48.8s
# 1008:	total: 49.7s	remaining: 48.8s
# 1009:	total: 49.7s	remaining: 48.7s
# 1010:	total: 49.7s	remaining: 48.7s
# 1011:	total: 49.8s	remaining: 48.6s
# 1012:	total: 49.8s	remaining: 48.5s
# 1013:	total: 49.9s	remaining: 48.5s
# 1014:	total: 49.9s	remaining: 48.4s
# 1015:	total: 50s	remaining: 48.4s
# 1016:	total: 50s	remaining: 48.3s
# 1017:	total: 50s	remaining: 48.3s
# 1018:	total: 50.1s	remaining: 48.2s
# 1019:	total: 50.1s	remaining: 48.2s
# 1020:	total: 50.2s	remaining: 48.1s
# 1021:	total: 50.2s	remaining: 48.1s
# 1022:	total: 50.3s	remaining: 48s
# 1023:	total: 50.3s	remaining: 47.9s
# 1024:	total: 50.3s	remaining: 47.9s
# 1025:	total: 50.4s	remaining: 47.8s
# 1026:	total: 50.4s	remaining: 47.8s
# 1027:	total: 50.5s	remaining: 47.7s
# 1028:	total: 50.5s	remaining: 47.7s
# 1029:	total: 50.6s	remaining: 47.6s
# 1030:	total: 50.6s	remaining: 47.6s
# 1031:	total: 50.6s	remaining: 47.5s
# 1032:	total: 50.7s	remaining: 47.4s
# 1033:	total: 50.7s	remaining: 47.4s
# 1034:	total: 50.8s	remaining: 47.3s
# 1035:	total: 50.8s	remaining: 47.3s
# 1036:	total: 50.9s	remaining: 47.2s
# 1037:	total: 50.9s	remaining: 47.2s
# 1038:	total: 50.9s	remaining: 47.1s
# 1039:	total: 51s	remaining: 47.1s
# 1040:	total: 51s	remaining: 47s
# 1041:	total: 51.1s	remaining: 47s
# 1042:	total: 51.1s	remaining: 46.9s
# 1043:	total: 51.2s	remaining: 46.9s
# 1044:	total: 51.2s	remaining: 46.8s
# 1045:	total: 51.2s	remaining: 46.7s
# 1046:	total: 51.3s	remaining: 46.7s
# 1047:	total: 51.3s	remaining: 46.6s
# 1048:	total: 51.4s	remaining: 46.6s
# 1049:	total: 51.4s	remaining: 46.5s
# 1050:	total: 51.5s	remaining: 46.5s
# 1051:	total: 51.5s	remaining: 46.4s
# 1052:	total: 51.5s	remaining: 46.3s
# 1053:	total: 51.6s	remaining: 46.3s
# 1054:	total: 51.6s	remaining: 46.2s
# 1055:	total: 51.7s	remaining: 46.2s
# 1056:	total: 51.7s	remaining: 46.1s
# 1057:	total: 51.7s	remaining: 46.1s
# 1058:	total: 51.8s	remaining: 46s
# 1059:	total: 51.8s	remaining: 46s
# 1060:	total: 51.9s	remaining: 45.9s
# 1061:	total: 51.9s	remaining: 45.8s
# 1062:	total: 51.9s	remaining: 45.8s
# 1063:	total: 52s	remaining: 45.7s
# 1064:	total: 52s	remaining: 45.7s
# 1065:	total: 52.1s	remaining: 45.6s
# 1066:	total: 52.1s	remaining: 45.6s
# 1067:	total: 52.1s	remaining: 45.5s
# 1068:	total: 52.2s	remaining: 45.5s
# 1069:	total: 52.2s	remaining: 45.4s
# 1070:	total: 52.3s	remaining: 45.3s
# 1071:	total: 52.3s	remaining: 45.3s
# 1072:	total: 52.4s	remaining: 45.2s
# 1073:	total: 52.4s	remaining: 45.2s
# 1074:	total: 52.4s	remaining: 45.1s
# 1075:	total: 52.5s	remaining: 45.1s
# 1076:	total: 52.5s	remaining: 45s
# 1077:	total: 52.6s	remaining: 45s
# 1078:	total: 52.6s	remaining: 44.9s
# 1079:	total: 52.7s	remaining: 44.9s
# 1080:	total: 52.7s	remaining: 44.8s
# 1081:	total: 52.7s	remaining: 44.7s
# 1082:	total: 52.8s	remaining: 44.7s
# 1083:	total: 52.8s	remaining: 44.6s
# 1084:	total: 52.9s	remaining: 44.6s
# 1085:	total: 52.9s	remaining: 44.5s
# 1086:	total: 52.9s	remaining: 44.5s
# 1087:	total: 53s	remaining: 44.4s
# 1088:	total: 53s	remaining: 44.4s
# 1089:	total: 53.1s	remaining: 44.3s
# 1090:	total: 53.1s	remaining: 44.2s
# 1091:	total: 53.1s	remaining: 44.2s
# 1092:	total: 53.2s	remaining: 44.1s
# 1093:	total: 53.2s	remaining: 44.1s
# 1094:	total: 53.3s	remaining: 44s
# 1095:	total: 53.3s	remaining: 44s
# 1096:	total: 53.4s	remaining: 43.9s
# 1097:	total: 53.4s	remaining: 43.9s
# 1098:	total: 53.5s	remaining: 43.8s
# 1099:	total: 53.5s	remaining: 43.8s
# 1100:	total: 53.5s	remaining: 43.7s
# 1101:	total: 53.6s	remaining: 43.7s
# 1102:	total: 53.6s	remaining: 43.6s
# 1103:	total: 53.7s	remaining: 43.6s
# 1104:	total: 53.7s	remaining: 43.5s
# 1105:	total: 53.7s	remaining: 43.4s
# 1106:	total: 53.8s	remaining: 43.4s
# 1107:	total: 53.8s	remaining: 43.3s
# 1108:	total: 53.9s	remaining: 43.3s
# 1109:	total: 53.9s	remaining: 43.2s
# 1110:	total: 54s	remaining: 43.2s
# 1111:	total: 54s	remaining: 43.1s
# 1112:	total: 54s	remaining: 43.1s
# 1113:	total: 54.1s	remaining: 43s
# 1114:	total: 54.1s	remaining: 43s
# 1115:	total: 54.2s	remaining: 42.9s
# 1116:	total: 54.2s	remaining: 42.9s
# 1117:	total: 54.3s	remaining: 42.8s
# 1118:	total: 54.3s	remaining: 42.8s
# 1119:	total: 54.4s	remaining: 42.7s
# 1120:	total: 54.4s	remaining: 42.7s
# 1121:	total: 54.5s	remaining: 42.6s
# 1122:	total: 54.5s	remaining: 42.6s
# 1123:	total: 54.5s	remaining: 42.5s
# 1124:	total: 54.6s	remaining: 42.4s
# 1125:	total: 54.6s	remaining: 42.4s
# 1126:	total: 54.7s	remaining: 42.3s
# 1127:	total: 54.7s	remaining: 42.3s
# 1128:	total: 54.8s	remaining: 42.2s
# 1129:	total: 54.8s	remaining: 42.2s
# 1130:	total: 54.8s	remaining: 42.1s
# 1131:	total: 54.9s	remaining: 42.1s
# 1132:	total: 54.9s	remaining: 42s
# 1133:	total: 55s	remaining: 42s
# 1134:	total: 55s	remaining: 41.9s
# 1135:	total: 55s	remaining: 41.9s
# 1136:	total: 55.1s	remaining: 41.8s
# 1137:	total: 55.1s	remaining: 41.8s
# 1138:	total: 55.2s	remaining: 41.7s
# 1139:	total: 55.2s	remaining: 41.6s
# 1140:	total: 55.2s	remaining: 41.6s
# 1141:	total: 55.3s	remaining: 41.5s
# 1142:	total: 55.3s	remaining: 41.5s
# 1143:	total: 55.4s	remaining: 41.4s
# 1144:	total: 55.4s	remaining: 41.4s
# 1145:	total: 55.4s	remaining: 41.3s
# 1146:	total: 55.5s	remaining: 41.3s
# 1147:	total: 55.5s	remaining: 41.2s
# 1148:	total: 55.6s	remaining: 41.2s
# 1149:	total: 55.6s	remaining: 41.1s
# 1150:	total: 55.7s	remaining: 41.1s
# 1151:	total: 55.7s	remaining: 41s
# 1152:	total: 55.8s	remaining: 41s
# 1153:	total: 55.8s	remaining: 40.9s
# 1154:	total: 55.8s	remaining: 40.8s
# 1155:	total: 55.9s	remaining: 40.8s
# 1156:	total: 55.9s	remaining: 40.7s
# 1157:	total: 56s	remaining: 40.7s
# 1158:	total: 56s	remaining: 40.6s
# 1159:	total: 56s	remaining: 40.6s
# 1160:	total: 56.1s	remaining: 40.5s
# 1161:	total: 56.1s	remaining: 40.5s
# 1162:	total: 56.2s	remaining: 40.4s
# 1163:	total: 56.2s	remaining: 40.4s
# 1164:	total: 56.3s	remaining: 40.3s
# 1165:	total: 56.3s	remaining: 40.3s
# 1166:	total: 56.3s	remaining: 40.2s
# 1167:	total: 56.4s	remaining: 40.2s
# 1168:	total: 56.4s	remaining: 40.1s
# 1169:	total: 56.5s	remaining: 40.1s
# 1170:	total: 56.5s	remaining: 40s
# 1171:	total: 56.5s	remaining: 40s
# 1172:	total: 56.6s	remaining: 39.9s
# 1173:	total: 56.6s	remaining: 39.8s
# 1174:	total: 56.7s	remaining: 39.8s
# 1175:	total: 56.7s	remaining: 39.7s
# 1176:	total: 56.8s	remaining: 39.7s
# 1177:	total: 56.8s	remaining: 39.6s
# 1178:	total: 56.9s	remaining: 39.6s
# 1179:	total: 56.9s	remaining: 39.5s
# 1180:	total: 56.9s	remaining: 39.5s
# 1181:	total: 57s	remaining: 39.4s
# 1182:	total: 57s	remaining: 39.4s
# 1183:	total: 57.1s	remaining: 39.3s
# 1184:	total: 57.1s	remaining: 39.3s
# 1185:	total: 57.1s	remaining: 39.2s
# 1186:	total: 57.2s	remaining: 39.2s
# 1187:	total: 57.2s	remaining: 39.1s
# 1188:	total: 57.3s	remaining: 39.1s
# 1189:	total: 57.3s	remaining: 39s
# 1190:	total: 57.4s	remaining: 39s
# 1191:	total: 57.4s	remaining: 38.9s
# 1192:	total: 57.5s	remaining: 38.9s
# 1193:	total: 57.5s	remaining: 38.8s
# 1194:	total: 57.5s	remaining: 38.8s
# 1195:	total: 57.6s	remaining: 38.7s
# 1196:	total: 57.6s	remaining: 38.7s
# 1197:	total: 57.7s	remaining: 38.6s
# 1198:	total: 57.7s	remaining: 38.6s
# 1199:	total: 57.8s	remaining: 38.5s
# 1200:	total: 57.8s	remaining: 38.5s
# 1201:	total: 57.8s	remaining: 38.4s
# 1202:	total: 57.9s	remaining: 38.3s
# 1203:	total: 57.9s	remaining: 38.3s
# 1204:	total: 58.1s	remaining: 38.3s
# 1205:	total: 58.1s	remaining: 38.3s
# 1206:	total: 58.2s	remaining: 38.2s
# 1207:	total: 58.2s	remaining: 38.2s
# 1208:	total: 58.3s	remaining: 38.1s
# 1209:	total: 58.3s	remaining: 38.1s
# 1210:	total: 58.3s	remaining: 38s
# 1211:	total: 58.4s	remaining: 38s
# 1212:	total: 58.4s	remaining: 37.9s
# 1213:	total: 58.5s	remaining: 37.9s
# 1214:	total: 58.5s	remaining: 37.8s
# 1215:	total: 58.6s	remaining: 37.8s
# 1216:	total: 58.6s	remaining: 37.7s
# 1217:	total: 58.7s	remaining: 37.7s
# 1218:	total: 58.7s	remaining: 37.6s
# 1219:	total: 58.7s	remaining: 37.6s
# 1220:	total: 58.8s	remaining: 37.5s
# 1221:	total: 58.8s	remaining: 37.5s
# 1222:	total: 58.9s	remaining: 37.4s
# 1223:	total: 58.9s	remaining: 37.4s
# 1224:	total: 59s	remaining: 37.3s
# 1225:	total: 59s	remaining: 37.2s
# 1226:	total: 59s	remaining: 37.2s
# 1227:	total: 59.1s	remaining: 37.1s
# 1228:	total: 59.1s	remaining: 37.1s
# 1229:	total: 59.2s	remaining: 37s
# 1230:	total: 59.2s	remaining: 37s
# 1231:	total: 59.3s	remaining: 36.9s
# 1232:	total: 59.3s	remaining: 36.9s
# 1233:	total: 59.4s	remaining: 36.8s
# 1234:	total: 59.4s	remaining: 36.8s
# 1235:	total: 59.4s	remaining: 36.7s
# 1236:	total: 59.5s	remaining: 36.7s
# 1237:	total: 59.5s	remaining: 36.6s
# 1238:	total: 59.6s	remaining: 36.6s
# 1239:	total: 59.6s	remaining: 36.5s
# 1240:	total: 59.6s	remaining: 36.5s
# 1241:	total: 59.7s	remaining: 36.4s
# 1242:	total: 59.7s	remaining: 36.4s
# 1243:	total: 59.8s	remaining: 36.3s
# 1244:	total: 59.8s	remaining: 36.3s
# 1245:	total: 59.9s	remaining: 36.2s
# 1246:	total: 59.9s	remaining: 36.2s
# 1247:	total: 59.9s	remaining: 36.1s
# 1248:	total: 60s	remaining: 36.1s
# 1249:	total: 1m	remaining: 36s
# 1250:	total: 1m	remaining: 36s
# 1251:	total: 1m	remaining: 35.9s
# 1252:	total: 1m	remaining: 35.8s
# 1253:	total: 1m	remaining: 35.8s
# 1254:	total: 1m	remaining: 35.7s
# 1255:	total: 1m	remaining: 35.7s
# 1256:	total: 1m	remaining: 35.6s
# 1257:	total: 1m	remaining: 35.6s
# 1258:	total: 1m	remaining: 35.5s
# 1259:	total: 1m	remaining: 35.5s
# 1260:	total: 1m	remaining: 35.4s
# 1261:	total: 1m	remaining: 35.4s
# 1262:	total: 1m	remaining: 35.4s
# 1263:	total: 1m	remaining: 35.3s
# 1264:	total: 1m	remaining: 35.3s
# 1265:	total: 1m	remaining: 35.2s
# 1266:	total: 1m	remaining: 35.2s
# 1267:	total: 1m	remaining: 35.1s
# 1268:	total: 1m	remaining: 35.1s
# 1269:	total: 1m	remaining: 35s
# 1270:	total: 1m	remaining: 35s
# 1271:	total: 1m 1s	remaining: 34.9s
# 1272:	total: 1m 1s	remaining: 34.9s
# 1273:	total: 1m 1s	remaining: 34.8s
# 1274:	total: 1m 1s	remaining: 34.8s
# 1275:	total: 1m 1s	remaining: 34.7s
# 1276:	total: 1m 1s	remaining: 34.7s
# 1277:	total: 1m 1s	remaining: 34.6s
# 1278:	total: 1m 1s	remaining: 34.6s
# 1279:	total: 1m 1s	remaining: 34.5s
# 1280:	total: 1m 1s	remaining: 34.5s
# 1281:	total: 1m 1s	remaining: 34.4s
# 1282:	total: 1m 1s	remaining: 34.4s
# 1283:	total: 1m 1s	remaining: 34.3s
# 1284:	total: 1m 1s	remaining: 34.3s
# 1285:	total: 1m 1s	remaining: 34.2s
# 1286:	total: 1m 1s	remaining: 34.2s
# 1287:	total: 1m 1s	remaining: 34.1s
# 1288:	total: 1m 1s	remaining: 34.1s
# 1289:	total: 1m 1s	remaining: 34s
# 1290:	total: 1m 1s	remaining: 34s
# 1291:	total: 1m 1s	remaining: 33.9s
# 1292:	total: 1m 1s	remaining: 33.9s
# 1293:	total: 1m 2s	remaining: 33.8s
# 1294:	total: 1m 2s	remaining: 33.8s
# 1295:	total: 1m 2s	remaining: 33.7s
# 1296:	total: 1m 2s	remaining: 33.7s
# 1297:	total: 1m 2s	remaining: 33.6s
# 1298:	total: 1m 2s	remaining: 33.6s
# 1299:	total: 1m 2s	remaining: 33.5s
# 1300:	total: 1m 2s	remaining: 33.5s
# 1301:	total: 1m 2s	remaining: 33.4s
# 1302:	total: 1m 2s	remaining: 33.4s
# 1303:	total: 1m 2s	remaining: 33.3s
# 1304:	total: 1m 2s	remaining: 33.3s
# 1305:	total: 1m 2s	remaining: 33.2s
# 1306:	total: 1m 2s	remaining: 33.2s
# 1307:	total: 1m 2s	remaining: 33.1s
# 1308:	total: 1m 2s	remaining: 33.1s
# 1309:	total: 1m 2s	remaining: 33s
# 1310:	total: 1m 2s	remaining: 33s
# 1311:	total: 1m 2s	remaining: 32.9s
# 1312:	total: 1m 2s	remaining: 32.9s
# 1313:	total: 1m 2s	remaining: 32.8s
# 1314:	total: 1m 2s	remaining: 32.8s
# 1315:	total: 1m 2s	remaining: 32.7s
# 1316:	total: 1m 3s	remaining: 32.7s
# 1317:	total: 1m 3s	remaining: 32.6s
# 1318:	total: 1m 3s	remaining: 32.6s
# 1319:	total: 1m 3s	remaining: 32.5s
# 1320:	total: 1m 3s	remaining: 32.5s
# 1321:	total: 1m 3s	remaining: 32.4s
# 1322:	total: 1m 3s	remaining: 32.4s
# 1323:	total: 1m 3s	remaining: 32.3s
# 1324:	total: 1m 3s	remaining: 32.3s
# 1325:	total: 1m 3s	remaining: 32.2s
# 1326:	total: 1m 3s	remaining: 32.2s
# 1327:	total: 1m 3s	remaining: 32.1s
# 1328:	total: 1m 3s	remaining: 32.1s
# 1329:	total: 1m 3s	remaining: 32s
# 1330:	total: 1m 3s	remaining: 32s
# 1331:	total: 1m 3s	remaining: 31.9s
# 1332:	total: 1m 3s	remaining: 31.9s
# 1333:	total: 1m 3s	remaining: 31.8s
# 1334:	total: 1m 3s	remaining: 31.8s
# 1335:	total: 1m 3s	remaining: 31.7s
# 1336:	total: 1m 3s	remaining: 31.7s
# 1337:	total: 1m 3s	remaining: 31.6s
# 1338:	total: 1m 3s	remaining: 31.6s
# 1339:	total: 1m 4s	remaining: 31.5s
# 1340:	total: 1m 4s	remaining: 31.5s
# 1341:	total: 1m 4s	remaining: 31.4s
# 1342:	total: 1m 4s	remaining: 31.4s
# 1343:	total: 1m 4s	remaining: 31.3s
# 1344:	total: 1m 4s	remaining: 31.3s
# 1345:	total: 1m 4s	remaining: 31.2s
# 1346:	total: 1m 4s	remaining: 31.2s
# 1347:	total: 1m 4s	remaining: 31.1s
# 1348:	total: 1m 4s	remaining: 31.1s
# 1349:	total: 1m 4s	remaining: 31s
# 1350:	total: 1m 4s	remaining: 31s
# 1351:	total: 1m 4s	remaining: 30.9s
# 1352:	total: 1m 4s	remaining: 30.9s
# 1353:	total: 1m 4s	remaining: 30.8s
# 1354:	total: 1m 4s	remaining: 30.8s
# 1355:	total: 1m 4s	remaining: 30.7s
# 1356:	total: 1m 4s	remaining: 30.7s
# 1357:	total: 1m 4s	remaining: 30.6s
# 1358:	total: 1m 4s	remaining: 30.6s
# 1359:	total: 1m 4s	remaining: 30.5s
# ...
# 1566:	total: 1m 13s	remaining: 20.4s
# 1567:	total: 1m 13s	remaining: 20.3s
# 1568:	total: 1m 13s	remaining: 20.3s
# 1569:	total: 1m 13s	remaining: 20.2s
# 1570:	total: 1m 13s	remaining: 20.2s
# 1571:	total: 1m 13s	remaining: 20.1s
# 1572:	total: 1m 13s	remaining: 20.1s
# 1573:	total: 1m 13s	remaining: 20s
# 1574:	total: 1m 14s	remaining: 20s
# 1575:	total: 1m 14s	remaining: 19.9s
# 1576:	total: 1m 14s	remaining: 19.9s
# 1577:	total: 1m 14s	remaining: 19.8s
# 1578:	total: 1m 14s	remaining: 19.8s
# 1579:	total: 1m 14s	remaining: 19.7s
# 1580:	total: 1m 14s	remaining: 19.7s
# 1581:	total: 1m 14s	remaining: 19.6s
# 1582:	total: 1m 14s	remaining: 19.6s
# 1583:	total: 1m 14s	remaining: 19.6s
# 1584:	total: 1m 14s	remaining: 19.5s
# 1585:	total: 1m 14s	remaining: 19.5s
# 1586:	total: 1m 14s	remaining: 19.4s
# 1587:	total: 1m 14s	remaining: 19.4s
# 1588:	total: 1m 14s	remaining: 19.3s
# 1589:	total: 1m 14s	remaining: 19.3s
# 1590:	total: 1m 14s	remaining: 19.2s
# 1591:	total: 1m 14s	remaining: 19.2s
# 1592:	total: 1m 14s	remaining: 19.1s
# 1593:	total: 1m 14s	remaining: 19.1s
# 1594:	total: 1m 14s	remaining: 19s
# 1595:	total: 1m 15s	remaining: 19s
# 1596:	total: 1m 15s	remaining: 18.9s
# 1597:	total: 1m 15s	remaining: 18.9s
# 1598:	total: 1m 15s	remaining: 18.9s
# 1599:	total: 1m 15s	remaining: 18.8s
# 1600:	total: 1m 15s	remaining: 18.8s
# 1601:	total: 1m 15s	remaining: 18.7s
# 1602:	total: 1m 15s	remaining: 18.7s
# 1603:	total: 1m 15s	remaining: 18.6s
# 1604:	total: 1m 15s	remaining: 18.6s
# 1605:	total: 1m 15s	remaining: 18.5s
# 1606:	total: 1m 15s	remaining: 18.5s
# 1607:	total: 1m 15s	remaining: 18.4s
# 1608:	total: 1m 15s	remaining: 18.4s
# 1609:	total: 1m 15s	remaining: 18.3s
# 1610:	total: 1m 15s	remaining: 18.3s
# 1611:	total: 1m 15s	remaining: 18.3s
# 1612:	total: 1m 15s	remaining: 18.2s
# 1613:	total: 1m 15s	remaining: 18.2s
# 1614:	total: 1m 15s	remaining: 18.1s
# 1615:	total: 1m 16s	remaining: 18.1s
# 1616:	total: 1m 16s	remaining: 18s
# 1617:	total: 1m 16s	remaining: 18s
# 1618:	total: 1m 16s	remaining: 17.9s
# 1619:	total: 1m 16s	remaining: 17.9s
# 1620:	total: 1m 16s	remaining: 17.8s
# 1621:	total: 1m 16s	remaining: 17.8s
# 1622:	total: 1m 16s	remaining: 17.7s
# 1623:	total: 1m 16s	remaining: 17.7s
# 1624:	total: 1m 16s	remaining: 17.7s
# 1625:	total: 1m 16s	remaining: 17.6s
# 1626:	total: 1m 16s	remaining: 17.6s
# 1627:	total: 1m 16s	remaining: 17.5s
# 1628:	total: 1m 16s	remaining: 17.5s
# 1629:	total: 1m 16s	remaining: 17.4s
# 1630:	total: 1m 16s	remaining: 17.4s
# 1631:	total: 1m 16s	remaining: 17.3s
# 1632:	total: 1m 16s	remaining: 17.3s
# 1633:	total: 1m 16s	remaining: 17.2s
# 1634:	total: 1m 16s	remaining: 17.2s
# 1635:	total: 1m 17s	remaining: 17.1s
# 1636:	total: 1m 17s	remaining: 17.1s
# 1637:	total: 1m 17s	remaining: 17.1s
# 1638:	total: 1m 17s	remaining: 17s
# 1639:	total: 1m 17s	remaining: 17s
# 1640:	total: 1m 17s	remaining: 16.9s
# 1641:	total: 1m 17s	remaining: 16.9s
# 1642:	total: 1m 17s	remaining: 16.8s
# 1643:	total: 1m 17s	remaining: 16.8s
# 1644:	total: 1m 17s	remaining: 16.7s
# 1645:	total: 1m 17s	remaining: 16.7s
# 1646:	total: 1m 17s	remaining: 16.7s
# 1647:	total: 1m 17s	remaining: 16.6s
# 1648:	total: 1m 17s	remaining: 16.6s
# 1649:	total: 1m 17s	remaining: 16.5s
# 1650:	total: 1m 17s	remaining: 16.5s
# 1651:	total: 1m 17s	remaining: 16.4s
# 1652:	total: 1m 18s	remaining: 16.4s
# 1653:	total: 1m 18s	remaining: 16.3s
# 1654:	total: 1m 18s	remaining: 16.3s
# 1655:	total: 1m 18s	remaining: 16.2s
# 1656:	total: 1m 18s	remaining: 16.2s
# 1657:	total: 1m 18s	remaining: 16.1s
# 1658:	total: 1m 18s	remaining: 16.1s
# 1659:	total: 1m 18s	remaining: 16.1s
# 1660:	total: 1m 18s	remaining: 16s
# 1661:	total: 1m 18s	remaining: 16s
# 1662:	total: 1m 18s	remaining: 15.9s
# 1663:	total: 1m 18s	remaining: 15.9s
# 1664:	total: 1m 18s	remaining: 15.8s
# 1665:	total: 1m 18s	remaining: 15.8s
# 1666:	total: 1m 18s	remaining: 15.7s
# 1667:	total: 1m 18s	remaining: 15.7s
# 1668:	total: 1m 18s	remaining: 15.6s
# 1669:	total: 1m 18s	remaining: 15.6s
# 1670:	total: 1m 18s	remaining: 15.5s
# 1671:	total: 1m 18s	remaining: 15.5s
# 1672:	total: 1m 19s	remaining: 15.4s
# 1673:	total: 1m 19s	remaining: 15.4s
# 1674:	total: 1m 19s	remaining: 15.3s
# 1675:	total: 1m 19s	remaining: 15.3s
# 1676:	total: 1m 19s	remaining: 15.3s
# 1677:	total: 1m 19s	remaining: 15.2s
# 1678:	total: 1m 19s	remaining: 15.2s
# 1679:	total: 1m 19s	remaining: 15.1s
# 1680:	total: 1m 19s	remaining: 15.1s
# 1681:	total: 1m 19s	remaining: 15s
# 1682:	total: 1m 19s	remaining: 15s
# 1683:	total: 1m 19s	remaining: 14.9s
# 1684:	total: 1m 19s	remaining: 14.9s
# 1685:	total: 1m 19s	remaining: 14.8s
# 1686:	total: 1m 19s	remaining: 14.8s
# 1687:	total: 1m 19s	remaining: 14.7s
# 1688:	total: 1m 19s	remaining: 14.7s
# 1689:	total: 1m 19s	remaining: 14.6s
# 1690:	total: 1m 19s	remaining: 14.6s
# 1691:	total: 1m 19s	remaining: 14.5s
# 1692:	total: 1m 19s	remaining: 14.5s
# 1693:	total: 1m 19s	remaining: 14.4s
# 1694:	total: 1m 20s	remaining: 14.4s
# 1695:	total: 1m 20s	remaining: 14.3s
# 1696:	total: 1m 20s	remaining: 14.3s
# 1697:	total: 1m 20s	remaining: 14.3s
# 1698:	total: 1m 20s	remaining: 14.2s
# 1699:	total: 1m 20s	remaining: 14.2s
# 1700:	total: 1m 20s	remaining: 14.1s
# 1701:	total: 1m 20s	remaining: 14.1s
# 1702:	total: 1m 20s	remaining: 14s
# 1703:	total: 1m 20s	remaining: 14s
# 1704:	total: 1m 20s	remaining: 13.9s
# 1705:	total: 1m 20s	remaining: 13.9s
# 1706:	total: 1m 20s	remaining: 13.8s
# 1707:	total: 1m 20s	remaining: 13.8s
# 1708:	total: 1m 20s	remaining: 13.7s
# 1709:	total: 1m 20s	remaining: 13.7s
# 1710:	total: 1m 20s	remaining: 13.6s
# 1711:	total: 1m 20s	remaining: 13.6s
# 1712:	total: 1m 20s	remaining: 13.5s
# 1713:	total: 1m 20s	remaining: 13.5s
# 1714:	total: 1m 20s	remaining: 13.4s
# 1715:	total: 1m 20s	remaining: 13.4s
# 1716:	total: 1m 20s	remaining: 13.3s
# 1717:	total: 1m 21s	remaining: 13.3s
# 1718:	total: 1m 21s	remaining: 13.2s
# 1719:	total: 1m 21s	remaining: 13.2s
# 1720:	total: 1m 21s	remaining: 13.2s
# 1721:	total: 1m 21s	remaining: 13.1s
# 1722:	total: 1m 21s	remaining: 13.1s
# 1723:	total: 1m 21s	remaining: 13s
# 1724:	total: 1m 21s	remaining: 13s
# 1725:	total: 1m 21s	remaining: 12.9s
# 1726:	total: 1m 21s	remaining: 12.9s
# 1727:	total: 1m 21s	remaining: 12.8s
# 1728:	total: 1m 21s	remaining: 12.8s
# 1729:	total: 1m 21s	remaining: 12.7s
# 1730:	total: 1m 21s	remaining: 12.7s
# 1731:	total: 1m 21s	remaining: 12.6s
# 1732:	total: 1m 21s	remaining: 12.6s
# 1733:	total: 1m 21s	remaining: 12.5s
# 1734:	total: 1m 21s	remaining: 12.5s
# 1735:	total: 1m 21s	remaining: 12.4s
# 1736:	total: 1m 21s	remaining: 12.4s
# 1737:	total: 1m 21s	remaining: 12.3s
# 1738:	total: 1m 21s	remaining: 12.3s
# 1739:	total: 1m 21s	remaining: 12.2s
# 1740:	total: 1m 21s	remaining: 12.2s
# 1741:	total: 1m 22s	remaining: 12.1s
# 1742:	total: 1m 22s	remaining: 12.1s
# 1743:	total: 1m 22s	remaining: 12.1s
# 1744:	total: 1m 22s	remaining: 12s
# 1745:	total: 1m 22s	remaining: 12s
# 1746:	total: 1m 22s	remaining: 11.9s
# 1747:	total: 1m 22s	remaining: 11.9s
# 1748:	total: 1m 22s	remaining: 11.8s
# 1749:	total: 1m 22s	remaining: 11.8s
# 1750:	total: 1m 22s	remaining: 11.7s
# 1751:	total: 1m 22s	remaining: 11.7s
# 1752:	total: 1m 22s	remaining: 11.6s
# 1753:	total: 1m 22s	remaining: 11.6s
# 1754:	total: 1m 22s	remaining: 11.5s
# 1755:	total: 1m 22s	remaining: 11.5s
# 1756:	total: 1m 22s	remaining: 11.4s
# 1757:	total: 1m 22s	remaining: 11.4s
# 1758:	total: 1m 22s	remaining: 11.3s
# 1759:	total: 1m 22s	remaining: 11.3s
# 1760:	total: 1m 22s	remaining: 11.2s
# 1761:	total: 1m 22s	remaining: 11.2s
# 1762:	total: 1m 22s	remaining: 11.1s
# 1763:	total: 1m 22s	remaining: 11.1s
# 1764:	total: 1m 23s	remaining: 11.1s
# 1765:	total: 1m 23s	remaining: 11s
# 1766:	total: 1m 23s	remaining: 11s
# 1767:	total: 1m 23s	remaining: 10.9s
# 1768:	total: 1m 23s	remaining: 10.9s
# 1769:	total: 1m 23s	remaining: 10.8s
# 1770:	total: 1m 23s	remaining: 10.8s
# 1771:	total: 1m 23s	remaining: 10.7s
# 1772:	total: 1m 23s	remaining: 10.7s
# 1773:	total: 1m 23s	remaining: 10.6s
# 1774:	total: 1m 23s	remaining: 10.6s
# 1775:	total: 1m 23s	remaining: 10.5s
# 1776:	total: 1m 23s	remaining: 10.5s
# 1777:	total: 1m 23s	remaining: 10.4s
# 1778:	total: 1m 23s	remaining: 10.4s
# 1779:	total: 1m 23s	remaining: 10.3s
# 1780:	total: 1m 23s	remaining: 10.3s
# 1781:	total: 1m 23s	remaining: 10.2s
# 1782:	total: 1m 23s	remaining: 10.2s
# 1783:	total: 1m 23s	remaining: 10.1s
# 1784:	total: 1m 23s	remaining: 10.1s
# 1785:	total: 1m 23s	remaining: 10.1s
# 1786:	total: 1m 23s	remaining: 10s
# 1787:	total: 1m 24s	remaining: 9.96s
# 1788:	total: 1m 24s	remaining: 9.91s
# 1789:	total: 1m 24s	remaining: 9.86s
# 1790:	total: 1m 24s	remaining: 9.82s
# 1791:	total: 1m 24s	remaining: 9.77s
# 1792:	total: 1m 24s	remaining: 9.72s
# 1793:	total: 1m 24s	remaining: 9.68s
# 1794:	total: 1m 24s	remaining: 9.63s
# 1795:	total: 1m 24s	remaining: 9.58s
# 1796:	total: 1m 24s	remaining: 9.53s
# 1797:	total: 1m 24s	remaining: 9.49s
# 1798:	total: 1m 24s	remaining: 9.44s
# 1799:	total: 1m 24s	remaining: 9.39s
# 1800:	total: 1m 24s	remaining: 9.34s
# 1801:	total: 1m 24s	remaining: 9.3s
# 1802:	total: 1m 24s	remaining: 9.25s
# 1803:	total: 1m 24s	remaining: 9.2s
# 1804:	total: 1m 24s	remaining: 9.15s
# 1805:	total: 1m 24s	remaining: 9.11s
# 1806:	total: 1m 24s	remaining: 9.06s
# 1807:	total: 1m 24s	remaining: 9.01s
# 1808:	total: 1m 24s	remaining: 8.97s
# 1809:	total: 1m 24s	remaining: 8.92s
# 1810:	total: 1m 25s	remaining: 8.87s
# 1811:	total: 1m 25s	remaining: 8.82s
# 1812:	total: 1m 25s	remaining: 8.78s
# 1813:	total: 1m 25s	remaining: 8.73s
# 1814:	total: 1m 25s	remaining: 8.68s
# 1815:	total: 1m 25s	remaining: 8.63s
# 1816:	total: 1m 25s	remaining: 8.59s
# 1817:	total: 1m 25s	remaining: 8.54s
# 1818:	total: 1m 25s	remaining: 8.49s
# 1819:	total: 1m 25s	remaining: 8.45s
# 1820:	total: 1m 25s	remaining: 8.4s
# 1821:	total: 1m 25s	remaining: 8.35s
# 1822:	total: 1m 25s	remaining: 8.3s
# 1823:	total: 1m 25s	remaining: 8.26s
# 1824:	total: 1m 25s	remaining: 8.21s
# 1825:	total: 1m 25s	remaining: 8.16s
# 1826:	total: 1m 25s	remaining: 8.11s
# 1827:	total: 1m 25s	remaining: 8.07s
# 1828:	total: 1m 25s	remaining: 8.02s
# 1829:	total: 1m 25s	remaining: 7.97s
# 1830:	total: 1m 25s	remaining: 7.92s
# 1831:	total: 1m 25s	remaining: 7.88s
# 1832:	total: 1m 25s	remaining: 7.83s
# 1833:	total: 1m 26s	remaining: 7.78s
# 1834:	total: 1m 26s	remaining: 7.74s
# 1835:	total: 1m 26s	remaining: 7.69s
# 1836:	total: 1m 26s	remaining: 7.64s
# 1837:	total: 1m 26s	remaining: 7.59s
# 1838:	total: 1m 26s	remaining: 7.55s
# 1839:	total: 1m 26s	remaining: 7.5s
# 1840:	total: 1m 26s	remaining: 7.45s
# 1841:	total: 1m 26s	remaining: 7.41s
# 1842:	total: 1m 26s	remaining: 7.36s
# 1843:	total: 1m 26s	remaining: 7.31s
# 1844:	total: 1m 26s	remaining: 7.27s
# 1845:	total: 1m 26s	remaining: 7.22s
# 1846:	total: 1m 26s	remaining: 7.17s
# 1847:	total: 1m 26s	remaining: 7.13s
# 1848:	total: 1m 26s	remaining: 7.08s
# 1849:	total: 1m 26s	remaining: 7.03s
# 1850:	total: 1m 26s	remaining: 6.98s
# 1851:	total: 1m 26s	remaining: 6.93s
# 1852:	total: 1m 26s	remaining: 6.89s
# 1853:	total: 1m 26s	remaining: 6.84s
# 1854:	total: 1m 26s	remaining: 6.79s
# 1855:	total: 1m 26s	remaining: 6.75s
# 1856:	total: 1m 27s	remaining: 6.7s
# 1857:	total: 1m 27s	remaining: 6.65s
# 1858:	total: 1m 27s	remaining: 6.61s
# 1859:	total: 1m 27s	remaining: 6.56s
# 1860:	total: 1m 27s	remaining: 6.51s
# 1861:	total: 1m 27s	remaining: 6.46s
# 1862:	total: 1m 27s	remaining: 6.42s
# 1863:	total: 1m 27s	remaining: 6.37s
# 1864:	total: 1m 27s	remaining: 6.32s
# 1865:	total: 1m 27s	remaining: 6.28s
# 1866:	total: 1m 27s	remaining: 6.23s
# 1867:	total: 1m 27s	remaining: 6.18s
# 1868:	total: 1m 27s	remaining: 6.13s
# 1869:	total: 1m 27s	remaining: 6.09s
# 1870:	total: 1m 27s	remaining: 6.04s
# 1871:	total: 1m 27s	remaining: 5.99s
# 1872:	total: 1m 27s	remaining: 5.95s
# 1873:	total: 1m 27s	remaining: 5.9s
# 1874:	total: 1m 27s	remaining: 5.85s
# 1875:	total: 1m 27s	remaining: 5.8s
# 1876:	total: 1m 27s	remaining: 5.76s
# 1877:	total: 1m 27s	remaining: 5.71s
# 1878:	total: 1m 27s	remaining: 5.66s
# 1879:	total: 1m 28s	remaining: 5.62s
# 1880:	total: 1m 28s	remaining: 5.57s
# 1881:	total: 1m 28s	remaining: 5.52s
# 1882:	total: 1m 28s	remaining: 5.47s
# 1883:	total: 1m 28s	remaining: 5.43s
# 1884:	total: 1m 28s	remaining: 5.38s
# 1885:	total: 1m 28s	remaining: 5.33s
# 1886:	total: 1m 28s	remaining: 5.29s
# 1887:	total: 1m 28s	remaining: 5.24s
# 1888:	total: 1m 28s	remaining: 5.19s
# 1889:	total: 1m 28s	remaining: 5.15s
# 1890:	total: 1m 28s	remaining: 5.1s
# 1891:	total: 1m 28s	remaining: 5.05s
# 1892:	total: 1m 28s	remaining: 5s
# 1893:	total: 1m 28s	remaining: 4.96s
# 1894:	total: 1m 28s	remaining: 4.91s
# 1895:	total: 1m 28s	remaining: 4.86s
# 1896:	total: 1m 28s	remaining: 4.82s
# 1897:	total: 1m 28s	remaining: 4.77s
# 1898:	total: 1m 28s	remaining: 4.72s
# 1899:	total: 1m 28s	remaining: 4.68s
# 1900:	total: 1m 28s	remaining: 4.63s
# 1901:	total: 1m 28s	remaining: 4.58s
# 1902:	total: 1m 28s	remaining: 4.54s
# 1903:	total: 1m 29s	remaining: 4.49s
# 1904:	total: 1m 29s	remaining: 4.44s
# 1905:	total: 1m 29s	remaining: 4.39s
# 1906:	total: 1m 29s	remaining: 4.35s
# 1907:	total: 1m 29s	remaining: 4.3s
# 1908:	total: 1m 29s	remaining: 4.25s
# 1909:	total: 1m 29s	remaining: 4.21s
# 1910:	total: 1m 29s	remaining: 4.16s
# 1911:	total: 1m 29s	remaining: 4.12s
# 1912:	total: 1m 29s	remaining: 4.07s
# 1913:	total: 1m 29s	remaining: 4.02s
# 1914:	total: 1m 29s	remaining: 3.97s
# 1915:	total: 1m 29s	remaining: 3.93s
# 1916:	total: 1m 29s	remaining: 3.88s
# 1917:	total: 1m 29s	remaining: 3.83s
# 1918:	total: 1m 29s	remaining: 3.79s
# 1919:	total: 1m 29s	remaining: 3.74s
# 1920:	total: 1m 29s	remaining: 3.69s
# 1921:	total: 1m 29s	remaining: 3.65s
# 1922:	total: 1m 29s	remaining: 3.6s
# 1923:	total: 1m 29s	remaining: 3.55s
# 1924:	total: 1m 29s	remaining: 3.5s
# 1925:	total: 1m 30s	remaining: 3.46s
# 1926:	total: 1m 30s	remaining: 3.41s
# 1927:	total: 1m 30s	remaining: 3.37s
# 1928:	total: 1m 30s	remaining: 3.32s
# 1929:	total: 1m 30s	remaining: 3.27s
# 1930:	total: 1m 30s	remaining: 3.22s
# 1931:	total: 1m 30s	remaining: 3.18s
# 1932:	total: 1m 30s	remaining: 3.13s
# 1933:	total: 1m 30s	remaining: 3.08s
# 1934:	total: 1m 30s	remaining: 3.04s
# 1935:	total: 1m 30s	remaining: 2.99s
# 1936:	total: 1m 30s	remaining: 2.94s
# 1937:	total: 1m 30s	remaining: 2.9s
# 1938:	total: 1m 30s	remaining: 2.85s
# 1939:	total: 1m 30s	remaining: 2.8s
# 1940:	total: 1m 30s	remaining: 2.75s
# 1941:	total: 1m 30s	remaining: 2.71s
# 1942:	total: 1m 30s	remaining: 2.66s
# 1943:	total: 1m 30s	remaining: 2.62s
# 1944:	total: 1m 30s	remaining: 2.57s
# 1945:	total: 1m 30s	remaining: 2.52s
# 1946:	total: 1m 30s	remaining: 2.47s
# 1947:	total: 1m 30s	remaining: 2.43s
# 1948:	total: 1m 31s	remaining: 2.38s
# 1949:	total: 1m 31s	remaining: 2.33s
# 1950:	total: 1m 31s	remaining: 2.29s
# 1951:	total: 1m 31s	remaining: 2.24s
# 1952:	total: 1m 31s	remaining: 2.19s
# 1953:	total: 1m 31s	remaining: 2.15s
# 1954:	total: 1m 31s	remaining: 2.1s
# 1955:	total: 1m 31s	remaining: 2.05s
# 1956:	total: 1m 31s	remaining: 2.01s
# 1957:	total: 1m 31s	remaining: 1.96s
# 1958:	total: 1m 31s	remaining: 1.91s
# 1959:	total: 1m 31s	remaining: 1.87s
# 1960:	total: 1m 31s	remaining: 1.82s
# 1961:	total: 1m 31s	remaining: 1.77s
# 1962:	total: 1m 31s	remaining: 1.73s
# 1963:	total: 1m 31s	remaining: 1.68s
# 1964:	total: 1m 31s	remaining: 1.63s
# 1965:	total: 1m 31s	remaining: 1.59s
# 1966:	total: 1m 31s	remaining: 1.54s
# 1967:	total: 1m 31s	remaining: 1.49s
# 1968:	total: 1m 31s	remaining: 1.45s
# 1969:	total: 1m 31s	remaining: 1.4s
# 1970:	total: 1m 31s	remaining: 1.35s
# 1971:	total: 1m 31s	remaining: 1.3s
# 1972:	total: 1m 32s	remaining: 1.26s
# 1973:	total: 1m 32s	remaining: 1.21s
# 1974:	total: 1m 32s	remaining: 1.17s
# 1975:	total: 1m 32s	remaining: 1.12s
# 1976:	total: 1m 32s	remaining: 1.07s
# 1977:	total: 1m 32s	remaining: 1.02s
# 1978:	total: 1m 32s	remaining: 979ms
# 1979:	total: 1m 32s	remaining: 932ms
# 1980:	total: 1m 32s	remaining: 886ms
# 1981:	total: 1m 32s	remaining: 839ms
# 1982:	total: 1m 32s	remaining: 793ms
# 1983:	total: 1m 32s	remaining: 746ms
# 1984:	total: 1m 32s	remaining: 699ms
# 1985:	total: 1m 32s	remaining: 653ms
# 1986:	total: 1m 32s	remaining: 606ms
# 1987:	total: 1m 32s	remaining: 559ms
# 1988:	total: 1m 32s	remaining: 513ms
# 1989:	total: 1m 32s	remaining: 466ms
# 1990:	total: 1m 32s	remaining: 420ms
# 1991:	total: 1m 32s	remaining: 373ms
# 1992:	total: 1m 32s	remaining: 326ms
# 1993:	total: 1m 32s	remaining: 280ms
# 1994:	total: 1m 32s	remaining: 233ms
# 1995:	total: 1m 33s	remaining: 186ms
# 1996:	total: 1m 33s	remaining: 140ms
# 1997:	total: 1m 33s	remaining: 93.2ms
# 1998:	total: 1m 33s	remaining: 46.6ms
# 1999:	total: 1m 33s	remaining: 0us

# %%
print("Time Taken to train: {}".format(end_time - start_time))
# Out:
# Time Taken to train: 96.46015167236328

# %% [markdown]
# `Model Testing:`

# %%
y_pred_cat = cat_classifier.predict(X_test)

# %%
print("Accuracy Score: {}".format(accuracy_score(y_test,y_pred_cat)))
# Out:
# Accuracy Score: 0.8647394472707274

# %% [markdown]
# `Checking for Overfitting and Under Fitting:`

# %%
print("Train Data Score: {}".format(cat_classifier.score(X_train, y_train)))
print("Test Data Score: {}".format(cat_classifier.score(X_test, y_test)))
# Out:
# Train Data Score: 0.8917743709610889
# Test Data Score: 0.8647394472707274

# %% [markdown]
# _`Accuracy Score of Training and Testing Data is comparable and almost equal. So, there is no question of Underfitting and Over Fitting. And model is generalizing well for new unseen data.`_

# %%
# Confusion Matrix:

print("Confusion Matrix:")
print("\n",confusion_matrix(y_test,y_pred_cat))
# Out:
# Confusion Matrix:
#
#  [[21634  1092]
#  [ 2843  3523]]

# %%
# classification Report:

print("classification_report:")
print("\n",classification_report(y_test,y_pred_cat))
# Out:
# classification_report:
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92     22726
#            1       0.76      0.55      0.64      6366
#
#     accuracy                           0.86     29092
#    macro avg       0.82      0.75      0.78     29092
# weighted avg       0.86      0.86      0.86     29092

# %%
# predicting the probabilities:

y_pred_cat_proba = cat_classifier.predict_proba(X_test)

# %%
# Finding True Positive Rate(tpr), False Positive Rate(fpr), threshold values to plot ROC curve  

from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_cat_proba[:,1])

# %%
# plotting ROC Curve:

plt.figure(figsize=(6,4))
plt.plot(fpr,tpr,'-g',linewidth=1)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve for Cat Boost Model')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()

# %%
#finding ROC AUC Scores:

from sklearn.metrics import roc_auc_score
print('ROC AUC Scores: {}'.format(roc_auc_score(y_test, y_pred_cat)))
# Out:
# ROC AUC Scores: 0.7526790215300754

# %% [markdown]
# <br>

# %% [markdown]
# `Finding whether model performance can be improved using Cross Validation Score:`

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(cat_classifier, X_train, y_train, cv = 5, scoring='accuracy')
print('Cross-validation scores:{}'.format(scores))
# Out:
# Learning rate set to 0.037811
# 0:	total: 71.8ms	remaining: 2m 23s
# 1:	total: 154ms	remaining: 2m 33s
# 2:	total: 243ms	remaining: 2m 41s
# 3:	total: 353ms	remaining: 2m 56s
# 4:	total: 439ms	remaining: 2m 55s
# 5:	total: 537ms	remaining: 2m 58s
# 6:	total: 644ms	remaining: 3m 3s
# 7:	total: 725ms	remaining: 3m
# 8:	total: 836ms	remaining: 3m 4s
# 9:	total: 920ms	remaining: 3m 3s
# 10:	total: 1s	remaining: 3m 1s
# 11:	total: 1.11s	remaining: 3m 3s
# 12:	total: 1.2s	remaining: 3m 3s
# 13:	total: 1.31s	remaining: 3m 6s
# 14:	total: 1.43s	remaining: 3m 9s
# 15:	total: 1.51s	remaining: 3m 6s
# 16:	total: 1.6s	remaining: 3m 6s
# 17:	total: 1.68s	remaining: 3m 5s
# 18:	total: 1.76s	remaining: 3m 3s
# 19:	total: 1.84s	remaining: 3m 2s
# 20:	total: 1.9s	remaining: 2m 59s
# 21:	total: 1.97s	remaining: 2m 56s
# 22:	total: 2.05s	remaining: 2m 56s
# 23:	total: 2.13s	remaining: 2m 55s
# 24:	total: 2.2s	remaining: 2m 53s
# 25:	total: 2.28s	remaining: 2m 53s
# 26:	total: 2.33s	remaining: 2m 50s
# 27:	total: 2.39s	remaining: 2m 48s
# 28:	total: 2.46s	remaining: 2m 47s
# 29:	total: 2.53s	remaining: 2m 46s
# 30:	total: 2.58s	remaining: 2m 44s
# 31:	total: 2.66s	remaining: 2m 43s
# 32:	total: 2.71s	remaining: 2m 41s
# 33:	total: 2.77s	remaining: 2m 39s
# 34:	total: 2.83s	remaining: 2m 38s
# 35:	total: 2.88s	remaining: 2m 37s
# 36:	total: 2.93s	remaining: 2m 35s
# 37:	total: 2.98s	remaining: 2m 33s
# 38:	total: 3.04s	remaining: 2m 33s
# 39:	total: 3.11s	remaining: 2m 32s
# 40:	total: 3.16s	remaining: 2m 30s
# 41:	total: 3.21s	remaining: 2m 29s
# 42:	total: 3.26s	remaining: 2m 28s
# 43:	total: 3.31s	remaining: 2m 27s
# 44:	total: 3.35s	remaining: 2m 25s
# 45:	total: 3.41s	remaining: 2m 24s
# 46:	total: 3.46s	remaining: 2m 23s
# 47:	total: 3.5s	remaining: 2m 22s
# 48:	total: 3.54s	remaining: 2m 20s
# 49:	total: 3.6s	remaining: 2m 20s
# 50:	total: 3.66s	remaining: 2m 20s
# 51:	total: 3.72s	remaining: 2m 19s
# 52:	total: 3.77s	remaining: 2m 18s
# 53:	total: 3.82s	remaining: 2m 17s
# 54:	total: 3.86s	remaining: 2m 16s
# 55:	total: 3.91s	remaining: 2m 15s
# 56:	total: 3.96s	remaining: 2m 15s
# 57:	total: 4.01s	remaining: 2m 14s
# 58:	total: 4.05s	remaining: 2m 13s
# 59:	total: 4.09s	remaining: 2m 12s
# 60:	total: 4.13s	remaining: 2m 11s
# 61:	total: 4.18s	remaining: 2m 10s
# 62:	total: 4.21s	remaining: 2m 9s
# 63:	total: 4.25s	remaining: 2m 8s
# 64:	total: 4.29s	remaining: 2m 7s
# 65:	total: 4.35s	remaining: 2m 7s
# 66:	total: 4.39s	remaining: 2m 6s
# 67:	total: 4.42s	remaining: 2m 5s
# 68:	total: 4.46s	remaining: 2m 4s
# 69:	total: 4.5s	remaining: 2m 4s
# 70:	total: 4.54s	remaining: 2m 3s
# 71:	total: 4.58s	remaining: 2m 2s
# 72:	total: 4.61s	remaining: 2m 1s
# 73:	total: 4.64s	remaining: 2m
# 74:	total: 4.68s	remaining: 2m
# 75:	total: 4.72s	remaining: 1m 59s
# 76:	total: 4.76s	remaining: 1m 58s
# 77:	total: 4.8s	remaining: 1m 58s
# 78:	total: 4.83s	remaining: 1m 57s
# 79:	total: 4.87s	remaining: 1m 56s
# 80:	total: 4.9s	remaining: 1m 56s
# 81:	total: 4.96s	remaining: 1m 55s
# 82:	total: 4.99s	remaining: 1m 55s
# 83:	total: 5.03s	remaining: 1m 54s
# 84:	total: 5.07s	remaining: 1m 54s
# 85:	total: 5.1s	remaining: 1m 53s
# 86:	total: 5.14s	remaining: 1m 52s
# 87:	total: 5.18s	remaining: 1m 52s
# 88:	total: 5.21s	remaining: 1m 51s
# 89:	total: 5.24s	remaining: 1m 51s
# 90:	total: 5.28s	remaining: 1m 50s
# 91:	total: 5.31s	remaining: 1m 50s
# 92:	total: 5.35s	remaining: 1m 49s
# 93:	total: 5.38s	remaining: 1m 49s
# 94:	total: 5.42s	remaining: 1m 48s
# 95:	total: 5.46s	remaining: 1m 48s
# 96:	total: 5.49s	remaining: 1m 47s
# 97:	total: 5.53s	remaining: 1m 47s
# 98:	total: 5.57s	remaining: 1m 46s
# 99:	total: 5.6s	remaining: 1m 46s
# 100:	total: 5.64s	remaining: 1m 46s
# 101:	total: 5.67s	remaining: 1m 45s
# 102:	total: 5.71s	remaining: 1m 45s
# 103:	total: 5.75s	remaining: 1m 44s
# 104:	total: 5.79s	remaining: 1m 44s
# 105:	total: 5.82s	remaining: 1m 43s
# 106:	total: 5.86s	remaining: 1m 43s
# 107:	total: 5.92s	remaining: 1m 43s
# 108:	total: 5.97s	remaining: 1m 43s
# 109:	total: 6.01s	remaining: 1m 43s
# 110:	total: 6.04s	remaining: 1m 42s
# 111:	total: 6.08s	remaining: 1m 42s
# 112:	total: 6.11s	remaining: 1m 42s
# 113:	total: 6.15s	remaining: 1m 41s
# 114:	total: 6.19s	remaining: 1m 41s
# 115:	total: 6.23s	remaining: 1m 41s
# 116:	total: 6.26s	remaining: 1m 40s
# 117:	total: 6.3s	remaining: 1m 40s
# 118:	total: 6.33s	remaining: 1m 40s
# 119:	total: 6.37s	remaining: 1m 39s
# 120:	total: 6.4s	remaining: 1m 39s
# 121:	total: 6.43s	remaining: 1m 39s
# 122:	total: 6.47s	remaining: 1m 38s
# 123:	total: 6.5s	remaining: 1m 38s
# 124:	total: 6.54s	remaining: 1m 38s
# 125:	total: 6.58s	remaining: 1m 37s
# 126:	total: 6.62s	remaining: 1m 37s
# 127:	total: 6.65s	remaining: 1m 37s
# 128:	total: 6.69s	remaining: 1m 37s
# 129:	total: 6.73s	remaining: 1m 36s
# 130:	total: 6.76s	remaining: 1m 36s
# 131:	total: 6.8s	remaining: 1m 36s
# 132:	total: 6.84s	remaining: 1m 35s
# 133:	total: 6.87s	remaining: 1m 35s
# 134:	total: 6.9s	remaining: 1m 35s
# 135:	total: 6.94s	remaining: 1m 35s
# 136:	total: 6.97s	remaining: 1m 34s
# 137:	total: 7.01s	remaining: 1m 34s
# 138:	total: 7.04s	remaining: 1m 34s
# 139:	total: 7.08s	remaining: 1m 34s
# 140:	total: 7.11s	remaining: 1m 33s
# 141:	total: 7.15s	remaining: 1m 33s
# 142:	total: 7.19s	remaining: 1m 33s
# 143:	total: 7.22s	remaining: 1m 33s
# 144:	total: 7.26s	remaining: 1m 32s
# 145:	total: 7.3s	remaining: 1m 32s
# 146:	total: 7.33s	remaining: 1m 32s
# 147:	total: 7.37s	remaining: 1m 32s
# 148:	total: 7.41s	remaining: 1m 32s
# 149:	total: 7.44s	remaining: 1m 31s
# 150:	total: 7.48s	remaining: 1m 31s
# 151:	total: 7.51s	remaining: 1m 31s
# 152:	total: 7.56s	remaining: 1m 31s
# 153:	total: 7.59s	remaining: 1m 30s
# 154:	total: 7.62s	remaining: 1m 30s
# 155:	total: 7.66s	remaining: 1m 30s
# 156:	total: 7.69s	remaining: 1m 30s
# 157:	total: 7.73s	remaining: 1m 30s
# 158:	total: 7.76s	remaining: 1m 29s
# 159:	total: 7.79s	remaining: 1m 29s
# 160:	total: 7.83s	remaining: 1m 29s
# 161:	total: 7.86s	remaining: 1m 29s
# 162:	total: 7.9s	remaining: 1m 28s
# 163:	total: 7.94s	remaining: 1m 28s
# 164:	total: 7.98s	remaining: 1m 28s
# 165:	total: 8.02s	remaining: 1m 28s
# 166:	total: 8.05s	remaining: 1m 28s
# 167:	total: 8.09s	remaining: 1m 28s
# 168:	total: 8.13s	remaining: 1m 28s
# 169:	total: 8.16s	remaining: 1m 27s
# 170:	total: 8.2s	remaining: 1m 27s
# 171:	total: 8.23s	remaining: 1m 27s
# 172:	total: 8.27s	remaining: 1m 27s
# 173:	total: 8.31s	remaining: 1m 27s
# 174:	total: 8.34s	remaining: 1m 27s
# 175:	total: 8.38s	remaining: 1m 26s
# 176:	total: 8.42s	remaining: 1m 26s
# 177:	total: 8.45s	remaining: 1m 26s
# 178:	total: 8.49s	remaining: 1m 26s
# 179:	total: 8.53s	remaining: 1m 26s
# 180:	total: 8.56s	remaining: 1m 26s
# 181:	total: 8.6s	remaining: 1m 25s
# 182:	total: 8.63s	remaining: 1m 25s
# 183:	total: 8.67s	remaining: 1m 25s
# 184:	total: 8.71s	remaining: 1m 25s
# 185:	total: 8.74s	remaining: 1m 25s
# 186:	total: 8.78s	remaining: 1m 25s
# 187:	total: 8.81s	remaining: 1m 24s
# 188:	total: 8.85s	remaining: 1m 24s
# 189:	total: 8.89s	remaining: 1m 24s
# 190:	total: 8.93s	remaining: 1m 24s
# 191:	total: 8.97s	remaining: 1m 24s
# 192:	total: 9.01s	remaining: 1m 24s
# 193:	total: 9.04s	remaining: 1m 24s
# 194:	total: 9.08s	remaining: 1m 24s
# 195:	total: 9.12s	remaining: 1m 23s
# 196:	total: 9.15s	remaining: 1m 23s
# 197:	total: 9.19s	remaining: 1m 23s
# 198:	total: 9.22s	remaining: 1m 23s
# 199:	total: 9.26s	remaining: 1m 23s
# 200:	total: 9.3s	remaining: 1m 23s
# 201:	total: 9.33s	remaining: 1m 23s
# 202:	total: 9.37s	remaining: 1m 22s
# 203:	total: 9.4s	remaining: 1m 22s
# 204:	total: 9.45s	remaining: 1m 22s
# 205:	total: 9.48s	remaining: 1m 22s
# 206:	total: 9.52s	remaining: 1m 22s
# 207:	total: 9.55s	remaining: 1m 22s
# 208:	total: 9.58s	remaining: 1m 22s
# 209:	total: 9.63s	remaining: 1m 22s
# 210:	total: 9.66s	remaining: 1m 21s
# 211:	total: 9.7s	remaining: 1m 21s
# 212:	total: 9.73s	remaining: 1m 21s
# 213:	total: 9.77s	remaining: 1m 21s
# 214:	total: 9.8s	remaining: 1m 21s
# 215:	total: 9.84s	remaining: 1m 21s
# 216:	total: 9.87s	remaining: 1m 21s
# 217:	total: 9.91s	remaining: 1m 21s
# 218:	total: 9.94s	remaining: 1m 20s
# 219:	total: 9.98s	remaining: 1m 20s
# 220:	total: 10s	remaining: 1m 20s
# 221:	total: 10.1s	remaining: 1m 20s
# 222:	total: 10.1s	remaining: 1m 20s
# 223:	total: 10.1s	remaining: 1m 20s
# 224:	total: 10.2s	remaining: 1m 20s
# 225:	total: 10.2s	remaining: 1m 20s
# 226:	total: 10.2s	remaining: 1m 19s
# 227:	total: 10.3s	remaining: 1m 19s
# 228:	total: 10.3s	remaining: 1m 19s
# 229:	total: 10.3s	remaining: 1m 19s
# 230:	total: 10.4s	remaining: 1m 19s
# 231:	total: 10.4s	remaining: 1m 19s
# 232:	total: 10.4s	remaining: 1m 19s
# 233:	total: 10.5s	remaining: 1m 19s
# 234:	total: 10.5s	remaining: 1m 18s
# 235:	total: 10.6s	remaining: 1m 18s
# 236:	total: 10.6s	remaining: 1m 18s
# 237:	total: 10.6s	remaining: 1m 18s
# 238:	total: 10.7s	remaining: 1m 18s
# 239:	total: 10.7s	remaining: 1m 18s
# 240:	total: 10.7s	remaining: 1m 18s
# 241:	total: 10.8s	remaining: 1m 18s
# 242:	total: 10.8s	remaining: 1m 18s
# 243:	total: 10.8s	remaining: 1m 18s
# 244:	total: 10.9s	remaining: 1m 17s
# 245:	total: 10.9s	remaining: 1m 17s
# 246:	total: 10.9s	remaining: 1m 17s
# 247:	total: 11s	remaining: 1m 17s
# 248:	total: 11s	remaining: 1m 17s
# 249:	total: 11.1s	remaining: 1m 17s
# 250:	total: 11.1s	remaining: 1m 17s
# 251:	total: 11.1s	remaining: 1m 17s
# 252:	total: 11.2s	remaining: 1m 17s
# 253:	total: 11.2s	remaining: 1m 16s
# 254:	total: 11.2s	remaining: 1m 16s
# 255:	total: 11.3s	remaining: 1m 16s
# 256:	total: 11.3s	remaining: 1m 16s
# 257:	total: 11.3s	remaining: 1m 16s
# 258:	total: 11.4s	remaining: 1m 16s
# 259:	total: 11.4s	remaining: 1m 16s
# 260:	total: 11.4s	remaining: 1m 16s
# 261:	total: 11.5s	remaining: 1m 16s
# 262:	total: 11.5s	remaining: 1m 16s
# 263:	total: 11.5s	remaining: 1m 15s
# 264:	total: 11.6s	remaining: 1m 15s
# 265:	total: 11.6s	remaining: 1m 15s
# 266:	total: 11.7s	remaining: 1m 15s
# 267:	total: 11.7s	remaining: 1m 15s
# 268:	total: 11.7s	remaining: 1m 15s
# 269:	total: 11.8s	remaining: 1m 15s
# 270:	total: 11.8s	remaining: 1m 15s
# 271:	total: 11.8s	remaining: 1m 15s
# 272:	total: 11.9s	remaining: 1m 15s
# 273:	total: 11.9s	remaining: 1m 15s
# 274:	total: 12s	remaining: 1m 15s
# 275:	total: 12s	remaining: 1m 14s
# 276:	total: 12s	remaining: 1m 14s
# 277:	total: 12.1s	remaining: 1m 14s
# 278:	total: 12.1s	remaining: 1m 14s
# 279:	total: 12.1s	remaining: 1m 14s
# 280:	total: 12.2s	remaining: 1m 14s
# 281:	total: 12.2s	remaining: 1m 14s
# 282:	total: 12.2s	remaining: 1m 14s
# 283:	total: 12.3s	remaining: 1m 14s
# 284:	total: 12.3s	remaining: 1m 14s
# 285:	total: 12.3s	remaining: 1m 13s
# 286:	total: 12.4s	remaining: 1m 13s
# 287:	total: 12.4s	remaining: 1m 13s
# 288:	total: 12.4s	remaining: 1m 13s
# 289:	total: 12.5s	remaining: 1m 13s
# 290:	total: 12.5s	remaining: 1m 13s
# 291:	total: 12.6s	remaining: 1m 13s
# 292:	total: 12.6s	remaining: 1m 13s
# 293:	total: 12.6s	remaining: 1m 13s
# 294:	total: 12.7s	remaining: 1m 13s
# 295:	total: 12.7s	remaining: 1m 13s
# 296:	total: 12.7s	remaining: 1m 13s
# 297:	total: 12.8s	remaining: 1m 12s
# 298:	total: 12.8s	remaining: 1m 12s
# 299:	total: 12.8s	remaining: 1m 12s
# 300:	total: 12.9s	remaining: 1m 12s
# 301:	total: 12.9s	remaining: 1m 12s
# 302:	total: 13s	remaining: 1m 12s
# 303:	total: 13s	remaining: 1m 12s
# 304:	total: 13s	remaining: 1m 12s
# 305:	total: 13.1s	remaining: 1m 12s
# 306:	total: 13.1s	remaining: 1m 12s
# 307:	total: 13.2s	remaining: 1m 12s
# 308:	total: 13.2s	remaining: 1m 12s
# 309:	total: 13.2s	remaining: 1m 12s
# 310:	total: 13.3s	remaining: 1m 11s
# 311:	total: 13.3s	remaining: 1m 11s
# 312:	total: 13.3s	remaining: 1m 11s
# 313:	total: 13.4s	remaining: 1m 11s
# 314:	total: 13.4s	remaining: 1m 11s
# 315:	total: 13.4s	remaining: 1m 11s
# 316:	total: 13.5s	remaining: 1m 11s
# 317:	total: 13.5s	remaining: 1m 11s
# 318:	total: 13.5s	remaining: 1m 11s
# 319:	total: 13.6s	remaining: 1m 11s
# 320:	total: 13.6s	remaining: 1m 11s
# 321:	total: 13.7s	remaining: 1m 11s
# 322:	total: 13.7s	remaining: 1m 11s
# 323:	total: 13.7s	remaining: 1m 11s
# 324:	total: 13.8s	remaining: 1m 10s
# 325:	total: 13.8s	remaining: 1m 10s
# 326:	total: 13.8s	remaining: 1m 10s
# 327:	total: 13.9s	remaining: 1m 10s
# 328:	total: 13.9s	remaining: 1m 10s
# 329:	total: 14s	remaining: 1m 10s
# 330:	total: 14s	remaining: 1m 10s
# 331:	total: 14.1s	remaining: 1m 10s
# 332:	total: 14.1s	remaining: 1m 10s
# 333:	total: 14.1s	remaining: 1m 10s
# 334:	total: 14.2s	remaining: 1m 10s
# 335:	total: 14.2s	remaining: 1m 10s
# 336:	total: 14.2s	remaining: 1m 10s
# 337:	total: 14.3s	remaining: 1m 10s
# 338:	total: 14.3s	remaining: 1m 10s
# 339:	total: 14.4s	remaining: 1m 10s
# 340:	total: 14.4s	remaining: 1m 10s
# 341:	total: 14.5s	remaining: 1m 10s
# 342:	total: 14.5s	remaining: 1m 10s
# 343:	total: 14.5s	remaining: 1m 9s
# 344:	total: 14.6s	remaining: 1m 9s
# 345:	total: 14.6s	remaining: 1m 9s
# 346:	total: 14.6s	remaining: 1m 9s
# 347:	total: 14.7s	remaining: 1m 9s
# 348:	total: 14.7s	remaining: 1m 9s
# 349:	total: 14.8s	remaining: 1m 9s
# 350:	total: 14.8s	remaining: 1m 9s
# 351:	total: 14.8s	remaining: 1m 9s
# 352:	total: 15s	remaining: 1m 9s
# 353:	total: 15s	remaining: 1m 9s
# 354:	total: 15.1s	remaining: 1m 9s
# 355:	total: 15.1s	remaining: 1m 9s
# 356:	total: 15.2s	remaining: 1m 9s
# 357:	total: 15.2s	remaining: 1m 9s
# 358:	total: 15.2s	remaining: 1m 9s
# 359:	total: 15.3s	remaining: 1m 9s
# 360:	total: 15.3s	remaining: 1m 9s
# 361:	total: 15.3s	remaining: 1m 9s
# 362:	total: 15.4s	remaining: 1m 9s
# 363:	total: 15.4s	remaining: 1m 9s
# 364:	total: 15.4s	remaining: 1m 9s
# 365:	total: 15.5s	remaining: 1m 9s
# 366:	total: 15.5s	remaining: 1m 9s
# 367:	total: 15.6s	remaining: 1m 9s
# 368:	total: 15.6s	remaining: 1m 9s
# 369:	total: 15.7s	remaining: 1m 8s
# 370:	total: 15.7s	remaining: 1m 8s
# 371:	total: 15.7s	remaining: 1m 8s
# 372:	total: 15.8s	remaining: 1m 8s
# 373:	total: 15.8s	remaining: 1m 8s
# 374:	total: 15.8s	remaining: 1m 8s
# 375:	total: 15.9s	remaining: 1m 8s
# 376:	total: 15.9s	remaining: 1m 8s
# 377:	total: 16s	remaining: 1m 8s
# 378:	total: 16s	remaining: 1m 8s
# 379:	total: 16s	remaining: 1m 8s
# 380:	total: 16.1s	remaining: 1m 8s
# 381:	total: 16.1s	remaining: 1m 8s
# 382:	total: 16.1s	remaining: 1m 8s
# 383:	total: 16.2s	remaining: 1m 8s
# 384:	total: 16.2s	remaining: 1m 7s
# 385:	total: 16.2s	remaining: 1m 7s
# 386:	total: 16.3s	remaining: 1m 7s
# 387:	total: 16.3s	remaining: 1m 7s
# 388:	total: 16.4s	remaining: 1m 7s
# 389:	total: 16.4s	remaining: 1m 7s
# 390:	total: 16.4s	remaining: 1m 7s
# 391:	total: 16.5s	remaining: 1m 7s
# 392:	total: 16.5s	remaining: 1m 7s
# 393:	total: 16.6s	remaining: 1m 7s
# 394:	total: 16.6s	remaining: 1m 7s
# 395:	total: 16.6s	remaining: 1m 7s
# 396:	total: 16.7s	remaining: 1m 7s
# 397:	total: 16.7s	remaining: 1m 7s
# 398:	total: 16.7s	remaining: 1m 7s
# 399:	total: 16.8s	remaining: 1m 7s
# 400:	total: 16.8s	remaining: 1m 7s
# 401:	total: 16.9s	remaining: 1m 6s
# 402:	total: 16.9s	remaining: 1m 6s
# 403:	total: 16.9s	remaining: 1m 6s
# 404:	total: 17s	remaining: 1m 6s
# 405:	total: 17s	remaining: 1m 6s
# 406:	total: 17s	remaining: 1m 6s
# 407:	total: 17.1s	remaining: 1m 6s
# 408:	total: 17.1s	remaining: 1m 6s
# 409:	total: 17.1s	remaining: 1m 6s
# 410:	total: 17.2s	remaining: 1m 6s
# 411:	total: 17.2s	remaining: 1m 6s
# 412:	total: 17.3s	remaining: 1m 6s
# 413:	total: 17.3s	remaining: 1m 6s
# 414:	total: 17.4s	remaining: 1m 6s
# 415:	total: 17.4s	remaining: 1m 6s
# 416:	total: 17.4s	remaining: 1m 6s
# 417:	total: 17.5s	remaining: 1m 6s
# 418:	total: 17.5s	remaining: 1m 6s
# 419:	total: 17.5s	remaining: 1m 5s
# 420:	total: 17.6s	remaining: 1m 5s
# 421:	total: 17.6s	remaining: 1m 5s
# 422:	total: 17.6s	remaining: 1m 5s
# 423:	total: 17.7s	remaining: 1m 5s
# 424:	total: 17.7s	remaining: 1m 5s
# 425:	total: 17.7s	remaining: 1m 5s
# 426:	total: 17.8s	remaining: 1m 5s
# 427:	total: 17.8s	remaining: 1m 5s
# 428:	total: 17.9s	remaining: 1m 5s
# 429:	total: 17.9s	remaining: 1m 5s
# 430:	total: 17.9s	remaining: 1m 5s
# 431:	total: 18s	remaining: 1m 5s
# 432:	total: 18s	remaining: 1m 5s
# 433:	total: 18s	remaining: 1m 5s
# 434:	total: 18.1s	remaining: 1m 5s
# 435:	total: 18.1s	remaining: 1m 4s
# 436:	total: 18.1s	remaining: 1m 4s
# 437:	total: 18.2s	remaining: 1m 4s
# 438:	total: 18.2s	remaining: 1m 4s
# 439:	total: 18.3s	remaining: 1m 4s
# 440:	total: 18.3s	remaining: 1m 4s
# 441:	total: 18.4s	remaining: 1m 4s
# 442:	total: 18.4s	remaining: 1m 4s
# 443:	total: 18.4s	remaining: 1m 4s
# 444:	total: 18.5s	remaining: 1m 4s
# 445:	total: 18.5s	remaining: 1m 4s
# 446:	total: 18.5s	remaining: 1m 4s
# 447:	total: 18.6s	remaining: 1m 4s
# 448:	total: 18.6s	remaining: 1m 4s
# 449:	total: 18.7s	remaining: 1m 4s
# 450:	total: 18.7s	remaining: 1m 4s
# 451:	total: 18.7s	remaining: 1m 4s
# 452:	total: 18.8s	remaining: 1m 4s
# 453:	total: 18.8s	remaining: 1m 4s
# 454:	total: 18.8s	remaining: 1m 3s
# 455:	total: 18.9s	remaining: 1m 3s
# 456:	total: 18.9s	remaining: 1m 3s
# 457:	total: 18.9s	remaining: 1m 3s
# 458:	total: 19s	remaining: 1m 3s
# 459:	total: 19s	remaining: 1m 3s
# 460:	total: 19s	remaining: 1m 3s
# 461:	total: 19.1s	remaining: 1m 3s
# 462:	total: 19.1s	remaining: 1m 3s
# 463:	total: 19.2s	remaining: 1m 3s
# 464:	total: 19.2s	remaining: 1m 3s
# 465:	total: 19.2s	remaining: 1m 3s
# 466:	total: 19.3s	remaining: 1m 3s
# 467:	total: 19.3s	remaining: 1m 3s
# 468:	total: 19.3s	remaining: 1m 3s
# 469:	total: 19.4s	remaining: 1m 3s
# 470:	total: 19.4s	remaining: 1m 3s
# 471:	total: 19.4s	remaining: 1m 2s
# 472:	total: 19.5s	remaining: 1m 2s
# 473:	total: 19.5s	remaining: 1m 2s
# 474:	total: 19.6s	remaining: 1m 2s
# 475:	total: 19.6s	remaining: 1m 2s
# 476:	total: 19.6s	remaining: 1m 2s
# 477:	total: 19.7s	remaining: 1m 2s
# 478:	total: 19.7s	remaining: 1m 2s
# 479:	total: 19.7s	remaining: 1m 2s
# 480:	total: 19.8s	remaining: 1m 2s
# 481:	total: 19.8s	remaining: 1m 2s
# 482:	total: 19.8s	remaining: 1m 2s
# 483:	total: 19.9s	remaining: 1m 2s
# 484:	total: 19.9s	remaining: 1m 2s
# 485:	total: 19.9s	remaining: 1m 2s
# 486:	total: 20s	remaining: 1m 2s
# 487:	total: 20s	remaining: 1m 2s
# 488:	total: 20.1s	remaining: 1m 1s
# 489:	total: 20.1s	remaining: 1m 1s
# 490:	total: 20.1s	remaining: 1m 1s
# 491:	total: 20.2s	remaining: 1m 1s
# 492:	total: 20.2s	remaining: 1m 1s
# 493:	total: 20.2s	remaining: 1m 1s
# 494:	total: 20.3s	remaining: 1m 1s
# 495:	total: 20.3s	remaining: 1m 1s
# 496:	total: 20.3s	remaining: 1m 1s
# 497:	total: 20.4s	remaining: 1m 1s
# 498:	total: 20.4s	remaining: 1m 1s
# 499:	total: 20.5s	remaining: 1m 1s
# 500:	total: 20.5s	remaining: 1m 1s
# 501:	total: 20.5s	remaining: 1m 1s
# 502:	total: 20.6s	remaining: 1m 1s
# 503:	total: 20.6s	remaining: 1m 1s
# 504:	total: 20.6s	remaining: 1m 1s
# 505:	total: 20.7s	remaining: 1m 1s
# 506:	total: 20.7s	remaining: 1m 1s
# 507:	total: 20.8s	remaining: 1m
# 508:	total: 20.8s	remaining: 1m
# 509:	total: 20.8s	remaining: 1m
# 510:	total: 20.9s	remaining: 1m
# 511:	total: 20.9s	remaining: 1m
# 512:	total: 20.9s	remaining: 1m
# 513:	total: 21s	remaining: 1m
# 514:	total: 21s	remaining: 1m
# 515:	total: 21s	remaining: 1m
# 516:	total: 21.1s	remaining: 1m
# 517:	total: 21.1s	remaining: 1m
# 518:	total: 21.1s	remaining: 1m
# 519:	total: 21.2s	remaining: 1m
# 520:	total: 21.2s	remaining: 1m
# 521:	total: 21.3s	remaining: 1m
# 522:	total: 21.3s	remaining: 1m
# 523:	total: 21.3s	remaining: 1m
# 524:	total: 21.4s	remaining: 1m
# 525:	total: 21.4s	remaining: 60s
# 526:	total: 21.4s	remaining: 59.9s
# 527:	total: 21.5s	remaining: 59.9s
# 528:	total: 21.5s	remaining: 59.8s
# 529:	total: 21.5s	remaining: 59.8s
# 530:	total: 21.6s	remaining: 59.7s
# 531:	total: 21.6s	remaining: 59.6s
# 532:	total: 21.7s	remaining: 59.6s
# 533:	total: 21.7s	remaining: 59.5s
# 534:	total: 21.7s	remaining: 59.5s
# 535:	total: 21.8s	remaining: 59.4s
# 536:	total: 21.8s	remaining: 59.4s
# 537:	total: 21.8s	remaining: 59.3s
# 538:	total: 21.9s	remaining: 59.3s
# 539:	total: 21.9s	remaining: 59.2s
# 540:	total: 21.9s	remaining: 59.2s
# 541:	total: 22s	remaining: 59.1s
# 542:	total: 22s	remaining: 59s
# 543:	total: 22.1s	remaining: 59s
# 544:	total: 22.1s	remaining: 59s
# 545:	total: 22.1s	remaining: 58.9s
# 546:	total: 22.2s	remaining: 58.9s
# 547:	total: 22.2s	remaining: 58.8s
# 548:	total: 22.2s	remaining: 58.8s
# 549:	total: 22.3s	remaining: 58.7s
# 550:	total: 22.3s	remaining: 58.6s
# 551:	total: 22.3s	remaining: 58.6s
# 552:	total: 22.4s	remaining: 58.5s
# 553:	total: 22.4s	remaining: 58.5s
# 554:	total: 22.4s	remaining: 58.4s
# 555:	total: 22.5s	remaining: 58.4s
# 556:	total: 22.5s	remaining: 58.3s
# 557:	total: 22.5s	remaining: 58.3s
# 558:	total: 22.6s	remaining: 58.2s
# 559:	total: 22.6s	remaining: 58.2s
# 560:	total: 22.7s	remaining: 58.1s
# 561:	total: 22.7s	remaining: 58.1s
# 562:	total: 22.7s	remaining: 58s
# 563:	total: 22.8s	remaining: 58s
# 564:	total: 22.8s	remaining: 58s
# 565:	total: 22.9s	remaining: 57.9s
# 566:	total: 22.9s	remaining: 57.9s
# 567:	total: 22.9s	remaining: 57.8s
# 568:	total: 23s	remaining: 57.7s
# 569:	total: 23s	remaining: 57.7s
# 570:	total: 23s	remaining: 57.6s
# 571:	total: 23.1s	remaining: 57.6s
# 572:	total: 23.1s	remaining: 57.5s
# 573:	total: 23.1s	remaining: 57.5s
# 574:	total: 23.2s	remaining: 57.4s
# 575:	total: 23.2s	remaining: 57.4s
# 576:	total: 23.3s	remaining: 57.3s
# 577:	total: 23.3s	remaining: 57.3s
# 578:	total: 23.3s	remaining: 57.2s
# 579:	total: 23.4s	remaining: 57.2s
# 580:	total: 23.4s	remaining: 57.1s
# 581:	total: 23.4s	remaining: 57.1s
# 582:	total: 23.5s	remaining: 57s
# 583:	total: 23.5s	remaining: 57s
# 584:	total: 23.5s	remaining: 56.9s
# 585:	total: 23.6s	remaining: 56.9s
# 586:	total: 23.6s	remaining: 56.8s
# 587:	total: 23.6s	remaining: 56.8s
# 588:	total: 23.7s	remaining: 56.8s
# 589:	total: 23.7s	remaining: 56.7s
# 590:	total: 23.8s	remaining: 56.6s
# 591:	total: 23.8s	remaining: 56.6s
# 592:	total: 23.8s	remaining: 56.6s
# 593:	total: 23.9s	remaining: 56.5s
# 594:	total: 23.9s	remaining: 56.5s
# 595:	total: 23.9s	remaining: 56.4s
# 596:	total: 24s	remaining: 56.4s
# 597:	total: 24s	remaining: 56.3s
# 598:	total: 24.1s	remaining: 56.3s
# 599:	total: 24.1s	remaining: 56.2s
# 600:	total: 24.1s	remaining: 56.2s
# 601:	total: 24.2s	remaining: 56.1s
# 602:	total: 24.2s	remaining: 56s
# 603:	total: 24.2s	remaining: 56s
# 604:	total: 24.3s	remaining: 56s
# 605:	total: 24.3s	remaining: 55.9s
# 606:	total: 24.3s	remaining: 55.9s
# 607:	total: 24.4s	remaining: 55.8s
# 608:	total: 24.4s	remaining: 55.8s
# 609:	total: 24.5s	remaining: 55.7s
# 610:	total: 24.5s	remaining: 55.7s
# 611:	total: 24.5s	remaining: 55.6s
# 612:	total: 24.6s	remaining: 55.5s
# 613:	total: 24.6s	remaining: 55.5s
# 614:	total: 24.6s	remaining: 55.5s
# 615:	total: 24.7s	remaining: 55.4s
# 616:	total: 24.7s	remaining: 55.4s
# 617:	total: 24.7s	remaining: 55.3s
# 618:	total: 24.8s	remaining: 55.3s
# 619:	total: 24.8s	remaining: 55.2s
# 620:	total: 24.8s	remaining: 55.2s
# 621:	total: 24.9s	remaining: 55.1s
# 622:	total: 24.9s	remaining: 55.1s
# 623:	total: 24.9s	remaining: 55s
# 624:	total: 25s	remaining: 55s
# 625:	total: 25s	remaining: 54.9s
# 626:	total: 25.1s	remaining: 54.9s
# 627:	total: 25.1s	remaining: 54.8s
# 628:	total: 25.1s	remaining: 54.8s
# 629:	total: 25.2s	remaining: 54.7s
# 630:	total: 25.2s	remaining: 54.7s
# 631:	total: 25.2s	remaining: 54.6s
# 632:	total: 25.3s	remaining: 54.6s
# 633:	total: 25.3s	remaining: 54.6s
# 634:	total: 25.4s	remaining: 54.5s
# 635:	total: 25.4s	remaining: 54.5s
# 636:	total: 25.4s	remaining: 54.4s
# 637:	total: 25.5s	remaining: 54.4s
# 638:	total: 25.5s	remaining: 54.3s
# 639:	total: 25.5s	remaining: 54.3s
# 640:	total: 25.6s	remaining: 54.2s
# 641:	total: 25.6s	remaining: 54.2s
# 642:	total: 25.6s	remaining: 54.1s
# 643:	total: 25.7s	remaining: 54.1s
# 644:	total: 25.7s	remaining: 54s
# 645:	total: 25.8s	remaining: 54s
# 646:	total: 25.8s	remaining: 53.9s
# 647:	total: 25.8s	remaining: 53.9s
# 648:	total: 25.9s	remaining: 53.8s
# 649:	total: 25.9s	remaining: 53.8s
# 650:	total: 25.9s	remaining: 53.7s
# 651:	total: 26s	remaining: 53.7s
# 652:	total: 26s	remaining: 53.6s
# 653:	total: 26s	remaining: 53.6s
# 654:	total: 26.1s	remaining: 53.5s
# 655:	total: 26.1s	remaining: 53.5s
# 656:	total: 26.1s	remaining: 53.4s
# 657:	total: 26.2s	remaining: 53.4s
# 658:	total: 26.2s	remaining: 53.3s
# 659:	total: 26.3s	remaining: 53.3s
# 660:	total: 26.3s	remaining: 53.3s
# 661:	total: 26.3s	remaining: 53.2s
# 662:	total: 26.4s	remaining: 53.2s
# 663:	total: 26.4s	remaining: 53.1s
# 664:	total: 26.4s	remaining: 53.1s
# 665:	total: 26.5s	remaining: 53s
# 666:	total: 26.5s	remaining: 53s
# 667:	total: 26.5s	remaining: 52.9s
# 668:	total: 26.6s	remaining: 52.9s
# 669:	total: 26.6s	remaining: 52.8s
# 670:	total: 26.7s	remaining: 52.8s
# 671:	total: 26.7s	remaining: 52.7s
# 672:	total: 26.7s	remaining: 52.7s
# 673:	total: 26.8s	remaining: 52.6s
# 674:	total: 26.8s	remaining: 52.6s
# 675:	total: 26.8s	remaining: 52.6s
# 676:	total: 26.9s	remaining: 52.5s
# 677:	total: 26.9s	remaining: 52.5s
# 678:	total: 26.9s	remaining: 52.4s
# 679:	total: 27s	remaining: 52.4s
# 680:	total: 27s	remaining: 52.3s
# 681:	total: 27.1s	remaining: 52.3s
# 682:	total: 27.1s	remaining: 52.2s
# 683:	total: 27.1s	remaining: 52.2s
# 684:	total: 27.2s	remaining: 52.1s
# 685:	total: 27.2s	remaining: 52.1s
# 686:	total: 27.2s	remaining: 52.1s
# 687:	total: 27.3s	remaining: 52s
# 688:	total: 27.3s	remaining: 51.9s
# 689:	total: 27.3s	remaining: 51.9s
# 690:	total: 27.4s	remaining: 51.9s
# 691:	total: 27.4s	remaining: 51.8s
# 692:	total: 27.4s	remaining: 51.8s
# 693:	total: 27.5s	remaining: 51.7s
# 694:	total: 27.5s	remaining: 51.7s
# 695:	total: 27.6s	remaining: 51.6s
# 696:	total: 27.6s	remaining: 51.6s
# 697:	total: 27.6s	remaining: 51.5s
# 698:	total: 27.7s	remaining: 51.5s
# 699:	total: 27.7s	remaining: 51.5s
# 700:	total: 27.7s	remaining: 51.4s
# 701:	total: 27.8s	remaining: 51.4s
# 702:	total: 27.8s	remaining: 51.3s
# 703:	total: 27.9s	remaining: 51.3s
# 704:	total: 27.9s	remaining: 51.2s
# 705:	total: 27.9s	remaining: 51.2s
# 706:	total: 28s	remaining: 51.1s
# 707:	total: 28s	remaining: 51.1s
# 708:	total: 28s	remaining: 51.1s
# 709:	total: 28.1s	remaining: 51s
# 710:	total: 28.1s	remaining: 51s
# 711:	total: 28.1s	remaining: 50.9s
# 712:	total: 28.2s	remaining: 50.9s
# 713:	total: 28.2s	remaining: 50.8s
# 714:	total: 28.2s	remaining: 50.8s
# 715:	total: 28.3s	remaining: 50.7s
# 716:	total: 28.3s	remaining: 50.7s
# 717:	total: 28.3s	remaining: 50.6s
# 718:	total: 28.4s	remaining: 50.6s
# 719:	total: 28.4s	remaining: 50.5s
# 720:	total: 28.5s	remaining: 50.5s
# 721:	total: 28.5s	remaining: 50.4s
# 722:	total: 28.5s	remaining: 50.4s
# 723:	total: 28.6s	remaining: 50.3s
# 724:	total: 28.6s	remaining: 50.3s
# 725:	total: 28.6s	remaining: 50.2s
# 726:	total: 28.7s	remaining: 50.2s
# 727:	total: 28.7s	remaining: 50.1s
# 728:	total: 28.7s	remaining: 50.1s
# 729:	total: 28.8s	remaining: 50.1s
# 730:	total: 28.8s	remaining: 50s
# 731:	total: 28.8s	remaining: 50s
# 732:	total: 28.9s	remaining: 49.9s
# 733:	total: 28.9s	remaining: 49.9s
# 734:	total: 29s	remaining: 49.8s
# 735:	total: 29s	remaining: 49.8s
# 736:	total: 29s	remaining: 49.7s
# 737:	total: 29.1s	remaining: 49.7s
# 738:	total: 29.1s	remaining: 49.6s
# 739:	total: 29.1s	remaining: 49.6s
# 740:	total: 29.2s	remaining: 49.6s
# 741:	total: 29.2s	remaining: 49.5s
# 742:	total: 29.2s	remaining: 49.5s
# 743:	total: 29.3s	remaining: 49.4s
# 744:	total: 29.3s	remaining: 49.4s
# 745:	total: 29.4s	remaining: 49.3s
# 746:	total: 29.4s	remaining: 49.3s
# 747:	total: 29.4s	remaining: 49.2s
# 748:	total: 29.5s	remaining: 49.2s
# 749:	total: 29.5s	remaining: 49.2s
# 750:	total: 29.5s	remaining: 49.1s
# 751:	total: 29.6s	remaining: 49.1s
# 752:	total: 29.6s	remaining: 49s
# 753:	total: 29.6s	remaining: 49s
# 754:	total: 29.7s	remaining: 49s
# 755:	total: 29.7s	remaining: 48.9s
# 756:	total: 29.8s	remaining: 48.9s
# 757:	total: 29.8s	remaining: 48.8s
# 758:	total: 29.8s	remaining: 48.8s
# 759:	total: 29.9s	remaining: 48.7s
# 760:	total: 29.9s	remaining: 48.7s
# 761:	total: 29.9s	remaining: 48.6s
# 762:	total: 30s	remaining: 48.6s
# 763:	total: 30s	remaining: 48.5s
# 764:	total: 30s	remaining: 48.5s
# 765:	total: 30.1s	remaining: 48.5s
# 766:	total: 30.1s	remaining: 48.4s
# 767:	total: 30.2s	remaining: 48.4s
# 768:	total: 30.2s	remaining: 48.3s
# 769:	total: 30.2s	remaining: 48.3s
# 770:	total: 30.3s	remaining: 48.2s
# 771:	total: 30.3s	remaining: 48.2s
# 772:	total: 30.3s	remaining: 48.2s
# 773:	total: 30.4s	remaining: 48.1s
# 774:	total: 30.4s	remaining: 48.1s
# 775:	total: 30.5s	remaining: 48s
# 776:	total: 30.5s	remaining: 48s
# 777:	total: 30.5s	remaining: 47.9s
# 778:	total: 30.6s	remaining: 47.9s
# 779:	total: 30.6s	remaining: 47.8s
# 780:	total: 30.6s	remaining: 47.8s
# 781:	total: 30.7s	remaining: 47.8s
# 782:	total: 30.7s	remaining: 47.7s
# 783:	total: 30.7s	remaining: 47.7s
# 784:	total: 30.8s	remaining: 47.6s
# 785:	total: 30.8s	remaining: 47.6s
# 786:	total: 30.8s	remaining: 47.5s
# 787:	total: 30.9s	remaining: 47.5s
# 788:	total: 30.9s	remaining: 47.4s
# 789:	total: 30.9s	remaining: 47.4s
# 790:	total: 31s	remaining: 47.4s
# 791:	total: 31s	remaining: 47.3s
# 792:	total: 31.1s	remaining: 47.3s
# 793:	total: 31.1s	remaining: 47.2s
# 794:	total: 31.1s	remaining: 47.2s
# 795:	total: 31.2s	remaining: 47.1s
# 796:	total: 31.2s	remaining: 47.1s
# 797:	total: 31.2s	remaining: 47.1s
# 798:	total: 31.3s	remaining: 47s
# 799:	total: 31.3s	remaining: 47s
# 800:	total: 31.3s	remaining: 46.9s
# 801:	total: 31.4s	remaining: 46.9s
# 802:	total: 31.4s	remaining: 46.8s
# 803:	total: 31.4s	remaining: 46.8s
# 804:	total: 31.5s	remaining: 46.7s
# 805:	total: 31.5s	remaining: 46.7s
# 806:	total: 31.6s	remaining: 46.7s
# 807:	total: 31.6s	remaining: 46.6s
# 808:	total: 31.6s	remaining: 46.6s
# 809:	total: 31.7s	remaining: 46.5s
# 810:	total: 31.7s	remaining: 46.5s
# 811:	total: 31.7s	remaining: 46.4s
# 812:	total: 31.8s	remaining: 46.4s
# 813:	total: 31.8s	remaining: 46.4s
# 814:	total: 31.9s	remaining: 46.3s
# 815:	total: 31.9s	remaining: 46.3s
# 816:	total: 31.9s	remaining: 46.2s
# 817:	total: 32s	remaining: 46.2s
# 818:	total: 32s	remaining: 46.1s
# 819:	total: 32s	remaining: 46.1s
# 820:	total: 32.1s	remaining: 46.1s
# 821:	total: 32.1s	remaining: 46s
# 822:	total: 32.1s	remaining: 46s
# 823:	total: 32.2s	remaining: 45.9s
# 824:	total: 32.2s	remaining: 45.9s
# 825:	total: 32.2s	remaining: 45.8s
# 826:	total: 32.3s	remaining: 45.8s
# 827:	total: 32.3s	remaining: 45.7s
# 828:	total: 32.4s	remaining: 45.7s
# 829:	total: 32.4s	remaining: 45.7s
# 830:	total: 32.4s	remaining: 45.6s
# 831:	total: 32.5s	remaining: 45.6s
# 832:	total: 32.5s	remaining: 45.5s
# 833:	total: 32.5s	remaining: 45.5s
# 834:	total: 32.6s	remaining: 45.4s
# 835:	total: 32.6s	remaining: 45.4s
# 836:	total: 32.6s	remaining: 45.4s
# 837:	total: 32.7s	remaining: 45.3s
# 838:	total: 32.7s	remaining: 45.3s
# 839:	total: 32.8s	remaining: 45.2s
# 840:	total: 32.8s	remaining: 45.2s
# 841:	total: 32.8s	remaining: 45.2s
# 842:	total: 32.9s	remaining: 45.1s
# 843:	total: 32.9s	remaining: 45.1s
# 844:	total: 32.9s	remaining: 45s
# 845:	total: 33s	remaining: 45s
# 846:	total: 33s	remaining: 44.9s
# 847:	total: 33.1s	remaining: 44.9s
# 848:	total: 33.1s	remaining: 44.9s
# 849:	total: 33.1s	remaining: 44.8s
# 850:	total: 33.2s	remaining: 44.8s
# 851:	total: 33.2s	remaining: 44.7s
# 852:	total: 33.2s	remaining: 44.7s
# 853:	total: 33.3s	remaining: 44.6s
# 854:	total: 33.3s	remaining: 44.6s
# 855:	total: 33.3s	remaining: 44.5s
# 856:	total: 33.4s	remaining: 44.5s
# 857:	total: 33.4s	remaining: 44.5s
# 858:	total: 33.4s	remaining: 44.4s
# 859:	total: 33.5s	remaining: 44.4s
# 860:	total: 33.5s	remaining: 44.3s
# 861:	total: 33.5s	remaining: 44.3s
# 862:	total: 33.6s	remaining: 44.2s
# 863:	total: 33.6s	remaining: 44.2s
# 864:	total: 33.7s	remaining: 44.2s
# 865:	total: 33.7s	remaining: 44.1s
# 866:	total: 33.7s	remaining: 44.1s
# 867:	total: 33.8s	remaining: 44s
# 868:	total: 33.8s	remaining: 44s
# 869:	total: 33.8s	remaining: 43.9s
# 870:	total: 33.9s	remaining: 43.9s
# 871:	total: 33.9s	remaining: 43.8s
# 872:	total: 33.9s	remaining: 43.8s
# 873:	total: 34s	remaining: 43.8s
# 874:	total: 34s	remaining: 43.7s
# 875:	total: 34s	remaining: 43.7s
# 876:	total: 34.1s	remaining: 43.6s
# 877:	total: 34.1s	remaining: 43.6s
# 878:	total: 34.2s	remaining: 43.6s
# 879:	total: 34.2s	remaining: 43.5s
# 880:	total: 34.2s	remaining: 43.5s
# 881:	total: 34.3s	remaining: 43.4s
# 882:	total: 34.3s	remaining: 43.4s
# 883:	total: 34.3s	remaining: 43.3s
# 884:	total: 34.4s	remaining: 43.3s
# 885:	total: 34.4s	remaining: 43.2s
# 886:	total: 34.4s	remaining: 43.2s
# 887:	total: 34.5s	remaining: 43.2s
# 888:	total: 34.5s	remaining: 43.1s
# 889:	total: 34.5s	remaining: 43.1s
# 890:	total: 34.6s	remaining: 43s
# 891:	total: 34.6s	remaining: 43s
# 892:	total: 34.7s	remaining: 43s
# 893:	total: 34.7s	remaining: 42.9s
# 894:	total: 34.7s	remaining: 42.9s
# 895:	total: 34.8s	remaining: 42.8s
# 896:	total: 34.8s	remaining: 42.8s
# 897:	total: 34.9s	remaining: 42.8s
# 898:	total: 35s	remaining: 42.9s
# 899:	total: 35s	remaining: 42.8s
# 900:	total: 35.1s	remaining: 42.8s
# 901:	total: 35.1s	remaining: 42.7s
# 902:	total: 35.1s	remaining: 42.7s
# 903:	total: 35.2s	remaining: 42.6s
# 904:	total: 35.2s	remaining: 42.6s
# 905:	total: 35.2s	remaining: 42.6s
# 906:	total: 35.3s	remaining: 42.5s
# 907:	total: 35.3s	remaining: 42.5s
# 908:	total: 35.3s	remaining: 42.4s
# 909:	total: 35.4s	remaining: 42.4s
# 910:	total: 35.4s	remaining: 42.3s
# 911:	total: 35.5s	remaining: 42.3s
# 912:	total: 35.5s	remaining: 42.3s
# 913:	total: 35.5s	remaining: 42.2s
# 914:	total: 35.6s	remaining: 42.2s
# 915:	total: 35.6s	remaining: 42.1s
# 916:	total: 35.6s	remaining: 42.1s
# 917:	total: 35.7s	remaining: 42.1s
# 918:	total: 35.7s	remaining: 42s
# 919:	total: 35.7s	remaining: 42s
# 920:	total: 35.8s	remaining: 41.9s
# 921:	total: 35.8s	remaining: 41.9s
# 922:	total: 35.9s	remaining: 41.8s
# 923:	total: 35.9s	remaining: 41.8s
# 924:	total: 35.9s	remaining: 41.8s
# 925:	total: 36s	remaining: 41.7s
# 926:	total: 36s	remaining: 41.7s
# 927:	total: 36s	remaining: 41.6s
# 928:	total: 36.1s	remaining: 41.6s
# 929:	total: 36.1s	remaining: 41.5s
# 930:	total: 36.1s	remaining: 41.5s
# 931:	total: 36.2s	remaining: 41.4s
# 932:	total: 36.2s	remaining: 41.4s
# 933:	total: 36.2s	remaining: 41.4s
# 934:	total: 36.3s	remaining: 41.3s
# 935:	total: 36.3s	remaining: 41.3s
# 936:	total: 36.3s	remaining: 41.2s
# 937:	total: 36.4s	remaining: 41.2s
# 938:	total: 36.4s	remaining: 41.1s
# 939:	total: 36.5s	remaining: 41.1s
# 940:	total: 36.5s	remaining: 41.1s
# 941:	total: 36.5s	remaining: 41s
# 942:	total: 36.6s	remaining: 41s
# 943:	total: 36.6s	remaining: 40.9s
# 944:	total: 36.6s	remaining: 40.9s
# 945:	total: 36.7s	remaining: 40.9s
# 946:	total: 36.7s	remaining: 40.8s
# 947:	total: 36.8s	remaining: 40.8s
# 948:	total: 36.8s	remaining: 40.7s
# 949:	total: 36.8s	remaining: 40.7s
# 950:	total: 36.9s	remaining: 40.7s
# 951:	total: 36.9s	remaining: 40.6s
# 952:	total: 36.9s	remaining: 40.6s
# 953:	total: 37s	remaining: 40.5s
# 954:	total: 37s	remaining: 40.5s
# 955:	total: 37s	remaining: 40.4s
# 956:	total: 37.1s	remaining: 40.4s
# 957:	total: 37.1s	remaining: 40.3s
# 958:	total: 37.1s	remaining: 40.3s
# 959:	total: 37.2s	remaining: 40.3s
# 960:	total: 37.2s	remaining: 40.2s
# 961:	total: 37.2s	remaining: 40.2s
# 962:	total: 37.3s	remaining: 40.1s
# 963:	total: 37.3s	remaining: 40.1s
# 964:	total: 37.3s	remaining: 40.1s
# 965:	total: 37.4s	remaining: 40s
# 966:	total: 37.4s	remaining: 40s
# 967:	total: 37.5s	remaining: 39.9s
# 968:	total: 37.5s	remaining: 39.9s
# 969:	total: 37.5s	remaining: 39.8s
# 970:	total: 37.6s	remaining: 39.8s
# 971:	total: 37.6s	remaining: 39.8s
# 972:	total: 37.6s	remaining: 39.7s
# 973:	total: 37.7s	remaining: 39.7s
# 974:	total: 37.7s	remaining: 39.7s
# 975:	total: 37.8s	remaining: 39.6s
# 976:	total: 37.8s	remaining: 39.6s
# 977:	total: 37.8s	remaining: 39.5s
# 978:	total: 37.9s	remaining: 39.5s
# 979:	total: 37.9s	remaining: 39.4s
# 980:	total: 37.9s	remaining: 39.4s
# 981:	total: 38s	remaining: 39.4s
# 982:	total: 38s	remaining: 39.3s
# 983:	total: 38s	remaining: 39.3s
# 984:	total: 38.1s	remaining: 39.2s
# 985:	total: 38.1s	remaining: 39.2s
# 986:	total: 38.1s	remaining: 39.2s
# 987:	total: 38.2s	remaining: 39.1s
# 988:	total: 38.2s	remaining: 39.1s
# 989:	total: 38.3s	remaining: 39s
# 990:	total: 38.3s	remaining: 39s
# 991:	total: 38.3s	remaining: 38.9s
# 992:	total: 38.4s	remaining: 38.9s
# 993:	total: 38.4s	remaining: 38.9s
# 994:	total: 38.4s	remaining: 38.8s
# 995:	total: 38.5s	remaining: 38.8s
# 996:	total: 38.5s	remaining: 38.7s
# 997:	total: 38.5s	remaining: 38.7s
# 998:	total: 38.6s	remaining: 38.7s
# 999:	total: 38.6s	remaining: 38.6s
# 1000:	total: 38.7s	remaining: 38.6s
# 1001:	total: 38.7s	remaining: 38.5s
# 1002:	total: 38.7s	remaining: 38.5s
# 1003:	total: 38.8s	remaining: 38.5s
# 1004:	total: 38.8s	remaining: 38.4s
# 1005:	total: 38.8s	remaining: 38.4s
# 1006:	total: 38.9s	remaining: 38.3s
# 1007:	total: 38.9s	remaining: 38.3s
# 1008:	total: 38.9s	remaining: 38.2s
# 1009:	total: 39s	remaining: 38.2s
# 1010:	total: 39s	remaining: 38.2s
# 1011:	total: 39s	remaining: 38.1s
# 1012:	total: 39.1s	remaining: 38.1s
# 1013:	total: 39.1s	remaining: 38s
# 1014:	total: 39.2s	remaining: 38s
# 1015:	total: 39.2s	remaining: 38s
# 1016:	total: 39.2s	remaining: 37.9s
# 1017:	total: 39.3s	remaining: 37.9s
# 1018:	total: 39.3s	remaining: 37.8s
# 1019:	total: 39.3s	remaining: 37.8s
# 1020:	total: 39.4s	remaining: 37.8s
# 1021:	total: 39.4s	remaining: 37.7s
# 1022:	total: 39.4s	remaining: 37.7s
# 1023:	total: 39.5s	remaining: 37.6s
# 1024:	total: 39.5s	remaining: 37.6s
# 1025:	total: 39.5s	remaining: 37.5s
# 1026:	total: 39.6s	remaining: 37.5s
# 1027:	total: 39.6s	remaining: 37.5s
# 1028:	total: 39.6s	remaining: 37.4s
# 1029:	total: 39.7s	remaining: 37.4s
# 1030:	total: 39.7s	remaining: 37.3s
# 1031:	total: 39.8s	remaining: 37.3s
# 1032:	total: 39.8s	remaining: 37.2s
# 1033:	total: 39.8s	remaining: 37.2s
# 1034:	total: 39.9s	remaining: 37.2s
# 1035:	total: 39.9s	remaining: 37.1s
# 1036:	total: 39.9s	remaining: 37.1s
# 1037:	total: 40s	remaining: 37s
# 1038:	total: 40s	remaining: 37s
# 1039:	total: 40s	remaining: 37s
# 1040:	total: 40.1s	remaining: 36.9s
# 1041:	total: 40.1s	remaining: 36.9s
# 1042:	total: 40.1s	remaining: 36.8s
# 1043:	total: 40.2s	remaining: 36.8s
# 1044:	total: 40.2s	remaining: 36.8s
# 1045:	total: 40.2s	remaining: 36.7s
# 1046:	total: 40.3s	remaining: 36.7s
# 1047:	total: 40.3s	remaining: 36.6s
# 1048:	total: 40.4s	remaining: 36.6s
# 1049:	total: 40.4s	remaining: 36.5s
# 1050:	total: 40.4s	remaining: 36.5s
# 1051:	total: 40.5s	remaining: 36.5s
# 1052:	total: 40.5s	remaining: 36.4s
# 1053:	total: 40.5s	remaining: 36.4s
# 1054:	total: 40.6s	remaining: 36.3s
# 1055:	total: 40.6s	remaining: 36.3s
# 1056:	total: 40.6s	remaining: 36.3s
# 1057:	total: 40.7s	remaining: 36.2s
# 1058:	total: 40.7s	remaining: 36.2s
# 1059:	total: 40.7s	remaining: 36.1s
# 1060:	total: 40.8s	remaining: 36.1s
# 1061:	total: 40.8s	remaining: 36s
# 1062:	total: 40.8s	remaining: 36s
# 1063:	total: 40.9s	remaining: 36s
# 1064:	total: 40.9s	remaining: 35.9s
# 1065:	total: 41s	remaining: 35.9s
# 1066:	total: 41s	remaining: 35.8s
# 1067:	total: 41s	remaining: 35.8s
# 1068:	total: 41.1s	remaining: 35.8s
# 1069:	total: 41.1s	remaining: 35.7s
# 1070:	total: 41.1s	remaining: 35.7s
# 1071:	total: 41.2s	remaining: 35.6s
# 1072:	total: 41.2s	remaining: 35.6s
# 1073:	total: 41.2s	remaining: 35.5s
# 1074:	total: 41.3s	remaining: 35.5s
# 1075:	total: 41.3s	remaining: 35.5s
# 1076:	total: 41.3s	remaining: 35.4s
# 1077:	total: 41.4s	remaining: 35.4s
# 1078:	total: 41.4s	remaining: 35.3s
# 1079:	total: 41.4s	remaining: 35.3s
# 1080:	total: 41.5s	remaining: 35.3s
# 1081:	total: 41.5s	remaining: 35.2s
# 1082:	total: 41.5s	remaining: 35.2s
# 1083:	total: 41.6s	remaining: 35.1s
# 1084:	total: 41.6s	remaining: 35.1s
# 1085:	total: 41.6s	remaining: 35s
# 1086:	total: 41.7s	remaining: 35s
# 1087:	total: 41.7s	remaining: 35s
# 1088:	total: 41.8s	remaining: 34.9s
# 1089:	total: 41.8s	remaining: 34.9s
# 1090:	total: 41.8s	remaining: 34.8s
# 1091:	total: 41.9s	remaining: 34.8s
# 1092:	total: 41.9s	remaining: 34.8s
# 1093:	total: 41.9s	remaining: 34.7s
# 1094:	total: 42s	remaining: 34.7s
# 1095:	total: 42s	remaining: 34.6s
# 1096:	total: 42s	remaining: 34.6s
# 1097:	total: 42.1s	remaining: 34.6s
# 1098:	total: 42.1s	remaining: 34.5s
# 1099:	total: 42.1s	remaining: 34.5s
# 1100:	total: 42.2s	remaining: 34.4s
# 1101:	total: 42.2s	remaining: 34.4s
# 1102:	total: 42.2s	remaining: 34.4s
# 1103:	total: 42.3s	remaining: 34.3s
# 1104:	total: 42.3s	remaining: 34.3s
# 1105:	total: 42.4s	remaining: 34.2s
# 1106:	total: 42.4s	remaining: 34.2s
# 1107:	total: 42.4s	remaining: 34.2s
# 1108:	total: 42.5s	remaining: 34.1s
# 1109:	total: 42.5s	remaining: 34.1s
# 1110:	total: 42.5s	remaining: 34s
# 1111:	total: 42.6s	remaining: 34s
# 1112:	total: 42.6s	remaining: 34s
# 1113:	total: 42.6s	remaining: 33.9s
# 1114:	total: 42.7s	remaining: 33.9s
# 1115:	total: 42.7s	remaining: 33.8s
# 1116:	total: 42.8s	remaining: 33.8s
# 1117:	total: 42.8s	remaining: 33.8s
# 1118:	total: 42.8s	remaining: 33.7s
# 1119:	total: 42.9s	remaining: 33.7s
# 1120:	total: 42.9s	remaining: 33.6s
# 1121:	total: 42.9s	remaining: 33.6s
# 1122:	total: 43s	remaining: 33.6s
# 1123:	total: 43s	remaining: 33.5s
# 1124:	total: 43s	remaining: 33.5s
# 1125:	total: 43.1s	remaining: 33.4s
# 1126:	total: 43.1s	remaining: 33.4s
# 1127:	total: 43.2s	remaining: 33.4s
# 1128:	total: 43.2s	remaining: 33.3s
# 1129:	total: 43.2s	remaining: 33.3s
# 1130:	total: 43.3s	remaining: 33.2s
# 1131:	total: 43.3s	remaining: 33.2s
# 1132:	total: 43.3s	remaining: 33.2s
# 1133:	total: 43.4s	remaining: 33.1s
# 1134:	total: 43.4s	remaining: 33.1s
# 1135:	total: 43.4s	remaining: 33s
# 1136:	total: 43.5s	remaining: 33s
# 1137:	total: 43.5s	remaining: 33s
# 1138:	total: 43.6s	remaining: 32.9s
# 1139:	total: 43.6s	remaining: 32.9s
# 1140:	total: 43.6s	remaining: 32.8s
# 1141:	total: 43.7s	remaining: 32.8s
# 1142:	total: 43.7s	remaining: 32.8s
# 1143:	total: 43.7s	remaining: 32.7s
# 1144:	total: 43.8s	remaining: 32.7s
# 1145:	total: 43.8s	remaining: 32.6s
# 1146:	total: 43.8s	remaining: 32.6s
# 1147:	total: 43.9s	remaining: 32.6s
# 1148:	total: 43.9s	remaining: 32.5s
# 1149:	total: 43.9s	remaining: 32.5s
# 1150:	total: 44s	remaining: 32.4s
# 1151:	total: 44s	remaining: 32.4s
# 1152:	total: 44s	remaining: 32.4s
# 1153:	total: 44.1s	remaining: 32.3s
# 1154:	total: 44.1s	remaining: 32.3s
# 1155:	total: 44.2s	remaining: 32.2s
# 1156:	total: 44.2s	remaining: 32.2s
# 1157:	total: 44.2s	remaining: 32.2s
# 1158:	total: 44.3s	remaining: 32.1s
# 1159:	total: 44.3s	remaining: 32.1s
# 1160:	total: 44.3s	remaining: 32s
# 1161:	total: 44.4s	remaining: 32s
# 1162:	total: 44.4s	remaining: 32s
# 1163:	total: 44.4s	remaining: 31.9s
# 1164:	total: 44.5s	remaining: 31.9s
# 1165:	total: 44.5s	remaining: 31.8s
# 1166:	total: 44.5s	remaining: 31.8s
# 1167:	total: 44.6s	remaining: 31.8s
# 1168:	total: 44.6s	remaining: 31.7s
# 1169:	total: 44.7s	remaining: 31.7s
# 1170:	total: 44.7s	remaining: 31.6s
# 1171:	total: 44.7s	remaining: 31.6s
# 1172:	total: 44.8s	remaining: 31.6s
# 1173:	total: 44.8s	remaining: 31.5s
# 1174:	total: 44.8s	remaining: 31.5s
# 1175:	total: 44.9s	remaining: 31.4s
# 1176:	total: 44.9s	remaining: 31.4s
# 1177:	total: 44.9s	remaining: 31.4s
# 1178:	total: 45s	remaining: 31.3s
# 1179:	total: 45s	remaining: 31.3s
# 1180:	total: 45s	remaining: 31.2s
# 1181:	total: 45.1s	remaining: 31.2s
# 1182:	total: 45.1s	remaining: 31.2s
# 1183:	total: 45.1s	remaining: 31.1s
# 1184:	total: 45.2s	remaining: 31.1s
# 1185:	total: 45.2s	remaining: 31s
# 1186:	total: 45.3s	remaining: 31s
# 1187:	total: 45.3s	remaining: 31s
# 1188:	total: 45.3s	remaining: 30.9s
# 1189:	total: 45.4s	remaining: 30.9s
# 1190:	total: 45.4s	remaining: 30.8s
# 1191:	total: 45.4s	remaining: 30.8s
# 1192:	total: 45.5s	remaining: 30.8s
# 1193:	total: 45.5s	remaining: 30.7s
# 1194:	total: 45.5s	remaining: 30.7s
# 1195:	total: 45.6s	remaining: 30.6s
# 1196:	total: 45.6s	remaining: 30.6s
# 1197:	total: 45.6s	remaining: 30.5s
# 1198:	total: 45.7s	remaining: 30.5s
# 1199:	total: 45.7s	remaining: 30.5s
# 1200:	total: 45.7s	remaining: 30.4s
# 1201:	total: 45.8s	remaining: 30.4s
# 1202:	total: 45.8s	remaining: 30.4s
# 1203:	total: 45.9s	remaining: 30.3s
# 1204:	total: 45.9s	remaining: 30.3s
# 1205:	total: 45.9s	remaining: 30.2s
# 1206:	total: 46s	remaining: 30.2s
# 1207:	total: 46s	remaining: 30.2s
# 1208:	total: 46s	remaining: 30.1s
# 1209:	total: 46.1s	remaining: 30.1s
# 1210:	total: 46.1s	remaining: 30s
# 1211:	total: 46.1s	remaining: 30s
# 1212:	total: 46.2s	remaining: 30s
# 1213:	total: 46.2s	remaining: 29.9s
# 1214:	total: 46.3s	remaining: 29.9s
# 1215:	total: 46.3s	remaining: 29.8s
# 1216:	total: 46.3s	remaining: 29.8s
# 1217:	total: 46.4s	remaining: 29.8s
# 1218:	total: 46.4s	remaining: 29.7s
# 1219:	total: 46.4s	remaining: 29.7s
# 1220:	total: 46.5s	remaining: 29.7s
# 1221:	total: 46.5s	remaining: 29.6s
# 1222:	total: 46.5s	remaining: 29.6s
# 1223:	total: 46.6s	remaining: 29.5s
# 1224:	total: 46.6s	remaining: 29.5s
# 1225:	total: 46.7s	remaining: 29.5s
# 1226:	total: 46.7s	remaining: 29.4s
# 1227:	total: 46.7s	remaining: 29.4s
# 1228:	total: 46.8s	remaining: 29.3s
# 1229:	total: 46.8s	remaining: 29.3s
# 1230:	total: 46.8s	remaining: 29.3s
# 1231:	total: 46.9s	remaining: 29.2s
# 1232:	total: 46.9s	remaining: 29.2s
# 1233:	total: 46.9s	remaining: 29.1s
# 1234:	total: 47s	remaining: 29.1s
# 1235:	total: 47s	remaining: 29.1s
# 1236:	total: 47.1s	remaining: 29s
# 1237:	total: 47.1s	remaining: 29s
# 1238:	total: 47.1s	remaining: 28.9s
# 1239:	total: 47.2s	remaining: 28.9s
# 1240:	total: 47.2s	remaining: 28.9s
# 1241:	total: 47.2s	remaining: 28.8s
# 1242:	total: 47.3s	remaining: 28.8s
# 1243:	total: 47.3s	remaining: 28.8s
# 1244:	total: 47.4s	remaining: 28.7s
# 1245:	total: 47.4s	remaining: 28.7s
# 1246:	total: 47.4s	remaining: 28.6s
# 1247:	total: 47.5s	remaining: 28.6s
# 1248:	total: 47.5s	remaining: 28.6s
# 1249:	total: 47.5s	remaining: 28.5s
# 1250:	total: 47.6s	remaining: 28.5s
# 1251:	total: 47.6s	remaining: 28.4s
# 1252:	total: 47.6s	remaining: 28.4s
# 1253:	total: 47.7s	remaining: 28.4s
# 1254:	total: 47.7s	remaining: 28.3s
# 1255:	total: 47.8s	remaining: 28.3s
# 1256:	total: 47.8s	remaining: 28.2s
# 1257:	total: 47.8s	remaining: 28.2s
# 1258:	total: 47.9s	remaining: 28.2s
# 1259:	total: 47.9s	remaining: 28.1s
# 1260:	total: 47.9s	remaining: 28.1s
# 1261:	total: 48s	remaining: 28.1s
# 1262:	total: 48s	remaining: 28s
# 1263:	total: 48s	remaining: 28s
# 1264:	total: 48.1s	remaining: 27.9s
# 1265:	total: 48.1s	remaining: 27.9s
# 1266:	total: 48.1s	remaining: 27.8s
# 1267:	total: 48.2s	remaining: 27.8s
# 1268:	total: 48.2s	remaining: 27.8s
# 1269:	total: 48.2s	remaining: 27.7s
# 1270:	total: 48.3s	remaining: 27.7s
# 1271:	total: 48.3s	remaining: 27.7s
# 1272:	total: 48.3s	remaining: 27.6s
# 1273:	total: 48.4s	remaining: 27.6s
# 1274:	total: 48.4s	remaining: 27.5s
# 1275:	total: 48.5s	remaining: 27.5s
# 1276:	total: 48.5s	remaining: 27.5s
# 1277:	total: 48.5s	remaining: 27.4s
# 1278:	total: 48.6s	remaining: 27.4s
# 1279:	total: 48.6s	remaining: 27.3s
# 1280:	total: 48.6s	remaining: 27.3s
# 1281:	total: 48.7s	remaining: 27.3s
# 1282:	total: 48.7s	remaining: 27.2s
# 1283:	total: 48.7s	remaining: 27.2s
# 1284:	total: 48.8s	remaining: 27.1s
# 1285:	total: 48.8s	remaining: 27.1s
# 1286:	total: 48.8s	remaining: 27.1s
# 1287:	total: 48.9s	remaining: 27s
# 1288:	total: 48.9s	remaining: 27s
# 1289:	total: 48.9s	remaining: 26.9s
# 1290:	total: 49s	remaining: 26.9s
# 1291:	total: 49s	remaining: 26.9s
# 1292:	total: 49.1s	remaining: 26.8s
# 1293:	total: 49.1s	remaining: 26.8s
# 1294:	total: 49.1s	remaining: 26.7s
# 1295:	total: 49.2s	remaining: 26.7s
# 1296:	total: 49.2s	remaining: 26.7s
# 1297:	total: 49.2s	remaining: 26.6s
# 1298:	total: 49.3s	remaining: 26.6s
# 1299:	total: 49.3s	remaining: 26.6s
# 1300:	total: 49.3s	remaining: 26.5s
# 1301:	total: 49.4s	remaining: 26.5s
# 1302:	total: 49.4s	remaining: 26.4s
# 1303:	total: 49.5s	remaining: 26.4s
# 1304:	total: 49.5s	remaining: 26.4s
# 1305:	total: 49.5s	remaining: 26.3s
# 1306:	total: 49.6s	remaining: 26.3s
# 1307:	total: 49.6s	remaining: 26.2s
# 1308:	total: 49.6s	remaining: 26.2s
# 1309:	total: 49.7s	remaining: 26.2s
# 1310:	total: 49.7s	remaining: 26.1s
# 1311:	total: 49.7s	remaining: 26.1s
# 1312:	total: 49.8s	remaining: 26s
# 1313:	total: 49.8s	remaining: 26s
# 1314:	total: 49.8s	remaining: 26s
# 1315:	total: 49.9s	remaining: 25.9s
# 1316:	total: 49.9s	remaining: 25.9s
# 1317:	total: 49.9s	remaining: 25.8s
# 1318:	total: 50s	remaining: 25.8s
# 1319:	total: 50s	remaining: 25.8s
# 1320:	total: 50.1s	remaining: 25.7s
# 1321:	total: 50.1s	remaining: 25.7s
# 1322:	total: 50.1s	remaining: 25.7s
# 1323:	total: 50.2s	remaining: 25.6s
# 1324:	total: 50.2s	remaining: 25.6s
# 1325:	total: 50.2s	remaining: 25.5s
# 1326:	total: 50.3s	remaining: 25.5s
# 1327:	total: 50.3s	remaining: 25.5s
# 1328:	total: 50.3s	remaining: 25.4s
# 1329:	total: 50.4s	remaining: 25.4s
# 1330:	total: 50.4s	remaining: 25.3s
# 1331:	total: 50.5s	remaining: 25.3s
# 1332:	total: 50.5s	remaining: 25.3s
# 1333:	total: 50.5s	remaining: 25.2s
# 1334:	total: 50.5s	remaining: 25.2s
# 1335:	total: 50.6s	remaining: 25.1s
# 1336:	total: 50.6s	remaining: 25.1s
# 1337:	total: 50.7s	remaining: 25.1s
# 1338:	total: 50.7s	remaining: 25s
# 1339:	total: 50.7s	remaining: 25s
# 1340:	total: 50.8s	remaining: 25s
# 1341:	total: 50.8s	remaining: 24.9s
# 1342:	total: 50.8s	remaining: 24.9s
# 1343:	total: 50.9s	remaining: 24.8s
# 1344:	total: 50.9s	remaining: 24.8s
# 1345:	total: 50.9s	remaining: 24.8s
# 1346:	total: 51s	remaining: 24.7s
# 1347:	total: 51s	remaining: 24.7s
# 1348:	total: 51s	remaining: 24.6s
# 1349:	total: 51.1s	remaining: 24.6s
# 1350:	total: 51.1s	remaining: 24.6s
# 1351:	total: 51.1s	remaining: 24.5s
# 1352:	total: 51.2s	remaining: 24.5s
# 1353:	total: 51.2s	remaining: 24.4s
# 1354:	total: 51.3s	remaining: 24.4s
# 1355:	total: 51.3s	remaining: 24.4s
# 1356:	total: 51.3s	remaining: 24.3s
# 1357:	total: 51.4s	remaining: 24.3s
# 1358:	total: 51.4s	remaining: 24.2s
# 1359:	total: 51.4s	remaining: 24.2s
# 1360:	total: 51.5s	remaining: 24.2s
# 1361:	total: 51.5s	remaining: 24.1s
# 1362:	total: 51.5s	remaining: 24.1s
# 1363:	total: 51.6s	remaining: 24s
# 1364:	total: 51.6s	remaining: 24s
# 1365:	total: 51.6s	remaining: 24s
# 1366:	total: 51.7s	remaining: 23.9s
# 1367:	total: 51.7s	remaining: 23.9s
# ...
# 1564:	total: 1m 2s	remaining: 17.3s
# 1565:	total: 1m 2s	remaining: 17.3s
# 1566:	total: 1m 2s	remaining: 17.2s
# 1567:	total: 1m 2s	remaining: 17.2s
# 1568:	total: 1m 2s	remaining: 17.2s
# 1569:	total: 1m 2s	remaining: 17.1s
# 1570:	total: 1m 2s	remaining: 17.1s
# 1571:	total: 1m 2s	remaining: 17s
# 1572:	total: 1m 2s	remaining: 17s
# 1573:	total: 1m 2s	remaining: 17s
# 1574:	total: 1m 2s	remaining: 16.9s
# 1575:	total: 1m 2s	remaining: 16.9s
# 1576:	total: 1m 2s	remaining: 16.8s
# 1577:	total: 1m 2s	remaining: 16.8s
# 1578:	total: 1m 2s	remaining: 16.8s
# 1579:	total: 1m 2s	remaining: 16.7s
# 1580:	total: 1m 2s	remaining: 16.7s
# 1581:	total: 1m 2s	remaining: 16.7s
# 1582:	total: 1m 3s	remaining: 16.6s
# 1583:	total: 1m 3s	remaining: 16.6s
# 1584:	total: 1m 3s	remaining: 16.5s
# 1585:	total: 1m 3s	remaining: 16.5s
# 1586:	total: 1m 3s	remaining: 16.5s
# 1587:	total: 1m 3s	remaining: 16.4s
# 1588:	total: 1m 3s	remaining: 16.4s
# 1589:	total: 1m 3s	remaining: 16.3s
# 1590:	total: 1m 3s	remaining: 16.3s
# 1591:	total: 1m 3s	remaining: 16.3s
# 1592:	total: 1m 3s	remaining: 16.2s
# 1593:	total: 1m 3s	remaining: 16.2s
# 1594:	total: 1m 3s	remaining: 16.2s
# 1595:	total: 1m 3s	remaining: 16.1s
# 1596:	total: 1m 3s	remaining: 16.1s
# 1597:	total: 1m 3s	remaining: 16s
# 1598:	total: 1m 3s	remaining: 16s
# 1599:	total: 1m 3s	remaining: 16s
# 1600:	total: 1m 3s	remaining: 15.9s
# 1601:	total: 1m 3s	remaining: 15.9s
# 1602:	total: 1m 3s	remaining: 15.8s
# 1603:	total: 1m 4s	remaining: 15.8s
# 1604:	total: 1m 4s	remaining: 15.8s
# 1605:	total: 1m 4s	remaining: 15.7s
# 1606:	total: 1m 4s	remaining: 15.7s
# 1607:	total: 1m 4s	remaining: 15.6s
# 1608:	total: 1m 4s	remaining: 15.6s
# 1609:	total: 1m 4s	remaining: 15.6s
# 1610:	total: 1m 4s	remaining: 15.5s
# 1611:	total: 1m 4s	remaining: 15.5s
# 1612:	total: 1m 4s	remaining: 15.4s
# 1613:	total: 1m 4s	remaining: 15.4s
# 1614:	total: 1m 4s	remaining: 15.4s
# 1615:	total: 1m 4s	remaining: 15.3s
# 1616:	total: 1m 4s	remaining: 15.3s
# 1617:	total: 1m 4s	remaining: 15.2s
# 1618:	total: 1m 4s	remaining: 15.2s
# 1619:	total: 1m 4s	remaining: 15.2s
# 1620:	total: 1m 4s	remaining: 15.1s
# 1621:	total: 1m 4s	remaining: 15.1s
# 1622:	total: 1m 4s	remaining: 15s
# 1623:	total: 1m 4s	remaining: 15s
# 1624:	total: 1m 4s	remaining: 15s
# 1625:	total: 1m 4s	remaining: 14.9s
# 1626:	total: 1m 4s	remaining: 14.9s
# 1627:	total: 1m 4s	remaining: 14.8s
# 1628:	total: 1m 4s	remaining: 14.8s
# 1629:	total: 1m 4s	remaining: 14.8s
# 1630:	total: 1m 5s	remaining: 14.7s
# 1631:	total: 1m 5s	remaining: 14.7s
# 1632:	total: 1m 5s	remaining: 14.6s
# 1633:	total: 1m 5s	remaining: 14.6s
# 1634:	total: 1m 5s	remaining: 14.6s
# 1635:	total: 1m 5s	remaining: 14.5s
# 1636:	total: 1m 5s	remaining: 14.5s
# 1637:	total: 1m 5s	remaining: 14.4s
# 1638:	total: 1m 5s	remaining: 14.4s
# 1639:	total: 1m 5s	remaining: 14.4s
# 1640:	total: 1m 5s	remaining: 14.3s
# 1641:	total: 1m 5s	remaining: 14.3s
# 1642:	total: 1m 5s	remaining: 14.2s
# 1643:	total: 1m 5s	remaining: 14.2s
# 1644:	total: 1m 5s	remaining: 14.2s
# 1645:	total: 1m 5s	remaining: 14.1s
# 1646:	total: 1m 5s	remaining: 14.1s
# 1647:	total: 1m 5s	remaining: 14s
# 1648:	total: 1m 5s	remaining: 14s
# 1649:	total: 1m 5s	remaining: 14s
# 1650:	total: 1m 5s	remaining: 13.9s
# 1651:	total: 1m 5s	remaining: 13.9s
# 1652:	total: 1m 5s	remaining: 13.8s
# 1653:	total: 1m 5s	remaining: 13.8s
# 1654:	total: 1m 5s	remaining: 13.8s
# 1655:	total: 1m 5s	remaining: 13.7s
# 1656:	total: 1m 6s	remaining: 13.7s
# 1657:	total: 1m 6s	remaining: 13.6s
# 1658:	total: 1m 6s	remaining: 13.6s
# 1659:	total: 1m 6s	remaining: 13.6s
# 1660:	total: 1m 6s	remaining: 13.5s
# 1661:	total: 1m 6s	remaining: 13.5s
# 1662:	total: 1m 6s	remaining: 13.5s
# 1663:	total: 1m 6s	remaining: 13.4s
# 1664:	total: 1m 6s	remaining: 13.4s
# 1665:	total: 1m 6s	remaining: 13.3s
# 1666:	total: 1m 6s	remaining: 13.3s
# 1667:	total: 1m 6s	remaining: 13.3s
# 1668:	total: 1m 6s	remaining: 13.2s
# 1669:	total: 1m 6s	remaining: 13.2s
# 1670:	total: 1m 6s	remaining: 13.1s
# 1671:	total: 1m 6s	remaining: 13.1s
# 1672:	total: 1m 6s	remaining: 13.1s
# 1673:	total: 1m 6s	remaining: 13s
# 1674:	total: 1m 6s	remaining: 13s
# 1675:	total: 1m 6s	remaining: 12.9s
# 1676:	total: 1m 6s	remaining: 12.9s
# 1677:	total: 1m 6s	remaining: 12.9s
# 1678:	total: 1m 6s	remaining: 12.8s
# 1679:	total: 1m 7s	remaining: 12.8s
# 1680:	total: 1m 7s	remaining: 12.7s
# 1681:	total: 1m 7s	remaining: 12.7s
# 1682:	total: 1m 7s	remaining: 12.7s
# 1683:	total: 1m 7s	remaining: 12.6s
# 1684:	total: 1m 7s	remaining: 12.6s
# 1685:	total: 1m 7s	remaining: 12.5s
# 1686:	total: 1m 7s	remaining: 12.5s
# 1687:	total: 1m 7s	remaining: 12.5s
# 1688:	total: 1m 7s	remaining: 12.4s
# 1689:	total: 1m 7s	remaining: 12.4s
# 1690:	total: 1m 7s	remaining: 12.4s
# 1691:	total: 1m 7s	remaining: 12.3s
# 1692:	total: 1m 7s	remaining: 12.3s
# 1693:	total: 1m 7s	remaining: 12.2s
# 1694:	total: 1m 7s	remaining: 12.2s
# 1695:	total: 1m 7s	remaining: 12.2s
# 1696:	total: 1m 7s	remaining: 12.1s
# 1697:	total: 1m 7s	remaining: 12.1s
# 1698:	total: 1m 7s	remaining: 12s
# 1699:	total: 1m 8s	remaining: 12s
# 1700:	total: 1m 8s	remaining: 12s
# 1701:	total: 1m 8s	remaining: 11.9s
# 1702:	total: 1m 8s	remaining: 11.9s
# 1703:	total: 1m 8s	remaining: 11.9s
# 1704:	total: 1m 8s	remaining: 11.8s
# 1705:	total: 1m 8s	remaining: 11.8s
# 1706:	total: 1m 8s	remaining: 11.8s
# 1707:	total: 1m 8s	remaining: 11.7s
# 1708:	total: 1m 8s	remaining: 11.7s
# 1709:	total: 1m 8s	remaining: 11.7s
# 1710:	total: 1m 8s	remaining: 11.6s
# 1711:	total: 1m 8s	remaining: 11.6s
# 1712:	total: 1m 8s	remaining: 11.5s
# 1713:	total: 1m 8s	remaining: 11.5s
# 1714:	total: 1m 8s	remaining: 11.5s
# 1715:	total: 1m 8s	remaining: 11.4s
# 1716:	total: 1m 9s	remaining: 11.4s
# 1717:	total: 1m 9s	remaining: 11.3s
# 1718:	total: 1m 9s	remaining: 11.3s
# 1719:	total: 1m 9s	remaining: 11.3s
# 1720:	total: 1m 9s	remaining: 11.2s
# 1721:	total: 1m 9s	remaining: 11.2s
# 1722:	total: 1m 9s	remaining: 11.2s
# 1723:	total: 1m 9s	remaining: 11.1s
# 1724:	total: 1m 9s	remaining: 11.1s
# 1725:	total: 1m 9s	remaining: 11s
# 1726:	total: 1m 9s	remaining: 11s
# 1727:	total: 1m 9s	remaining: 11s
# 1728:	total: 1m 9s	remaining: 10.9s
# 1729:	total: 1m 9s	remaining: 10.9s
# 1730:	total: 1m 9s	remaining: 10.8s
# 1731:	total: 1m 9s	remaining: 10.8s
# 1732:	total: 1m 9s	remaining: 10.8s
# 1733:	total: 1m 9s	remaining: 10.7s
# 1734:	total: 1m 9s	remaining: 10.7s
# 1735:	total: 1m 9s	remaining: 10.6s
# 1736:	total: 1m 10s	remaining: 10.6s
# 1737:	total: 1m 10s	remaining: 10.6s
# 1738:	total: 1m 10s	remaining: 10.6s
# 1739:	total: 1m 10s	remaining: 10.5s
# 1740:	total: 1m 10s	remaining: 10.5s
# 1741:	total: 1m 10s	remaining: 10.4s
# 1742:	total: 1m 10s	remaining: 10.4s
# 1743:	total: 1m 10s	remaining: 10.4s
# 1744:	total: 1m 10s	remaining: 10.3s
# 1745:	total: 1m 10s	remaining: 10.3s
# 1746:	total: 1m 10s	remaining: 10.3s
# 1747:	total: 1m 10s	remaining: 10.2s
# 1748:	total: 1m 10s	remaining: 10.2s
# 1749:	total: 1m 10s	remaining: 10.1s
# 1750:	total: 1m 11s	remaining: 10.1s
# 1751:	total: 1m 11s	remaining: 10.1s
# 1752:	total: 1m 11s	remaining: 10s
# 1753:	total: 1m 11s	remaining: 9.98s
# 1754:	total: 1m 11s	remaining: 9.95s
# 1755:	total: 1m 11s	remaining: 9.91s
# 1756:	total: 1m 11s	remaining: 9.87s
# 1757:	total: 1m 11s	remaining: 9.83s
# 1758:	total: 1m 11s	remaining: 9.79s
# 1759:	total: 1m 11s	remaining: 9.75s
# 1760:	total: 1m 11s	remaining: 9.71s
# 1761:	total: 1m 11s	remaining: 9.67s
# 1762:	total: 1m 11s	remaining: 9.63s
# 1763:	total: 1m 11s	remaining: 9.6s
# 1764:	total: 1m 11s	remaining: 9.56s
# 1765:	total: 1m 11s	remaining: 9.52s
# 1766:	total: 1m 11s	remaining: 9.48s
# 1767:	total: 1m 11s	remaining: 9.44s
# 1768:	total: 1m 11s	remaining: 9.4s
# 1769:	total: 1m 11s	remaining: 9.36s
# 1770:	total: 1m 12s	remaining: 9.32s
# 1771:	total: 1m 12s	remaining: 9.28s
# 1772:	total: 1m 12s	remaining: 9.25s
# 1773:	total: 1m 12s	remaining: 9.22s
# 1774:	total: 1m 12s	remaining: 9.18s
# 1775:	total: 1m 12s	remaining: 9.14s
# 1776:	total: 1m 12s	remaining: 9.11s
# 1777:	total: 1m 12s	remaining: 9.07s
# 1778:	total: 1m 12s	remaining: 9.04s
# 1779:	total: 1m 12s	remaining: 9s
# 1780:	total: 1m 12s	remaining: 8.96s
# 1781:	total: 1m 12s	remaining: 8.92s
# 1782:	total: 1m 12s	remaining: 8.88s
# 1783:	total: 1m 12s	remaining: 8.84s
# 1784:	total: 1m 12s	remaining: 8.8s
# 1785:	total: 1m 13s	remaining: 8.76s
# 1786:	total: 1m 13s	remaining: 8.72s
# 1787:	total: 1m 13s	remaining: 8.68s
# 1788:	total: 1m 13s	remaining: 8.63s
# 1789:	total: 1m 13s	remaining: 8.59s
# 1790:	total: 1m 13s	remaining: 8.55s
# 1791:	total: 1m 13s	remaining: 8.51s
# 1792:	total: 1m 13s	remaining: 8.47s
# 1793:	total: 1m 13s	remaining: 8.43s
# 1794:	total: 1m 13s	remaining: 8.39s
# 1795:	total: 1m 13s	remaining: 8.35s
# 1796:	total: 1m 13s	remaining: 8.31s
# 1797:	total: 1m 13s	remaining: 8.27s
# 1798:	total: 1m 13s	remaining: 8.23s
# 1799:	total: 1m 13s	remaining: 8.19s
# 1800:	total: 1m 13s	remaining: 8.15s
# 1801:	total: 1m 13s	remaining: 8.11s
# 1802:	total: 1m 13s	remaining: 8.06s
# 1803:	total: 1m 13s	remaining: 8.02s
# 1804:	total: 1m 13s	remaining: 7.98s
# 1805:	total: 1m 13s	remaining: 7.94s
# 1806:	total: 1m 13s	remaining: 7.9s
# 1807:	total: 1m 13s	remaining: 7.86s
# 1808:	total: 1m 14s	remaining: 7.82s
# 1809:	total: 1m 14s	remaining: 7.79s
# 1810:	total: 1m 14s	remaining: 7.75s
# 1811:	total: 1m 14s	remaining: 7.71s
# 1812:	total: 1m 14s	remaining: 7.67s
# 1813:	total: 1m 14s	remaining: 7.63s
# 1814:	total: 1m 14s	remaining: 7.58s
# 1815:	total: 1m 14s	remaining: 7.54s
# 1816:	total: 1m 14s	remaining: 7.5s
# 1817:	total: 1m 14s	remaining: 7.46s
# 1818:	total: 1m 14s	remaining: 7.42s
# 1819:	total: 1m 14s	remaining: 7.38s
# 1820:	total: 1m 14s	remaining: 7.34s
# 1821:	total: 1m 14s	remaining: 7.3s
# 1822:	total: 1m 14s	remaining: 7.26s
# 1823:	total: 1m 14s	remaining: 7.22s
# 1824:	total: 1m 14s	remaining: 7.18s
# 1825:	total: 1m 14s	remaining: 7.14s
# 1826:	total: 1m 14s	remaining: 7.1s
# 1827:	total: 1m 14s	remaining: 7.06s
# 1828:	total: 1m 15s	remaining: 7.02s
# 1829:	total: 1m 15s	remaining: 6.98s
# 1830:	total: 1m 15s	remaining: 6.94s
# 1831:	total: 1m 15s	remaining: 6.9s
# 1832:	total: 1m 15s	remaining: 6.86s
# 1833:	total: 1m 15s	remaining: 6.81s
# 1834:	total: 1m 15s	remaining: 6.77s
# 1835:	total: 1m 15s	remaining: 6.73s
# 1836:	total: 1m 15s	remaining: 6.69s
# 1837:	total: 1m 15s	remaining: 6.65s
# 1838:	total: 1m 15s	remaining: 6.61s
# 1839:	total: 1m 15s	remaining: 6.57s
# 1840:	total: 1m 15s	remaining: 6.53s
# 1841:	total: 1m 15s	remaining: 6.49s
# 1842:	total: 1m 15s	remaining: 6.46s
# 1843:	total: 1m 15s	remaining: 6.42s
# 1844:	total: 1m 15s	remaining: 6.38s
# 1845:	total: 1m 15s	remaining: 6.34s
# 1846:	total: 1m 15s	remaining: 6.29s
# 1847:	total: 1m 15s	remaining: 6.25s
# 1848:	total: 1m 16s	remaining: 6.21s
# 1849:	total: 1m 16s	remaining: 6.17s
# 1850:	total: 1m 16s	remaining: 6.13s
# 1851:	total: 1m 16s	remaining: 6.09s
# 1852:	total: 1m 16s	remaining: 6.05s
# 1853:	total: 1m 16s	remaining: 6.01s
# 1854:	total: 1m 16s	remaining: 5.97s
# 1855:	total: 1m 16s	remaining: 5.93s
# 1856:	total: 1m 16s	remaining: 5.89s
# 1857:	total: 1m 16s	remaining: 5.84s
# 1858:	total: 1m 16s	remaining: 5.8s
# 1859:	total: 1m 16s	remaining: 5.76s
# 1860:	total: 1m 16s	remaining: 5.72s
# 1861:	total: 1m 16s	remaining: 5.68s
# 1862:	total: 1m 16s	remaining: 5.64s
# 1863:	total: 1m 16s	remaining: 5.6s
# 1864:	total: 1m 16s	remaining: 5.56s
# 1865:	total: 1m 16s	remaining: 5.52s
# 1866:	total: 1m 16s	remaining: 5.48s
# 1867:	total: 1m 16s	remaining: 5.43s
# 1868:	total: 1m 16s	remaining: 5.39s
# 1869:	total: 1m 16s	remaining: 5.35s
# 1870:	total: 1m 17s	remaining: 5.31s
# 1871:	total: 1m 17s	remaining: 5.27s
# 1872:	total: 1m 17s	remaining: 5.23s
# 1873:	total: 1m 17s	remaining: 5.19s
# 1874:	total: 1m 17s	remaining: 5.15s
# 1875:	total: 1m 17s	remaining: 5.11s
# 1876:	total: 1m 17s	remaining: 5.07s
# 1877:	total: 1m 17s	remaining: 5.03s
# 1878:	total: 1m 17s	remaining: 5s
# 1879:	total: 1m 17s	remaining: 4.95s
# 1880:	total: 1m 17s	remaining: 4.91s
# 1881:	total: 1m 17s	remaining: 4.87s
# 1882:	total: 1m 17s	remaining: 4.83s
# 1883:	total: 1m 17s	remaining: 4.79s
# 1884:	total: 1m 17s	remaining: 4.75s
# 1885:	total: 1m 17s	remaining: 4.71s
# 1886:	total: 1m 17s	remaining: 4.67s
# 1887:	total: 1m 17s	remaining: 4.62s
# 1888:	total: 1m 17s	remaining: 4.58s
# 1889:	total: 1m 18s	remaining: 4.54s
# 1890:	total: 1m 18s	remaining: 4.5s
# 1891:	total: 1m 18s	remaining: 4.46s
# 1892:	total: 1m 18s	remaining: 4.42s
# 1893:	total: 1m 18s	remaining: 4.38s
# 1894:	total: 1m 18s	remaining: 4.34s
# 1895:	total: 1m 18s	remaining: 4.29s
# 1896:	total: 1m 18s	remaining: 4.25s
# 1897:	total: 1m 18s	remaining: 4.21s
# 1898:	total: 1m 18s	remaining: 4.17s
# 1899:	total: 1m 18s	remaining: 4.13s
# 1900:	total: 1m 18s	remaining: 4.09s
# 1901:	total: 1m 18s	remaining: 4.05s
# 1902:	total: 1m 18s	remaining: 4.01s
# 1903:	total: 1m 18s	remaining: 3.97s
# 1904:	total: 1m 18s	remaining: 3.92s
# 1905:	total: 1m 18s	remaining: 3.88s
# 1906:	total: 1m 18s	remaining: 3.84s
# 1907:	total: 1m 18s	remaining: 3.8s
# 1908:	total: 1m 18s	remaining: 3.76s
# 1909:	total: 1m 18s	remaining: 3.72s
# 1910:	total: 1m 18s	remaining: 3.68s
# 1911:	total: 1m 18s	remaining: 3.64s
# 1912:	total: 1m 19s	remaining: 3.6s
# 1913:	total: 1m 19s	remaining: 3.55s
# 1914:	total: 1m 19s	remaining: 3.51s
# 1915:	total: 1m 19s	remaining: 3.47s
# 1916:	total: 1m 19s	remaining: 3.44s
# 1917:	total: 1m 19s	remaining: 3.4s
# 1918:	total: 1m 19s	remaining: 3.35s
# 1919:	total: 1m 19s	remaining: 3.31s
# 1920:	total: 1m 19s	remaining: 3.27s
# 1921:	total: 1m 19s	remaining: 3.23s
# 1922:	total: 1m 19s	remaining: 3.19s
# 1923:	total: 1m 19s	remaining: 3.15s
# 1924:	total: 1m 19s	remaining: 3.1s
# 1925:	total: 1m 19s	remaining: 3.06s
# 1926:	total: 1m 19s	remaining: 3.02s
# 1927:	total: 1m 19s	remaining: 2.98s
# 1928:	total: 1m 19s	remaining: 2.94s
# 1929:	total: 1m 19s	remaining: 2.9s
# 1930:	total: 1m 19s	remaining: 2.85s
# 1931:	total: 1m 19s	remaining: 2.81s
# 1932:	total: 1m 19s	remaining: 2.77s
# 1933:	total: 1m 19s	remaining: 2.73s
# 1934:	total: 1m 20s	remaining: 2.69s
# 1935:	total: 1m 20s	remaining: 2.65s
# 1936:	total: 1m 20s	remaining: 2.6s
# 1937:	total: 1m 20s	remaining: 2.56s
# 1938:	total: 1m 20s	remaining: 2.52s
# 1939:	total: 1m 20s	remaining: 2.48s
# 1940:	total: 1m 20s	remaining: 2.44s
# 1941:	total: 1m 20s	remaining: 2.4s
# 1942:	total: 1m 20s	remaining: 2.36s
# 1943:	total: 1m 20s	remaining: 2.31s
# 1944:	total: 1m 20s	remaining: 2.27s
# 1945:	total: 1m 20s	remaining: 2.23s
# 1946:	total: 1m 20s	remaining: 2.19s
# 1947:	total: 1m 20s	remaining: 2.15s
# 1948:	total: 1m 20s	remaining: 2.11s
# 1949:	total: 1m 20s	remaining: 2.07s
# 1950:	total: 1m 20s	remaining: 2.02s
# 1951:	total: 1m 20s	remaining: 1.98s
# 1952:	total: 1m 20s	remaining: 1.94s
# 1953:	total: 1m 20s	remaining: 1.9s
# 1954:	total: 1m 20s	remaining: 1.86s
# 1955:	total: 1m 20s	remaining: 1.82s
# 1956:	total: 1m 20s	remaining: 1.78s
# 1957:	total: 1m 21s	remaining: 1.74s
# 1958:	total: 1m 21s	remaining: 1.7s
# 1959:	total: 1m 21s	remaining: 1.66s
# 1960:	total: 1m 21s	remaining: 1.61s
# 1961:	total: 1m 21s	remaining: 1.57s
# 1962:	total: 1m 21s	remaining: 1.53s
# 1963:	total: 1m 21s	remaining: 1.49s
# 1964:	total: 1m 21s	remaining: 1.45s
# 1965:	total: 1m 21s	remaining: 1.41s
# 1966:	total: 1m 21s	remaining: 1.37s
# 1967:	total: 1m 21s	remaining: 1.32s
# 1968:	total: 1m 21s	remaining: 1.28s
# 1969:	total: 1m 21s	remaining: 1.24s
# 1970:	total: 1m 21s	remaining: 1.2s
# 1971:	total: 1m 21s	remaining: 1.16s
# 1972:	total: 1m 21s	remaining: 1.12s
# 1973:	total: 1m 21s	remaining: 1.08s
# 1974:	total: 1m 21s	remaining: 1.03s
# 1975:	total: 1m 21s	remaining: 994ms
# 1976:	total: 1m 21s	remaining: 953ms
# 1977:	total: 1m 21s	remaining: 911ms
# 1978:	total: 1m 21s	remaining: 870ms
# 1979:	total: 1m 21s	remaining: 828ms
# 1980:	total: 1m 22s	remaining: 787ms
# 1981:	total: 1m 22s	remaining: 746ms
# 1982:	total: 1m 22s	remaining: 704ms
# 1983:	total: 1m 22s	remaining: 663ms
# 1984:	total: 1m 22s	remaining: 622ms
# 1985:	total: 1m 22s	remaining: 580ms
# 1986:	total: 1m 22s	remaining: 539ms
# 1987:	total: 1m 22s	remaining: 497ms
# 1988:	total: 1m 22s	remaining: 456ms
# 1989:	total: 1m 22s	remaining: 414ms
# 1990:	total: 1m 22s	remaining: 373ms
# 1991:	total: 1m 22s	remaining: 332ms
# 1992:	total: 1m 22s	remaining: 290ms
# 1993:	total: 1m 22s	remaining: 249ms
# 1994:	total: 1m 22s	remaining: 207ms
# 1995:	total: 1m 22s	remaining: 166ms
# 1996:	total: 1m 22s	remaining: 124ms
# 1997:	total: 1m 22s	remaining: 82.9ms
# 1998:	total: 1m 22s	remaining: 41.5ms
# 1999:	total: 1m 22s	remaining: 0us
# Cross-validation scores:[0.86233565 0.86542923 0.8652144  0.86138444 0.86456409]

# %%
print('Average cross-validation score: {}'.format(scores.mean()))
# Out:
# Average cross-validation score: 0.8637855628471602

# %% [markdown]
# _`The mean accuracy score of cross validation is almost same like original model accuracy score which is 0.8647050735597415. So, accuracy of model may not be improved using Cross-validation.`_

# %% [markdown]
# <hr style="height:1px">

# %% [markdown]
# <span style='font-size:15px;'><b>`(iii) Random Forest`</b></span>

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# `Model Training:`

# %%
start_time = time.time()
classifier_rf=RandomForestClassifier()
classifier_rf.fit(X_train,y_train)
end_time = time.time()

# %%
print("Time Taken to train: {}".format(end_time - start_time))
# Out:
# Time Taken to train: 78.29639101028442

# %% [markdown]
# `Model Testing:`

# %%
y_pred_rf = classifier_rf.predict(X_test)

# %%
print("Accuracy Score: {}".format(accuracy_score(y_test,y_pred_rf)))
# Out:
# Accuracy Score: 0.856111645813282

# %% [markdown]
# `Checking for Overfitting and Under Fitting:`

# %%
print("Train Data Score: {}".format(classifier_rf.score(X_train, y_train)))
print("Test Data Score: {}".format(classifier_rf.score(X_test, y_test)))
# Out:
# Train Data Score: 0.9999742197167606
# Test Data Score: 0.856111645813282

# %% [markdown]
# _`Accuracy score for Training Set is almost 1 or 100%, which is quite uncommon. And testing accuracy is 0.85. It seems like model is overfitting, because the generalization for unseen data is not that accurate, when compared with seen data and difference between training - testing accuracy is not minimum.`_

# %% [markdown]
# ## `8) Results and Conclusion:`  <a class="anchor" id=""></a>

# %% [markdown]
# `Best Models in terms of accuracy (In my Experiment):`
#
#     1) Cat Boost Model
#     2) Logistic Regression
#     3) Random Forest
#
# `Best Models in terms of Computation Time (In my Experiment):`
#
#     1) Logistic Regression
#     2) Random Forest
#     3) Cat Boost Model

# %% [markdown]
# `Conclusion:`
#
# The accuracy score of Cat Boost Model is high when compared with accuracy scores of Logistic Regression and Random Forest. But cat Boost model consumes lot of time to train the model.
#
# In terms of computation time and Accuracy score, logistic Regression model is doing job.

# %% [markdown]
# ## `9) Saving Classifier Object into Pickle File:`  <a class="anchor" id="10"></a>

# %%
with open('logreg.pkl', 'wb') as file:
    pickle.dump(classifier_logreg, file)

# %%
with open('catboostclassifier.pkl', 'wb') as file:
    pickle.dump(cat_classifier, file)

# %% [markdown]
# <br>
# <h1 align="center">. . . . . .</h1>
